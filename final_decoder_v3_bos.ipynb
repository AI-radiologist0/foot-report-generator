# %%
import os
import re
import json
import logging
import unicodedata
import random
from collections import defaultdict, Counter

import numpy as np
import cv2
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, random_split
from PIL import Image
from torchvision import transforms
from tqdm import tqdm
import timm
from transformers import GPT2Tokenizer, GPT2LMHeadModel
from sentence_transformers import SentenceTransformer
import matplotlib.pyplot as plt

logging.basicConfig(level=logging.INFO)

# =============================================================================
# Utility functions
# =============================================================================

def count_labels(data, target_classes, cfg):
    class_counts = defaultdict(int)
    data_by_class = defaultdict(list)
    for entry in tqdm(data.values(), desc="Counting dataset"):
        lbl = entry.get('class_label', '').lower()
        if lbl in target_classes and os.path.exists(entry['file_path']):
            class_counts[lbl] += 1
            data_by_class[lbl].append(entry)
    return class_counts, data_by_class

def prepare_abnormal_normal_data(data, cfg):
    random.seed(42)
    abnormal = ['ra', 'oa', 'gout']
    normal = ['normal']
    class_counts, data_by_class = count_labels(data, abnormal + normal, cfg)
    combined = {
        'abnormal': sum((data_by_class[c] for c in abnormal), []),
        'normal': data_by_class['normal']
    }
    combined_counts = {
        'abnormal': sum(class_counts[c] for c in abnormal),
        'normal': class_counts['normal']
    }
    if not cfg.DATASET.BALANCE and not cfg.DATASET.AUGMENT:
        return sum(combined.values(), []), combined_counts, combined_counts
    min_count = min(combined_counts.values())
    balanced = []
    final_counts = {}
    for lbl, items in combined.items():
        sampled = random.sample(items, min_count)
        balanced.extend(sampled)
        final_counts[lbl] = min_count
    if cfg.DATASET.AUGMENT:
        balanced *= 2
    return balanced, combined_counts, final_counts

def prepare_data(data, target_classes, cfg, is_binary=False):
    random.seed(42)
    if len(target_classes) == 2 and 'abnormal' in target_classes and 'normal' in target_classes:
        logging.info("Using abnormal-vs-normal logic")
        return prepare_abnormal_normal_data(data, cfg)
    class_counts, data_by_class = count_labels(data, target_classes, cfg)
    logging.info(f"Original class distribution: {class_counts}")
    if not cfg.DATASET.BALANCE and not cfg.DATASET.AUGMENT:
        return sum(data_by_class.values(), []), class_counts, class_counts
    min_count = min(class_counts.values())
    balanced, final_counts = [], {}
    for lbl in target_classes:
        sampled = random.sample(data_by_class[lbl], min_count)
        balanced.extend(sampled)
        final_counts[lbl] = min_count
    logging.info(f"Balanced class distribution: {final_counts}")
    if cfg.DATASET.AUGMENT:
        balanced *= 2
    return balanced, class_counts, final_counts

# =============================================================================
# Transforms
# =============================================================================

imagenet_mean = [0.485, 0.456, 0.406]
imagenet_std  = [0.229, 0.224, 0.225]

train_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(imagenet_mean, imagenet_std)
])

patch_transform = transforms.Compose([
    transforms.Resize((112, 112)),
    transforms.ToTensor(),
    transforms.Normalize(imagenet_mean, imagenet_std)
])

# =============================================================================
# Dataset
# =============================================================================

class FinalSamplesDataset(Dataset):
    def __init__(self, cfg, image_transform=train_transform, patch_transform=patch_transform):
        self.cfg = cfg
        self.image_transform = image_transform
        self.patch_transform = patch_transform

        self.target_classes = cfg.DATASET.TARGET_CLASSES
        if isinstance(self.target_classes, str):
            self.target_classes = self.target_classes.split(",")

        self.is_binary = len(self.target_classes) == 2
        self.abnormal_classify = self.is_binary and 'abnormal' in self.target_classes
        self.abnormal_mapping = (
            {'ra': 'abnormal', 'oa': 'abnormal', 'gout': 'abnormal', 'normal': 'normal'}
            if self.abnormal_classify else None
        )

        with open(cfg.DATASET.JSON, 'r') as f:
            raw_list = json.load(f)

        filtered = []
        for item in raw_list:
            merged = item.get('merged_image_path', '')
            fp = item.get('file_paths', [])
            if isinstance(fp, str):
                fp = [fp]
            paths = [merged] + fp
            if any(os.path.exists(p) for p in paths):
                filtered.append((merged, fp, item))

        self.data = {}
        for i, (merged, fp, item) in enumerate(filtered):
            cls = item.get('class', 'unknown').lower()
            if self.abnormal_mapping:
                cls = self.abnormal_mapping.get(cls, cls)
            self.data[i] = {
                'file_path': merged,
                'left_right_file_path': fp,
                'class_label': cls,
                'diagnosis': item.get('diagnosis', ''),
                'keypoints': item.get('keypoints', {})
            }

        if self.is_binary:
            balanced, _, _ = prepare_data(self.data, self.target_classes, cfg, True)
            self.data = {i: e for i, e in enumerate(balanced)}

        self.eos_token = None

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        e = self.data[idx]
        img = Image.open(e['file_path']).convert('RGB')
        img = self.image_transform(img)

        patches = self._gen_patches(e['left_right_file_path'], e['keypoints'])
        pt = [self.patch_transform(Image.fromarray(p)) for p in patches]
        patches_tensor = torch.stack(pt, 0) if pt else torch.zeros(34, 3, 112, 112)

        raw = e.get('diagnosis', '')
        clean = self._clean_report(raw)
        tok = tokenizer(clean, truncation=True, max_length=512, return_tensors='pt')

        return {
            'full_img':       img,
            'patches':        patches_tensor,
            'raw_report':     raw,
            'cleaned_report': clean,
            'input_ids':      tok['input_ids'].squeeze(0),
            'attention_mask': tok['attention_mask'].squeeze(0)
        }

    def _gen_patches(self, paths, kps_dict, crop_size=(200, 300), patch_size=(112, 112)):
        def extract(arr, side_kps):
            lst = []
            pts = side_kps[0]['keypoints']
            for i in range(17):
                x, y, s = int(pts[3*i]), int(pts[3*i+1]), pts[3*i+2]
                if s > 0:
                    x0 = max(x - crop_size[0]//2, 0)
                    y0 = max(y - crop_size[1]//2, 0)
                    x1 = min(x + crop_size[0]//2, arr.shape[1])
                    y1 = min(y + crop_size[1]//2, arr.shape[0])
                    c = arr[y0:y1, x0:x1]
                    if c.size:
                        lst.append(cv2.resize(c, patch_size))
            return lst

        def pad17(lst):
            black = np.zeros((patch_size[1], patch_size[0], 3), np.uint8)
            while len(lst) < 17:
                lst.append(black)
            return lst[:17]

        left, right = [], []
        if len(paths) == 1:
            pth = paths[0]
            if not pth or not os.path.exists(pth):
                return pad17([]) + pad17([])
            img_arr = cv2.imread(pth)
            if img_arr is None:
                return pad17([]) + pad17([])
            arr = cv2.cvtColor(img_arr, cv2.COLOR_BGR2RGB)
            if kps_dict.get('left'):  left  = extract(arr, kps_dict['left'])
            if kps_dict.get('right'): right = extract(arr, kps_dict['right'])
        else:
            for side, pth in zip(['left', 'right'], paths):
                if pth and os.path.exists(pth):
                    img_arr = cv2.imread(pth)
                    if img_arr is not None:
                        arr = cv2.cvtColor(img_arr, cv2.COLOR_BGR2RGB)
                        if kps_dict.get(side):
                            lst = extract(arr, kps_dict[side])
                            if side == 'left':  left  = lst
                            else:               right = lst

        if left and not right:
            right = [cv2.flip(p, 1) for p in left]
        if right and not left:
            left  = [cv2.flip(p, 1) for p in right]
        if not left and not right:
            return pad17([]) + pad17([])

        return pad17(left) + pad17(right)

    def _clean_report(self, text):
        text = unicodedata.normalize('NFKC', text or '')
        text = text.replace('_x000D_', ' ')
        text = re.sub(r'(?m)^\s*-+\s*$', '', text)
        text = re.sub(r'[^\x00-\x7F]+', ' ', text)
        text = re.sub(r'([.!?]){2,}', r'\1', text)
        text = re.sub(r'\[\s*finding\s*\]', '[FINDING]', text, flags=re.IGNORECASE)
        text = re.sub(r'\[\s*conclusion\s*\]', '[CONCLUSION]', text, flags=re.IGNORECASE)
        text = re.sub(r'\[\s*diagnosis\s*\]', '[DIAGNOSIS]', text, flags=re.IGNORECASE)
        parts = re.split(r'\[\s*recommend(?:ation)?\s*\]', text, flags=re.IGNORECASE)
        text = parts[0]
        fm = re.search(r'\[FINDING\](.*?)(?=\[|$)', text, flags=re.IGNORECASE|re.DOTALL)
        cm = re.search(r'\[CONCLUSION\](.*?)(?=\[|$)', text, flags=re.IGNORECASE|re.DOTALL)
        if fm and cm and fm.group(1).strip().lower() == cm.group(1).strip().lower():
            text = re.sub(r'\[CONCLUSION\].*?(?=\[|$)', '', text, flags=re.IGNORECASE|re.DOTALL)
        text = re.sub(r'\[\s*(FINDING|CONCLUSION|DIAGNOSIS)\s*\]', '', text, flags=re.IGNORECASE)
        text = re.sub(r'\s+', ' ', text).strip()
        text = re.sub(r'^-+\s*', '', text)
        if text and not text.endswith(self.eos_token):
            text += ' ' + self.eos_token
        return text

# =============================================================================
# Collate function (with .long() casts)
# =============================================================================

def collate_fn(batch):
    imgs = torch.stack([b['full_img'] for b in batch])
    pts  = [b['patches'] for b in batch]
    max_p = max(p.shape[0] for p in pts)
    pads = []
    for p in pts:
        if p.shape[0] < max_p:
            pad = torch.zeros((max_p - p.shape[0], *p.shape[1:]))
            p = torch.cat([p, pad], dim=0)
        pads.append(p)
    patches = torch.stack(pads, 0)

    ids   = [b['input_ids'] for b in batch]
    masks = [b['attention_mask'] for b in batch]
    ids   = nn.utils.rnn.pad_sequence(ids,   batch_first=True, padding_value=tokenizer.pad_token_id).long()
    masks = nn.utils.rnn.pad_sequence(masks, batch_first=True, padding_value=0).long()

    return {
        'full_imgs':       imgs,
        'patches':         patches,
        'input_ids':       ids,
        'attention_mask':  masks,
        'raw_reports':     [b['raw_report'] for b in batch],
        'cleaned_reports': [b['cleaned_report'] for b in batch]
    }

# =============================================================================
# Model
# =============================================================================

class MultiModalModel(nn.Module):
    def __init__(self, gpt2_model_name='gpt2'):
        super().__init__()
        self.global_encoder = timm.create_model('swin_base_patch4_window7_224', pretrained=True)
        self.global_encoder.reset_classifier(0)
        self.global_proj = nn.Linear(self.global_encoder.num_features, 768)

        self.patch_encoder = timm.create_model('resnet50', pretrained=True)
        self.patch_encoder.fc = nn.Identity()
        self.patch_proj = nn.Linear(self.patch_encoder.num_features, 768)

        self.attn = nn.MultiheadAttention(embed_dim=768, num_heads=8, batch_first=True)
        self.norm = nn.LayerNorm(768)

        self.decoder = GPT2LMHeadModel.from_pretrained(gpt2_model_name, add_cross_attention=True)

    def _pool(self, feats):
        return feats.mean(dim=[2,3]) if feats.ndim>2 else feats

    def forward(self, imgs, patches, input_ids, attention_mask, decoder_labels=None):
        # encode global image
        g = self.global_encoder(imgs)
        g = self.global_proj(g).unsqueeze(1)

        # encode patches
        B, N, C, H, W = patches.shape
        p = patches.view(B*N, C, H, W)
        pf = (self.patch_encoder.forward_features(p)
              if hasattr(self.patch_encoder, 'forward_features')
              else self.patch_encoder(p))
        pf = self._pool(pf)
        pf = self.patch_proj(pf).view(B, N, 768)

        # cross-attention
        cat, _ = self.attn(
            torch.cat([g, pf], dim=1),
            torch.cat([g, pf], dim=1),
            torch.cat([g, pf], dim=1)
        )
        cat = self.norm(cat)

        # decode
        return self.decoder(
            input_ids=input_ids,
            attention_mask=attention_mask,
            encoder_hidden_states=cat,
            labels=decoder_labels
        )

# =============================================================================
# Train / Eval helpers (with .long() casts)
# =============================================================================

def train_epoch(model, loader, optimizer, scaler, device):
    model.train()
    total_loss = 0.0
    for b in tqdm(loader, desc="Training", leave=False):
        imgs = b['full_imgs'].to(device)
        pts  = b['patches'].to(device)
        ids  = b['input_ids'].long().to(device)
        msk  = b['attention_mask'].long().to(device)

        optimizer.zero_grad()
        with torch.cuda.amp.autocast():
            out = model(imgs, pts, ids, msk, decoder_labels=ids)
            loss = out.loss
        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()
        total_loss += loss.item()
    return total_loss / len(loader)

def evaluate(model, loader, device):
    model.eval()
    total_loss = 0.0
    all_gen, all_gt = [], []
    for b in tqdm(loader, desc="Evaluating", leave=False):
        imgs = b['full_imgs'].to(device)
        pts  = b['patches'].to(device)
        ids  = b['input_ids'].long().to(device)
        msk  = b['attention_mask'].long().to(device)

        # teacher-forced loss
        with torch.no_grad():
            out = model(imgs, pts, ids, msk, decoder_labels=ids)
            total_loss += out.loss.item()

        # prepare pure BOS
        B = imgs.size(0)
        bos = torch.full((B, 1), tokenizer.eos_token_id, dtype=torch.long, device=device)
        bos_mask = torch.ones_like(bos)

        # generate
        with torch.no_grad():
            g = model.global_encoder(imgs)
            g = model.global_proj(g).unsqueeze(1)

            B, N, C, H, W = pts.shape
            p = pts.view(B*N, C, H, W)
            pf = (model.patch_encoder.forward_features(p)
                  if hasattr(model.patch_encoder, 'forward_features')
                  else model.patch_encoder(p))
            pf = model._pool(pf)
            pf = model.patch_proj(pf).view(B, N, 768)

            cat, _ = model.attn(
                torch.cat([g, pf], dim=1),
                torch.cat([g, pf], dim=1),
                torch.cat([g, pf], dim=1)
            )
            cat = model.norm(cat)

            gen_ids = model.decoder.generate(
                input_ids=bos,
                attention_mask=bos_mask,
                encoder_hidden_states=cat,
                max_length=100,
                do_sample=True,
                top_k=50,
                top_p=0.95,
                temperature=0.7,
                repetition_penalty=1.2,
                eos_token_id=tokenizer.eos_token_id,
                pad_token_id=tokenizer.eos_token_id
            )

        gen_txt = [tokenizer.decode(g_, skip_special_tokens=True) for g_ in gen_ids]
        gt_txt  = [tokenizer.decode(i_, skip_special_tokens=True) for i_ in ids]
        all_gen.extend(gen_txt)
        all_gt.extend(gt_txt)

    return total_loss / len(loader), all_gen, all_gt

def compute_semantic_similarity(gen, gt):
    stm = SentenceTransformer('all-MiniLM-L6-v2')
    e1 = stm.encode(gen, convert_to_tensor=True)
    e2 = stm.encode(gt, convert_to_tensor=True)
    return nn.functional.cosine_similarity(e1, e2).mean().item()

def plot_metrics(train_losses, val_losses, sems):
    epochs = range(1, len(train_losses)+1)
    plt.figure(figsize=(12,5))

    plt.subplot(1,2,1)
    plt.plot(epochs, train_losses, label="Train Loss")
    plt.plot(epochs, val_losses,   label="Validation Loss")
    plt.xlabel("Epoch"); plt.ylabel("Loss"); plt.legend()

    plt.subplot(1,2,2)
    plt.plot(epochs, sems, label="Semantic Similarity")
    plt.xlabel("Epoch"); plt.ylabel("Similarity"); plt.legend()

    plt.tight_layout()
    plt.show()

# =============================================================================
# MAIN (with early stopping)
# =============================================================================

if __name__ == "__main__":
    # config
    class Cfg: pass
    cfg = Cfg()
    cfg.DATASET = Cfg()
    cfg.DATASET.JSON           = 'final_samples_both_only_v2.json'
    cfg.DATASET.USE_RAW        = True
    cfg.DATASET.USE_PATCH      = True
    cfg.DATASET.REPORT         = True
    cfg.DATASET.TARGET_CLASSES = ['ra','oa','gout','normal','uncertain','ref.prev']
    cfg.DATASET.BALANCE        = False
    cfg.DATASET.AUGMENT        = False

    # tokenizer & device
    tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
    tokenizer.pad_token = tokenizer.eos_token
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print("Using device:", device)

    # prepare dataset
    dataset = FinalSamplesDataset(cfg)
    dataset.eos_token = tokenizer.eos_token

    dist = Counter(e['class_label'] for e in dataset.data.values())
    print("\nDataset class distribution:")
    for cls, cnt in dist.items():
        print(f"  {cls}: {cnt}")

    # train/val/test split
    n       = len(dataset)
    n_train = int(0.8 * n)
    n_val   = int(0.1 * n)
    n_test  = n - n_train - n_val

    train_ds, val_ds, test_ds = random_split(dataset, [n_train, n_val, n_test])
    print(f"# train={len(train_ds)}, val={len(val_ds)}, test={len(test_ds)}")

    train_loader = DataLoader(train_ds, batch_size=4, shuffle=True,  collate_fn=collate_fn)
    val_loader   = DataLoader(val_ds,   batch_size=4, shuffle=False, collate_fn=collate_fn)
    test_loader  = DataLoader(test_ds,  batch_size=4, shuffle=False, collate_fn=collate_fn)

    # model, optimizer, scheduler, scaler
    model     = MultiModalModel().to(device)
    optimizer = optim.AdamW(model.parameters(), lr=5e-5)
    scheduler = optim.lr_scheduler.CosineAnnealingWarmRestarts(optimizer, T_0=10, T_mult=2)
    scaler    = torch.cuda.amp.GradScaler()

    # early stopping params
    patience          = 3
    best_val_loss     = float('inf')
    epochs_no_improve = 0

    # training loop
    num_epochs = 10
    train_losses, val_losses, sems = [], [], []

    for epoch in range(1, num_epochs+1):
        print(f"\nEpoch {epoch}/{num_epochs}")
        train_loss = train_epoch(model, train_loader, optimizer, scaler, device)
        val_loss, gen_txt, gt_txt = evaluate(model, val_loader, device)
        sem = compute_semantic_similarity(gen_txt, gt_txt)

        train_losses.append(train_loss)
        val_losses.append(val_loss)
        sems.append(sem)

        print(f"  Train Loss          : {train_loss:.4f}")
        print(f"  Validation Loss     : {val_loss:.4f}")
        print(f"  Semantic Similarity : {sem:.4f}")

        scheduler.step()

        if val_loss < best_val_loss:
            best_val_loss     = val_loss
            epochs_no_improve = 0
            torch.save(model.state_dict(), 'best_model.pt')
        else:
            epochs_no_improve += 1
            if epochs_no_improve >= patience:
                print(f"No improvement for {patience} epochs. Early stopping.")
                break

    # load best model
    #model.load_state_dict(torch.load('best_model.pt', map_location=device))

    # plot metrics
    plot_metrics(train_losses, val_losses, sems)

    # final test eval
    test_loss, test_gen, test_gt = evaluate(model, test_loader, device)
    test_sem = compute_semantic_similarity(test_gen, test_gt)

    print("\n========== TEST RESULTS ==========")
    print(f"Test Loss          : {test_loss:.4f}")
    print(f"Test Semantic Sim  : {test_sem:.4f}")

    # random examples
    print("\n===== RANDOM TEST EXAMPLES =====")
    for idx in random.sample(range(len(test_ds)), min(10, len(test_ds))):
        ex = test_ds[idx]
        raw   = ex['raw_report']
        clean = ex['cleaned_report']

        fi = ex['full_img'].unsqueeze(0).to(device)
        pa = ex['patches'].unsqueeze(0).to(device)

        # re-encode features
        g = model.global_encoder(fi)
        g = model.global_proj(g).unsqueeze(1)
        B, N, C, H, W = pa.shape
        p = pa.view(B*N, C, H, W)
        pf = (model.patch_encoder.forward_features(p)
              if hasattr(model.patch_encoder, 'forward_features')
              else model.patch_encoder(p))
        pf = model._pool(pf)
        pf = model.patch_proj(pf).view(B, N, 768)

        cat, _ = model.attn(
            torch.cat([g, pf], dim=1),
            torch.cat([g, pf], dim=1),
            torch.cat([g, pf], dim=1)
        )
        cat = model.norm(cat)

        # pure BOS token
        bos = torch.full((1, 1), tokenizer.eos_token_id, dtype=torch.long, device=device)
        bos_mask = torch.ones_like(bos)

        gen_ids = model.decoder.generate(
            input_ids=bos,
            attention_mask=bos_mask,
            encoder_hidden_states=cat,
            max_length=120,
            do_sample=True,
            top_k=40,
            top_p=0.95,
            temperature=0.5,
            repetition_penalty=1.3,
            eos_token_id=tokenizer.eos_token_id,
            pad_token_id=tokenizer.eos_token_id
        )
        gen = tokenizer.decode(gen_ids[0], skip_special_tokens=True)

        print(f"\n--- Example {idx} ---")
        print(f"Raw Report       :\n{raw}")
        print(f"Cleaned Report   :\n{clean}")
        print(f"Generated Report :\n{gen}")
# Out:
# 2025-05-08 15:26:08.104283: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-05-08 15:26:08.111099: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746743168.118781   44858 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746743168.121116   44858 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1746743168.127115   44858 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1746743168.127121   44858 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1746743168.127123   44858 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1746743168.127123   44858 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-05-08 15:26:08.129467: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Using device: cuda
#
# Dataset class distribution:
#   oa: 573
#   ra: 115
#   uncertain: 620
#   oa, ra: 8
#   normal: 748
#   gout: 267
#   combination of oa, ra: 3
#   ref.prev: 60
# # train=1915, val=239, test=240
# INFO:timm.models._builder:Loading pretrained weights from Hugging Face hub (timm/swin_base_patch4_window7_224.ms_in22k_ft_in1k)
# INFO:timm.models._hub:[timm/swin_base_patch4_window7_224.ms_in22k_ft_in1k] Safe alternative available for 'pytorch_model.bin' (as 'model.safetensors'). Loading weights using safetensors.
# INFO:timm.models._builder:Loading pretrained weights from Hugging Face hub (timm/resnet50.a1_in1k)
# INFO:timm.models._hub:[timm/resnet50.a1_in1k] Safe alternative available for 'pytorch_model.bin' (as 'model.safetensors'). Loading weights using safetensors.
# Some weights of GPT2LMHeadModel were not initialized from the model checkpoint at gpt2 and are newly initialized: ['h.0.crossattention.c_attn.bias', 'h.0.crossattention.c_attn.weight', 'h.0.crossattention.c_proj.bias', 'h.0.crossattention.c_proj.weight', 'h.0.crossattention.q_attn.bias', 'h.0.crossattention.q_attn.weight', 'h.0.ln_cross_attn.bias', 'h.0.ln_cross_attn.weight', 'h.1.crossattention.c_attn.bias', 'h.1.crossattention.c_attn.weight', 'h.1.crossattention.c_proj.bias', 'h.1.crossattention.c_proj.weight', 'h.1.crossattention.q_attn.bias', 'h.1.crossattention.q_attn.weight', 'h.1.ln_cross_attn.bias', 'h.1.ln_cross_attn.weight', 'h.10.crossattention.c_attn.bias', 'h.10.crossattention.c_attn.weight', 'h.10.crossattention.c_proj.bias', 'h.10.crossattention.c_proj.weight', 'h.10.crossattention.q_attn.bias', 'h.10.crossattention.q_attn.weight', 'h.10.ln_cross_attn.bias', 'h.10.ln_cross_attn.weight', 'h.11.crossattention.c_attn.bias', 'h.11.crossattention.c_attn.weight', 'h.11.crossattention.c_proj.bias', 'h.11.crossattention.c_proj.weight', 'h.11.crossattention.q_attn.bias', 'h.11.crossattention.q_attn.weight', 'h.11.ln_cross_attn.bias', 'h.11.ln_cross_attn.weight', 'h.2.crossattention.c_attn.bias', 'h.2.crossattention.c_attn.weight', 'h.2.crossattention.c_proj.bias', 'h.2.crossattention.c_proj.weight', 'h.2.crossattention.q_attn.bias', 'h.2.crossattention.q_attn.weight', 'h.2.ln_cross_attn.bias', 'h.2.ln_cross_attn.weight', 'h.3.crossattention.c_attn.bias', 'h.3.crossattention.c_attn.weight', 'h.3.crossattention.c_proj.bias', 'h.3.crossattention.c_proj.weight', 'h.3.crossattention.q_attn.bias', 'h.3.crossattention.q_attn.weight', 'h.3.ln_cross_attn.bias', 'h.3.ln_cross_attn.weight', 'h.4.crossattention.c_attn.bias', 'h.4.crossattention.c_attn.weight', 'h.4.crossattention.c_proj.bias', 'h.4.crossattention.c_proj.weight', 'h.4.crossattention.q_attn.bias', 'h.4.crossattention.q_attn.weight', 'h.4.ln_cross_attn.bias', 'h.4.ln_cross_attn.weight', 'h.5.crossattention.c_attn.bias', 'h.5.crossattention.c_attn.weight', 'h.5.crossattention.c_proj.bias', 'h.5.crossattention.c_proj.weight', 'h.5.crossattention.q_attn.bias', 'h.5.crossattention.q_attn.weight', 'h.5.ln_cross_attn.bias', 'h.5.ln_cross_attn.weight', 'h.6.crossattention.c_attn.bias', 'h.6.crossattention.c_attn.weight', 'h.6.crossattention.c_proj.bias', 'h.6.crossattention.c_proj.weight', 'h.6.crossattention.q_attn.bias', 'h.6.crossattention.q_attn.weight', 'h.6.ln_cross_attn.bias', 'h.6.ln_cross_attn.weight', 'h.7.crossattention.c_attn.bias', 'h.7.crossattention.c_attn.weight', 'h.7.crossattention.c_proj.bias', 'h.7.crossattention.c_proj.weight', 'h.7.crossattention.q_attn.bias', 'h.7.crossattention.q_attn.weight', 'h.7.ln_cross_attn.bias', 'h.7.ln_cross_attn.weight', 'h.8.crossattention.c_attn.bias', 'h.8.crossattention.c_attn.weight', 'h.8.crossattention.c_proj.bias', 'h.8.crossattention.c_proj.weight', 'h.8.crossattention.q_attn.bias', 'h.8.crossattention.q_attn.weight', 'h.8.ln_cross_attn.bias', 'h.8.ln_cross_attn.weight', 'h.9.crossattention.c_attn.bias', 'h.9.crossattention.c_attn.weight', 'h.9.crossattention.c_proj.bias', 'h.9.crossattention.c_proj.weight', 'h.9.crossattention.q_attn.bias', 'h.9.crossattention.q_attn.weight', 'h.9.ln_cross_attn.bias', 'h.9.ln_cross_attn.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /tmp/ipykernel_44858/1821338189.py:495: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler    = torch.cuda.amp.GradScaler()
# Epoch 1/10
# Training:   0%|          | 0/479 [00:00<?, ?it/s]/tmp/ipykernel_44858/1821338189.py:354: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# Evaluating:   0%|          | 0/60 [00:00<?, ?it/s]         A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:   2%|▏         | 1/60 [00:00<00:35,  1.66it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:   3%|▎         | 2/60 [00:01<00:33,  1.73it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:   5%|▌         | 3/60 [00:01<00:32,  1.75it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:   7%|▋         | 4/60 [00:02<00:31,  1.75it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:   8%|▊         | 5/60 [00:02<00:32,  1.70it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  10%|█         | 6/60 [00:03<00:31,  1.72it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  12%|█▏        | 7/60 [00:04<00:30,  1.75it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  13%|█▎        | 8/60 [00:04<00:29,  1.78it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  15%|█▌        | 9/60 [00:05<00:29,  1.75it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  17%|█▋        | 10/60 [00:05<00:28,  1.77it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  18%|█▊        | 11/60 [00:06<00:27,  1.78it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  20%|██        | 12/60 [00:06<00:27,  1.77it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  22%|██▏       | 13/60 [00:07<00:27,  1.73it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  23%|██▎       | 14/60 [00:08<00:26,  1.75it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  25%|██▌       | 15/60 [00:08<00:25,  1.76it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  27%|██▋       | 16/60 [00:09<00:24,  1.78it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  28%|██▊       | 17/60 [00:09<00:24,  1.77it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  30%|███       | 18/60 [00:10<00:23,  1.76it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  32%|███▏      | 19/60 [00:10<00:23,  1.76it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  33%|███▎      | 20/60 [00:11<00:22,  1.79it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  35%|███▌      | 21/60 [00:11<00:22,  1.75it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  37%|███▋      | 22/60 [00:12<00:21,  1.75it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  38%|███▊      | 23/60 [00:13<00:20,  1.79it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  40%|████      | 24/60 [00:13<00:19,  1.80it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  42%|████▏     | 25/60 [00:14<00:19,  1.79it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  43%|████▎     | 26/60 [00:14<00:18,  1.80it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  45%|████▌     | 27/60 [00:15<00:18,  1.81it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  47%|████▋     | 28/60 [00:15<00:17,  1.79it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  48%|████▊     | 29/60 [00:16<00:17,  1.79it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  50%|█████     | 30/60 [00:16<00:16,  1.78it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  52%|█████▏    | 31/60 [00:17<00:16,  1.78it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  53%|█████▎    | 32/60 [00:18<00:15,  1.79it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  55%|█████▌    | 33/60 [00:18<00:15,  1.80it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  57%|█████▋    | 34/60 [00:19<00:14,  1.77it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  58%|█████▊    | 35/60 [00:19<00:13,  1.79it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  60%|██████    | 36/60 [00:20<00:13,  1.81it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  62%|██████▏   | 37/60 [00:20<00:12,  1.79it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  63%|██████▎   | 38/60 [00:21<00:12,  1.80it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  65%|██████▌   | 39/60 [00:21<00:11,  1.81it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  67%|██████▋   | 40/60 [00:22<00:11,  1.80it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  68%|██████▊   | 41/60 [00:23<00:10,  1.74it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  70%|███████   | 42/60 [00:23<00:10,  1.77it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  72%|███████▏  | 43/60 [00:24<00:09,  1.79it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  73%|███████▎  | 44/60 [00:24<00:08,  1.81it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  75%|███████▌  | 45/60 [00:25<00:08,  1.78it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  77%|███████▋  | 46/60 [00:25<00:07,  1.80it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  78%|███████▊  | 47/60 [00:26<00:07,  1.77it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  80%|████████  | 48/60 [00:27<00:06,  1.74it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  82%|████████▏ | 49/60 [00:27<00:06,  1.77it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  83%|████████▎ | 50/60 [00:28<00:05,  1.78it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  85%|████████▌ | 51/60 [00:28<00:05,  1.80it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  87%|████████▋ | 52/60 [00:29<00:04,  1.80it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  88%|████████▊ | 53/60 [00:29<00:03,  1.80it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  90%|█████████ | 54/60 [00:30<00:03,  1.81it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  92%|█████████▏| 55/60 [00:30<00:02,  1.80it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  93%|█████████▎| 56/60 [00:31<00:02,  1.80it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  95%|█████████▌| 57/60 [00:32<00:01,  1.79it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  97%|█████████▋| 58/60 [00:32<00:01,  1.82it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  98%|█████████▊| 59/60 [00:33<00:00,  1.80it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# INFO:sentence_transformers.SentenceTransformer:Use pytorch device_name: cuda
# INFO:sentence_transformers.SentenceTransformer:Load pretrained SentenceTransformer: all-MiniLM-L6-v2
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
#   Train Loss          : 1.2759
#   Validation Loss     : 0.8584
#   Semantic Similarity : 0.4253
#
# Epoch 2/10
# Evaluating:   0%|          | 0/60 [00:00<?, ?it/s]         A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:   2%|▏         | 1/60 [00:00<00:32,  1.81it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:   3%|▎         | 2/60 [00:01<00:31,  1.85it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:   5%|▌         | 3/60 [00:01<00:31,  1.82it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:   7%|▋         | 4/60 [00:01<00:25,  2.18it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:   8%|▊         | 5/60 [00:02<00:27,  1.98it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  10%|█         | 6/60 [00:03<00:28,  1.91it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  12%|█▏        | 7/60 [00:03<00:28,  1.88it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  13%|█▎        | 8/60 [00:04<00:27,  1.87it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  15%|█▌        | 9/60 [00:04<00:28,  1.82it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  17%|█▋        | 10/60 [00:05<00:22,  2.18it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  18%|█▊        | 11/60 [00:05<00:23,  2.05it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  20%|██        | 12/60 [00:06<00:24,  1.95it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  22%|██▏       | 13/60 [00:06<00:25,  1.88it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  23%|██▎       | 14/60 [00:06<00:20,  2.22it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  25%|██▌       | 15/60 [00:07<00:21,  2.08it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  27%|██▋       | 16/60 [00:07<00:18,  2.41it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  28%|██▊       | 17/60 [00:08<00:16,  2.61it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  30%|███       | 18/60 [00:08<00:14,  2.83it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  32%|███▏      | 19/60 [00:08<00:17,  2.40it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  33%|███▎      | 20/60 [00:09<00:18,  2.20it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  35%|███▌      | 21/60 [00:10<00:19,  2.02it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  37%|███▋      | 22/60 [00:10<00:16,  2.32it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  38%|███▊      | 23/60 [00:10<00:17,  2.17it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  40%|████      | 24/60 [00:11<00:14,  2.50it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  42%|████▏     | 25/60 [00:11<00:15,  2.23it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  43%|████▎     | 26/60 [00:12<00:16,  2.09it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  45%|████▌     | 27/60 [00:12<00:16,  2.01it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  47%|████▋     | 28/60 [00:13<00:16,  1.93it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  48%|████▊     | 29/60 [00:13<00:13,  2.26it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  50%|█████     | 30/60 [00:14<00:14,  2.10it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  52%|█████▏    | 31/60 [00:14<00:12,  2.42it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  53%|█████▎    | 32/60 [00:15<00:12,  2.19it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  55%|█████▌    | 33/60 [00:15<00:13,  2.07it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  57%|█████▋    | 34/60 [00:16<00:13,  1.97it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  58%|█████▊    | 35/60 [00:16<00:13,  1.92it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  60%|██████    | 36/60 [00:17<00:12,  1.90it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  62%|██████▏   | 37/60 [00:17<00:12,  1.86it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  63%|██████▎   | 38/60 [00:18<00:11,  1.84it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  65%|██████▌   | 39/60 [00:18<00:11,  1.81it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  67%|██████▋   | 40/60 [00:19<00:11,  1.77it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  68%|██████▊   | 41/60 [00:20<00:11,  1.71it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  70%|███████   | 42/60 [00:20<00:10,  1.73it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  72%|███████▏  | 43/60 [00:21<00:09,  1.76it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  73%|███████▎  | 44/60 [00:21<00:09,  1.77it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  75%|███████▌  | 45/60 [00:22<00:08,  1.74it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  77%|███████▋  | 46/60 [00:22<00:07,  1.78it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  78%|███████▊  | 47/60 [00:23<00:06,  2.07it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  80%|████████  | 48/60 [00:23<00:06,  1.94it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  82%|████████▏ | 49/60 [00:24<00:04,  2.27it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  83%|████████▎ | 50/60 [00:24<00:04,  2.12it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  85%|████████▌ | 51/60 [00:25<00:04,  2.02it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  87%|████████▋ | 52/60 [00:25<00:03,  2.36it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  88%|████████▊ | 53/60 [00:26<00:03,  2.16it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  90%|█████████ | 54/60 [00:26<00:02,  2.45it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  92%|█████████▏| 55/60 [00:26<00:02,  2.19it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  93%|█████████▎| 56/60 [00:27<00:01,  2.06it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  95%|█████████▌| 57/60 [00:27<00:01,  1.97it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  97%|█████████▋| 58/60 [00:28<00:01,  1.94it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  98%|█████████▊| 59/60 [00:29<00:00,  1.89it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# INFO:sentence_transformers.SentenceTransformer:Use pytorch device_name: cuda
# INFO:sentence_transformers.SentenceTransformer:Load pretrained SentenceTransformer: all-MiniLM-L6-v2
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
#   Train Loss          : 0.8033
#   Validation Loss     : 0.7697
#   Semantic Similarity : 0.3242
#
# Epoch 3/10
# Evaluating:   0%|          | 0/60 [00:00<?, ?it/s]         A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:   2%|▏         | 1/60 [00:00<00:14,  3.99it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:   3%|▎         | 2/60 [00:00<00:15,  3.85it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:   5%|▌         | 3/60 [00:00<00:15,  3.75it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:   7%|▋         | 4/60 [00:01<00:14,  3.76it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:   8%|▊         | 5/60 [00:01<00:15,  3.56it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  10%|█         | 6/60 [00:01<00:15,  3.53it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  12%|█▏        | 7/60 [00:01<00:14,  3.67it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  13%|█▎        | 8/60 [00:02<00:13,  3.94it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  15%|█▌        | 9/60 [00:02<00:13,  3.75it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  17%|█▋        | 10/60 [00:02<00:13,  3.77it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  18%|█▊        | 11/60 [00:02<00:12,  3.78it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  20%|██        | 12/60 [00:03<00:12,  3.85it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  22%|██▏       | 13/60 [00:03<00:13,  3.57it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  23%|██▎       | 14/60 [00:03<00:12,  3.67it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  25%|██▌       | 15/60 [00:04<00:12,  3.71it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  27%|██▋       | 16/60 [00:04<00:12,  3.63it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  28%|██▊       | 17/60 [00:04<00:12,  3.56it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  30%|███       | 18/60 [00:04<00:11,  3.59it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  32%|███▏      | 19/60 [00:05<00:11,  3.59it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  33%|███▎      | 20/60 [00:05<00:10,  3.66it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  35%|███▌      | 21/60 [00:05<00:11,  3.54it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  37%|███▋      | 22/60 [00:05<00:10,  3.71it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  38%|███▊      | 23/60 [00:06<00:09,  3.79it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  40%|████      | 24/60 [00:06<00:09,  3.80it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  42%|████▏     | 25/60 [00:06<00:09,  3.73it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  43%|████▎     | 26/60 [00:07<00:08,  3.79it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  45%|████▌     | 27/60 [00:07<00:08,  3.89it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  47%|████▋     | 28/60 [00:07<00:08,  3.82it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  48%|████▊     | 29/60 [00:07<00:08,  3.83it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  50%|█████     | 30/60 [00:08<00:07,  3.89it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  52%|█████▏    | 31/60 [00:08<00:07,  3.87it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  53%|█████▎    | 32/60 [00:08<00:07,  3.78it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  55%|█████▌    | 33/60 [00:08<00:07,  3.78it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  57%|█████▋    | 34/60 [00:09<00:06,  3.74it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  58%|█████▊    | 35/60 [00:09<00:06,  3.78it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  60%|██████    | 36/60 [00:09<00:06,  3.89it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  62%|██████▏   | 37/60 [00:09<00:06,  3.76it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  63%|██████▎   | 38/60 [00:10<00:05,  3.81it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  65%|██████▌   | 39/60 [00:10<00:05,  3.82it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  67%|██████▋   | 40/60 [00:10<00:05,  3.68it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  68%|██████▊   | 41/60 [00:11<00:05,  3.51it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  70%|███████   | 42/60 [00:11<00:04,  3.70it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  72%|███████▏  | 43/60 [00:11<00:04,  3.72it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  73%|███████▎  | 44/60 [00:11<00:04,  3.80it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  75%|███████▌  | 45/60 [00:12<00:04,  3.65it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  77%|███████▋  | 46/60 [00:12<00:03,  3.79it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  78%|███████▊  | 47/60 [00:12<00:03,  3.63it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  80%|████████  | 48/60 [00:12<00:03,  3.52it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  82%|████████▏ | 49/60 [00:13<00:03,  3.59it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  83%|████████▎ | 50/60 [00:13<00:02,  3.66it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  85%|████████▌ | 51/60 [00:13<00:02,  3.75it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  87%|████████▋ | 52/60 [00:13<00:02,  3.78it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  88%|████████▊ | 53/60 [00:14<00:01,  3.78it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  90%|█████████ | 54/60 [00:14<00:01,  3.84it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# ...
# Evaluating:  37%|███▋      | 22/60 [00:09<00:18,  2.07it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  38%|███▊      | 23/60 [00:09<00:15,  2.35it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  40%|████      | 24/60 [00:10<00:13,  2.63it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  42%|████▏     | 25/60 [00:10<00:12,  2.88it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  43%|████▎     | 26/60 [00:10<00:11,  3.08it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  45%|████▌     | 27/60 [00:10<00:10,  3.09it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  47%|████▋     | 28/60 [00:11<00:10,  3.18it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  48%|████▊     | 29/60 [00:11<00:10,  3.05it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  50%|█████     | 30/60 [00:11<00:09,  3.25it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  52%|█████▏    | 31/60 [00:12<00:09,  3.15it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  53%|█████▎    | 32/60 [00:12<00:09,  3.09it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  55%|█████▌    | 33/60 [00:13<00:10,  2.51it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  57%|█████▋    | 34/60 [00:13<00:09,  2.69it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  58%|█████▊    | 35/60 [00:13<00:08,  2.98it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  60%|██████    | 36/60 [00:14<00:09,  2.47it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  62%|██████▏   | 37/60 [00:14<00:08,  2.66it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  63%|██████▎   | 38/60 [00:15<00:09,  2.27it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  65%|██████▌   | 39/60 [00:15<00:09,  2.14it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  67%|██████▋   | 40/60 [00:15<00:08,  2.46it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  68%|██████▊   | 41/60 [00:16<00:07,  2.52it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  70%|███████   | 42/60 [00:16<00:06,  2.69it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  72%|███████▏  | 43/60 [00:17<00:07,  2.33it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  73%|███████▎  | 44/60 [00:17<00:07,  2.12it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  75%|███████▌  | 45/60 [00:18<00:06,  2.38it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  77%|███████▋  | 46/60 [00:18<00:06,  2.17it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  78%|███████▊  | 47/60 [00:18<00:05,  2.50it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  80%|████████  | 48/60 [00:19<00:04,  2.77it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  82%|████████▏ | 49/60 [00:19<00:04,  2.39it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  83%|████████▎ | 50/60 [00:19<00:03,  2.67it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  85%|████████▌ | 51/60 [00:20<00:03,  2.96it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  87%|████████▋ | 52/60 [00:20<00:02,  3.09it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  88%|████████▊ | 53/60 [00:20<00:02,  3.26it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  90%|█████████ | 54/60 [00:21<00:01,  3.13it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  92%|█████████▏| 55/60 [00:21<00:01,  3.15it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  93%|█████████▎| 56/60 [00:21<00:01,  2.98it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  95%|█████████▌| 57/60 [00:22<00:00,  3.10it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  97%|█████████▋| 58/60 [00:22<00:00,  2.55it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  98%|█████████▊| 59/60 [00:22<00:00,  2.65it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# INFO:sentence_transformers.SentenceTransformer:Use pytorch device_name: cuda
# INFO:sentence_transformers.SentenceTransformer:Load pretrained SentenceTransformer: all-MiniLM-L6-v2
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# ========== TEST RESULTS ==========
# Test Loss          : 0.7623
# Test Semantic Sim  : 0.2574
#
# ===== RANDOM TEST EXAMPLES =====
#
# --- Example 93 ---
# Raw Report       :
# [ Finding ]_x000D_
# interval progression of erosions._x000D_
# [ Diagnosis ]_x000D_
# interval progression of erosions._x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# interval progression of erosions. interval progression of erosions. <|endoftext|>
# Generated Report :
# visible crystal deposition in Rt. 1st MTP joint
#
# --- Example 60 ---
# Raw Report       :
# [FINDING       ]_x000D_no significant interval change since last study._x000D__x000D_[CONCLUSION    ]_x000D_no significant interval change since last study._x000D__x000D_[RECOMMENDATION]_x000D_-
# Cleaned Report   :
# no significant interval change since last study. <|endoftext|>
# Generated Report :
# thesophyte in plantar aspect of left calcaneus. ____________________ R/O gout, both feet and ankles degenerative change with increased opacity --> RA involvement or old fracture cannot be excluded since osteopenia mild joint space narrowing at L4th MTP joints -> rheumatoid arthritis rather than inflammatory reaction hallux valgare type III Lt fibular tip soft tissue swelling diffuse vascular insufficiency subluxation sclerotic lesion - multiple sites including TMT head suspicious erosion vs bone fragment deposition around 1st metatarsal shafts ==> possible accessory
#
# --- Example 50 ---
# Raw Report       :
# [ Finding ]_x000D_
# _x000D_
# [ Diagnosis ]_x000D_
# No significant interval change since last study._x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# No significant interval change since last study. <|endoftext|>
# Generated Report :
# visible crystal deposition in the Rt. 1st MTP joint area of both calcaneus and interphalangeal joints
#
# --- Example 122 ---
# Raw Report       :
# [ Finding ]_x000D_
# _x000D_
# [ Diagnosis ]_x000D_
# Hallux valgus, left foot._x000D_
# Possible large bone erosion with overhanging edge in medial aspect of left 1st metatarsal head._x000D_
#  --- possible gouty arthritis._x000D_
#  --- Rec) Clinical correlation._x000D_
# Suspicious fracture with partial callus formation of right lateral malleolus._x000D_
# --- with soft tissue swelling._x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# Hallux valgus, left foot. Possible large bone erosion with overhanging edge in medial aspect of left 1st metatarsal head. --- possible gouty arthritis. --- Rec) Clinical correlation. Suspicious fracture with partial callus formation of right lateral malleolus. --- with soft tissue swelling. <|endoftext|>
# Generated Report :
# steophyte of both calcaneus. ____________________ Rec) clinical correlation, suggested Rt. 1st MTP joint soft tissue swelling and mild degenerative change --> gout involvement (mainly left lateral malleolar area). Both accessory navicular bone type II with OA Lt. ankle osteopenia esp> foot fracture or old compression injury vs. erosion rather than periarticular insufficiency bony protrusion in medial aspect of right talonavicle level head --- possible tophaceous glands around the posterior portion os trigonum side view Hallux valg
#
# --- Example 121 ---
# Raw Report       :
# [ Finding ]_x000D_
# Rt. 1st IP joint flexion deformity._x000D_
# Lt. 1st MTP joint OA_x000D_
# Rt. 5th MTP and both 5th IP joint, erosion._x000D_
# degenerative change, both kness._x000D_
# Rt. 2nd and Lt. 5th MCP joint, and both both wrist R/O gout._x000D_
#  _x000D_
# Lt. ankle, joint destruction_x000D_
#      --> R/O Charcot joint._x000D_
# [ Conclusion ]_x000D_
# Rt. 1st IP joint flexion deformity._x000D_
# Lt. 1st MTP joint OA_x000D_
# Rt. 5th MTP and both 5th IP joint, erosion._x000D_
# degenerative change, both kness._x000D_
# Rt. 2nd and Lt. 5th MCP joint, and both both wrist R/O gout._x000D_
#  _x000D_
# Lt. ankle, joint destruction_x000D_
#      --> R/O Charcot joint._x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# Rt. 1st IP joint flexion deformity. Lt. 1st MTP joint OA Rt. 5th MTP and both 5th IP joint, erosion. degenerative change, both kness. Rt. 2nd and Lt. 5th MCP joint, and both both wrist R/O gout. Lt. ankle, joint destruction --> R/O Charcot joint. <|endoftext|>
# Generated Report :
# out.
#
# --- Example 144 ---
# Raw Report       :
# [FINDING       ]_x000D_degenerative change_x000D__x000D_[CONCLUSION    ]_x000D_degenerative change_x000D__x000D_[RECOMMENDATION]_x000D_-
# Cleaned Report   :
# degenerative change <|endoftext|>
# Generated Report :
# tibia, talus
#
# --- Example 116 ---
# Raw Report       :
# [FINDING       ]_x000D_both hands, DIP joints, OA, rather than psoriatic arthritis.
#
# Rt. 1st MCP joint subluxation.
#
# flat foot, both._x000D__x000D_[CONCLUSION    ]_x000D_both hands, DIP joints, OA, rather than psoriatic arthritis.
#
# Rt. 1st MCP joint subluxation.
#
# flat foot, both._x000D__x000D_[RECOMMENDATION]_x000D_-
# Cleaned Report   :
# both hands, DIP joints, OA, rather than psoriatic arthritis. Rt. 1st MCP joint subluxation. flat foot, both. <|endoftext|>
# Generated Report :
# steopenia. degenerative change
#
# --- Example 9 ---
# Raw Report       :
# [ Finding ]_x000D_
# _x000D_
# [ Conclusion ]_x000D_
# Degenerative changes._x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# Degenerative changes. <|endoftext|>
# Generated Report :
# tux valgus, both. ____________________ 2018-10>2018 R/O gout rec) clinical correlation no significant bony lesion on radiographs or CT scans of rheumatoid arthritis joints and sclerotic joint effusion Lt fibular tip soft tissue swelling vs old fracture with bone fragment in dorsal aspect -> RA involvement mild degenerative change esp > suggested - interval progressed erosive changes --> consider Fx ulnocarpal coalition rather than periarticular osteopenia halluar neck OA == possible inflammatory reaction tophi (Rafnar
#
# --- Example 54 ---
# Raw Report       :
# [ Finding ]_x000D_
# both 1st toe and 5th toe, gout arthritis._x000D_
# _x000D_
# Rt. distal tibiofibular joint, gout involvement._x000D_
# both ankle, gout involvement._x000D_
# _x000D_
# Lt. knee, gout._x000D_
# _x000D_
# both wrist and hands gout._x000D_
# _x000D_
# [ Conclusion ]_x000D_
# both 1st toe and 5th toe, gout arthritis._x000D_
# _x000D_
# Rt. distal tibiofibular joint, gout involvement._x000D_
# both ankle, gout involvement._x000D_
# _x000D_
# Lt. knee, gout._x000D_
# _x000D_
# both wrist and hands gout._x000D_
# _x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# both 1st toe and 5th toe, gout arthritis. Rt. distal tibiofibular joint, gout involvement. both ankle, gout involvement. Lt. knee, gout. both wrist and hands gout. <|endoftext|>
# Generated Report :
# tibia, both. degenerative change
#
# --- Example 127 ---
# Raw Report       :
# [ Finding ]_x000D_
# _x000D_
# [ Diagnosis ]_x000D_
# Both hallux valgus._x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# Both hallux valgus. <|endoftext|>
# Generated Report :
# out.

# %%
import os
import re
import json
import logging
import unicodedata
import random
from collections import defaultdict, Counter

import numpy as np
import cv2
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, random_split
from PIL import Image
from torchvision import transforms
from tqdm import tqdm
import timm
from transformers import GPT2Tokenizer, GPT2LMHeadModel
from sentence_transformers import SentenceTransformer
import matplotlib.pyplot as plt

logging.basicConfig(level=logging.INFO)

# =============================================================================
# Utility functions
# =============================================================================

def count_labels(data, target_classes, cfg):
    class_counts = defaultdict(int)
    data_by_class = defaultdict(list)
    for entry in tqdm(data.values(), desc="Counting dataset"):
        lbl = entry.get('class_label', '').lower()
        if lbl in target_classes and os.path.exists(entry['file_path']):
            class_counts[lbl] += 1
            data_by_class[lbl].append(entry)
    return class_counts, data_by_class

def prepare_abnormal_normal_data(data, cfg):
    random.seed(42)
    abnormal = ['ra', 'oa', 'gout']
    normal = ['normal']
    class_counts, data_by_class = count_labels(data, abnormal + normal, cfg)
    combined = {
        'abnormal': sum((data_by_class[c] for c in abnormal), []),
        'normal': data_by_class['normal']
    }
    combined_counts = {
        'abnormal': sum(class_counts[c] for c in abnormal),
        'normal': class_counts['normal']
    }
    if not cfg.DATASET.BALANCE and not cfg.DATASET.AUGMENT:
        return sum(combined.values(), []), combined_counts, combined_counts
    min_count = min(combined_counts.values())
    balanced = []
    final_counts = {}
    for lbl, items in combined.items():
        sampled = random.sample(items, min_count)
        balanced.extend(sampled)
        final_counts[lbl] = min_count
    if cfg.DATASET.AUGMENT:
        balanced *= 2
    return balanced, combined_counts, final_counts

def prepare_data(data, target_classes, cfg, is_binary=False):
    random.seed(42)
    if len(target_classes) == 2 and 'abnormal' in target_classes and 'normal' in target_classes:
        logging.info("Using abnormal-vs-normal logic")
        return prepare_abnormal_normal_data(data, cfg)
    class_counts, data_by_class = count_labels(data, target_classes, cfg)
    logging.info(f"Original class distribution: {class_counts}")
    if not cfg.DATASET.BALANCE and not cfg.DATASET.AUGMENT:
        return sum(data_by_class.values(), []), class_counts, class_counts
    min_count = min(class_counts.values())
    balanced, final_counts = [], {}
    for lbl in target_classes:
        sampled = random.sample(data_by_class[lbl], min_count)
        balanced.extend(sampled)
        final_counts[lbl] = min_count
    logging.info(f"Balanced class distribution: {final_counts}")
    if cfg.DATASET.AUGMENT:
        balanced *= 2
    return balanced, class_counts, final_counts

# =============================================================================
# Transforms
# =============================================================================

imagenet_mean = [0.485, 0.456, 0.406]
imagenet_std = [0.229, 0.224, 0.225]

train_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(imagenet_mean, imagenet_std)
])

patch_transform = transforms.Compose([
    transforms.Resize((112, 112)),
    transforms.ToTensor(),
    transforms.Normalize(imagenet_mean, imagenet_std)
])

# =============================================================================
# Dataset
# =============================================================================

class FinalSamplesDataset(Dataset):
    def __init__(self, cfg, image_transform=train_transform, patch_transform=patch_transform):
        self.cfg = cfg
        self.image_transform = image_transform
        self.patch_transform = patch_transform

        self.target_classes = cfg.DATASET.TARGET_CLASSES
        if isinstance(self.target_classes, str):
            self.target_classes = self.target_classes.split(",")

        self.is_binary = len(self.target_classes) == 2
        self.abnormal_classify = self.is_binary and 'abnormal' in self.target_classes
        self.abnormal_mapping = (
            {'ra': 'abnormal', 'oa': 'abnormal', 'gout': 'abnormal', 'normal': 'normal'}
            if self.abnormal_classify else None
        )

        with open(cfg.DATASET.JSON, 'r') as f:
            raw_list = json.load(f)

        filtered = []
        for item in raw_list:
            merged = item.get('merged_image_path', '')
            fp = item.get('file_paths', [])
            if isinstance(fp, str):
                fp = [fp]
            paths = [merged] + fp
            if any(os.path.exists(p) for p in paths):
                filtered.append((merged, fp, item))

        self.data = {}
        for i, (merged, fp, item) in enumerate(filtered):
            cls = item.get('class', 'unknown').lower()
            if self.abnormal_mapping:
                cls = self.abnormal_mapping.get(cls, cls)
            self.data[i] = {
                'file_path': merged,
                'left_right_file_path': fp,
                'class_label': cls,
                'diagnosis': item.get('diagnosis', ''),
                'keypoints': item.get('keypoints', {})
            }

        if self.is_binary:
            balanced, _, _ = prepare_data(self.data, self.target_classes, cfg, True)
            self.data = {i: e for i, e in enumerate(balanced)}

        self.eos_token = None

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        e = self.data[idx]
        img = Image.open(e['file_path']).convert('RGB')
        img = self.image_transform(img)

        patches = self._gen_patches(e['left_right_file_path'], e['keypoints'])
        pt = [self.patch_transform(Image.fromarray(p)) for p in patches]
        patches_tensor = torch.stack(pt, 0) if pt else torch.zeros(34, 3, 112, 112)

        raw = e.get('diagnosis', '')
        clean = self._clean_report(raw)
        tok = tokenizer(clean, truncation=True, max_length=512, return_tensors='pt')

        return {
            'full_img': img,
            'patches': patches_tensor,
            'raw_report': raw,
            'cleaned_report': clean,
            'input_ids': tok['input_ids'].squeeze(0),
            'attention_mask': tok['attention_mask'].squeeze(0)
        }

    def _gen_patches(self, paths, kps_dict, crop_size=(200, 300), patch_size=(112, 112)):
        def extract(arr, side_kps):
            lst = []
            pts = side_kps[0]['keypoints']
            for i in range(17):
                x, y, s = int(pts[3*i]), int(pts[3*i+1]), pts[3*i+2]
                if s > 0:
                    x0 = max(x - crop_size[0]//2, 0)
                    y0 = max(y - crop_size[1]//2, 0)
                    x1 = min(x + crop_size[0]//2, arr.shape[1])
                    y1 = min(y + crop_size[1]//2, arr.shape[0])
                    c = arr[y0:y1, x0:x1]
                    if c.size:
                        lst.append(cv2.resize(c, patch_size))
            return lst

        def pad17(lst):
            black = np.zeros((patch_size[1], patch_size[0], 3), np.uint8)
            while len(lst) < 17:
                lst.append(black)
            return lst[:17]

        left, right = [], []
        if len(paths) == 1:
            pth = paths[0]
            if not pth or not os.path.exists(pth):
                return pad17([]) + pad17([])
            img_arr = cv2.imread(pth)
            if img_arr is None:
                return pad17([]) + pad17([])
            arr = cv2.cvtColor(img_arr, cv2.COLOR_BGR2RGB)
            if kps_dict.get('left'): left = extract(arr, kps_dict['left'])
            if kps_dict.get('right'): right = extract(arr, kps_dict['right'])
        else:
            for side, pth in zip(['left', 'right'], paths):
                if pth and os.path.exists(pth):
                    img_arr = cv2.imread(pth)
                    if img_arr is not None:
                        arr = cv2.cvtColor(img_arr, cv2.COLOR_BGR2RGB)
                        if kps_dict.get(side):
                            lst = extract(arr, kps_dict[side])
                            if side == 'left': left = lst
                            else: right = lst

        if left and not right:
            right = [cv2.flip(p, 1) for p in left]
        if right and not left:
            left = [cv2.flip(p, 1) for p in right]
        if not left and not right:
            return pad17([]) + pad17([])

        return pad17(left) + pad17(right)

    def _clean_report(self, text):
        text = unicodedata.normalize('NFKC', text or '')
        text = re.sub(r'(?m)^-+\s*$', '', text)
        text = re.sub(r'[^\x00-\x7F]+', ' ', text)
        text = re.sub(r'([.!?]){2,}', r'\1', text)
        text = re.sub(r'\[\s*finding\s*\]', '[FINDING]', text, flags=re.IGNORECASE)
        text = re.sub(r'\[\s*conclusion\s*\]', '[CONCLUSION]', text, flags=re.IGNORECASE)
        text = re.sub(r'\[\s*diagnosis\s*\]', '[DIAGNOSIS]', text, flags=re.IGNORECASE)
        parts = re.split(r'\[\s*recommend(?:ation)?\s*\]', text, flags=re.IGNORECASE)
        text = parts[0]
        fm = re.search(r'\[FINDING\](.*?)(?=\[|$)', text, flags=re.IGNORECASE | re.DOTALL)
        cm = re.search(r'\[CONCLUSION\](.*?)(?=\[|$)', text, flags=re.IGNORECASE | re.DOTALL)
        if fm and cm and fm.group(1).strip().lower() == cm.group(1).strip().lower():
            text = re.sub(r'\[CONCLUSION\].*?(?=\[|$)', '', text, flags=re.IGNORECASE | re.DOTALL)
        text = re.sub(r'\[\s*(FINDING|CONCLUSION|DIAGNOSIS)\s*\]', '', text, flags=re.IGNORECASE)
        text = text.replace('_x000D_', ' ')
        text = re.sub(r'\s+', ' ', text).strip()
        if text and not text.endswith(self.eos_token):
            text += ' ' + self.eos_token
        return text

# =============================================================================
# Collate function
# =============================================================================

def collate_fn(batch):
    imgs = torch.stack([b['full_img'] for b in batch])
    pts = [b['patches'] for b in batch]
    max_p = max(p.shape[0] for p in pts)
    pads = []
    for p in pts:
        if p.shape[0] < max_p:
            pad = torch.zeros((max_p - p.shape[0], *p.shape[1:]))
            p = torch.cat([p, pad], dim=0)
        pads.append(p)
    patches = torch.stack(pads, 0)

    ids = [b['input_ids'] for b in batch]
    masks = [b['attention_mask'] for b in batch]
    ids = nn.utils.rnn.pad_sequence(ids, batch_first=True, padding_value=tokenizer.pad_token_id)
    masks = nn.utils.rnn.pad_sequence(masks, batch_first=True, padding_value=0)

    return {
        'full_imgs': imgs,
        'patches': patches,
        'input_ids': ids,
        'attention_mask': masks,
        'raw_reports': [b['raw_report'] for b in batch],
        'cleaned_reports': [b['cleaned_report'] for b in batch]
    }

# =============================================================================
# Model
# =============================================================================

class MultiModalModel(nn.Module):
    def __init__(self, gpt2_model_name='gpt2'):
        super().__init__()
        self.global_encoder = timm.create_model('swin_base_patch4_window7_224', pretrained=True)
        self.global_encoder.reset_classifier(0)
        self.global_proj = nn.Linear(self.global_encoder.num_features, 768)

        self.patch_encoder = timm.create_model('resnet50', pretrained=True)
        self.patch_encoder.fc = nn.Identity()
        self.patch_proj = nn.Linear(self.patch_encoder.num_features, 768)

        self.attn = nn.MultiheadAttention(embed_dim=768, num_heads=8, batch_first=True)
        self.norm = nn.LayerNorm(768)

        self.decoder = GPT2LMHeadModel.from_pretrained(gpt2_model_name, add_cross_attention=True)

    def _pool(self, feats):
        return feats.mean(dim=[2, 3]) if feats.ndim > 2 else feats

    def forward(self, imgs, patches, input_ids, attention_mask, decoder_labels=None):
        g = self.global_encoder(imgs)
        g = self.global_proj(g).unsqueeze(1)

        B, N, C, H, W = patches.shape
        p = patches.view(B * N, C, H, W)
        pf = (self.patch_encoder.forward_features(p)
              if hasattr(self.patch_encoder, 'forward_features')
              else self.patch_encoder(p))
        pf = self._pool(pf)
        pf = self.patch_proj(pf)
        pf = pf.view(B, N, 768)

        cat = torch.cat([g, pf], dim=1)
        comb, _ = self.attn(cat, cat, cat)
        comb = self.norm(comb)

        return self.decoder(
            input_ids=input_ids,
            attention_mask=attention_mask,
            encoder_hidden_states=comb,
            labels=decoder_labels
        )

# =============================================================================
# Train / Eval helpers
# =============================================================================

def train_epoch(model, loader, optimizer, scaler, device):
    model.train()
    total_loss = 0.0
    for b in tqdm(loader, desc="Training", leave=False):
        imgs = b['full_imgs'].to(device)
        pts = b['patches'].to(device)
        ids = b['input_ids'].to(device)
        msk = b['attention_mask'].to(device)

        optimizer.zero_grad()
        with torch.cuda.amp.autocast():
            out = model(imgs, pts, ids, msk, decoder_labels=ids)
            loss = out.loss
        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()
        total_loss += loss.item()
    return total_loss / len(loader)

def evaluate(model, loader, device):
    model.eval()
    total_loss = 0.0
    all_gen, all_gt = [], []

    for b in tqdm(loader, desc="Evaluating", leave=False):
        imgs = b['full_imgs'].to(device)
        pts = b['patches'].to(device)
        ids = b['input_ids'].to(device)
        msk = b['attention_mask'].to(device)

        with torch.no_grad():
            out = model(imgs, pts, ids, msk, decoder_labels=ids)
            total_loss += out.loss.item()

            prompt = ids[:, :1]
            print(f'---------In Evaluate---------')
            print(f'Prompt = {prompt}')
            g = model.global_encoder(imgs)
            g = model.global_proj(g).unsqueeze(1)

            B, N, C, H, W = pts.shape
            p = pts.view(B * N, C, H, W)
            pf = model.patch_encoder(p)
            pf = model._pool(pf)
            pf = model.patch_proj(pf)
            pf = pf.view(B, N, 768)

            cat = torch.cat([g, pf], dim=1)
            comb, _ = model.attn(cat, cat, cat)
            comb = model.norm(comb)

            gen_ids = model.decoder.generate(
                input_ids=prompt,
                encoder_hidden_states=comb,
                attention_mask=torch.ones_like(prompt),
                max_length=100,
                do_sample=True,
                top_k=50,
                top_p=0.95,
                temperature=0.7,
                repetition_penalty=1.2,
                eos_token_id=tokenizer.eos_token_id,
                pad_token_id=tokenizer.eos_token_id
            )

            gen_txt = [tokenizer.decode(g_, skip_special_tokens=True) for g_ in gen_ids]
            gt_txt = [tokenizer.decode(i_, skip_special_tokens=True) for i_ in ids]
            all_gen.extend(gen_txt)
            all_gt.extend(gt_txt)

    return total_loss / len(loader), all_gen, all_gt

def compute_semantic_similarity(gen, gt):
    stm = SentenceTransformer('all-MiniLM-L6-v2')
    e1 = stm.encode(gen, convert_to_tensor=True)
    e2 = stm.encode(gt, convert_to_tensor=True)
    return nn.functional.cosine_similarity(e1, e2).mean().item()

def plot_metrics(train_losses, val_losses, sems):
    epochs = range(1, len(train_losses) + 1)
    plt.figure(figsize=(12, 5))

    plt.subplot(1, 2, 1)
    plt.plot(epochs, train_losses, label="Train Loss")
    plt.plot(epochs, val_losses, label="Validation Loss")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(epochs, sems, label="Semantic Similarity")
    plt.xlabel("Epoch")
    plt.ylabel("Similarity")
    plt.legend()

    plt.tight_layout()
    plt.show()

# =============================================================================
# MAIN
# =============================================================================

class Cfg: pass
cfg = Cfg()
cfg.DATASET = Cfg()
cfg.DATASET.JSON = 'final_samples_both_only_v2.json'
cfg.DATASET.USE_RAW = True
cfg.DATASET.USE_PATCH = True
cfg.DATASET.REPORT = True
cfg.DATASET.TARGET_CLASSES = ['ra', 'oa', 'gout', 'normal', 'uncertain', 'ref.prev']
cfg.DATASET.BALANCE = False
cfg.DATASET.AUGMENT = False

tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
tokenizer.pad_token = tokenizer.eos_token
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

dataset = FinalSamplesDataset(cfg)
dataset.eos_token = tokenizer.eos_token

dist = Counter(e['class_label'] for e in dataset.data.values())
print("\nDataset class distribution:")
for cls, cnt in dist.items():
    print(f"  {cls}: {cnt}")

# split into train / val / test
n = len(dataset)
n_train = int(0.8 * n)
n_val = int(0.1 * n)
n_test = n - n_train - n_val

train_ds, val_ds, test_ds = random_split(dataset, [n_train, n_val, n_test])

# print sample counts
print(f"\nNumber of training samples:   {len(train_ds)}")
print(f"Number of validation samples: {len(val_ds)}")
print(f"Number of test samples:       {len(test_ds)}")
print(f"Total samples:                {len(train_ds) + len(val_ds) + len(test_ds)}\n")

train_loader = DataLoader(train_ds, batch_size=4, shuffle=True, collate_fn=collate_fn)
val_loader = DataLoader(val_ds, batch_size=4, shuffle=False, collate_fn=collate_fn)
test_loader = DataLoader(test_ds, batch_size=4, shuffle=False, collate_fn=collate_fn)

model = MultiModalModel().to(device)
optimizer = optim.AdamW(model.parameters(), lr=5e-5)
scheduler = torch.optim.lr_scheduler.CosineAnnealingWarmRestarts(optimizer, T_0=10, T_mult=2)
scaler = torch.cuda.amp.GradScaler()

num_epochs = 1
train_losses, val_losses, sems = [], [], []

for epoch in range(num_epochs):
    print(f"\nEpoch {epoch + 1}/{num_epochs}")
    train_loss = train_epoch(model, train_loader, optimizer, scaler, device)
    val_loss, gen_txt, gt_txt = evaluate(model, val_loader, device)
    sem = compute_semantic_similarity(gen_txt, gt_txt)

    train_losses.append(train_loss)
    val_losses.append(val_loss)
    sems.append(sem)

    print(f"  Train Loss          : {train_loss:.4f}")
    print(f"  Validation Loss     : {val_loss:.4f}")
    print(f"  Semantic Similarity : {sem:.4f}")
    scheduler.step()

plot_metrics(train_losses, val_losses, sems)

test_loss, test_gen, test_gt = evaluate(model, test_loader, device)
test_sem = compute_semantic_similarity(test_gen, test_gt)

print("\n========== TEST RESULTS ==========")
print(f"Test Loss          : {test_loss:.4f}")
print(f"Test Semantic Sim  : {test_sem:.4f}")

print("\n===== RANDOM TEST EXAMPLES =====")
for idx in random.sample(range(len(test_ds)), min(10, len(test_ds))):
    ex = test_ds[idx]
    raw = ex['raw_report']
    clean = ex['cleaned_report']
    fi = ex['full_img'].unsqueeze(0).to(device)
    pa = ex['patches'].unsqueeze(0).to(device)
    prompt = ex['input_ids'][:1].unsqueeze(0).to(device)
    print(f'\n--------In Test--------\n')
    print(f'Prompt = {prompt}')

    g = model.global_encoder(fi)
    g = model.global_proj(g).unsqueeze(1)
    B, N, C, H, W = pa.shape
    p = pa.view(B * N, C, H, W)
    pf = model.patch_encoder(p)
    pf = model._pool(pf)
    pf = model.patch_proj(pf)
    pf = pf.view(B, N, 768)

    cat = torch.cat([g, pf], dim=1)
    comb, _ = model.attn(cat, cat, cat)
    comb = model.norm(comb)

    gen_ids = model.decoder.generate(
        input_ids=prompt,
        encoder_hidden_states=comb,
        attention_mask=torch.ones_like(prompt),
        max_length=120,
        do_sample=True,
        top_k=40,
        top_p=0.95,
        temperature=0.5,
        repetition_penalty=1.3,
        eos_token_id=tokenizer.eos_token_id,
        pad_token_id=tokenizer.eos_token_id
    )

    gen = tokenizer.decode(gen_ids[0], skip_special_tokens=True)

    print(f"\n--- Example {idx} ---")
    print(f"Raw Report       : \n{raw}")
    print(f"Cleaned Report   : \n{clean}")
    print(f"Generated Report : \n{gen}")
# Out:
# Using device: cuda
#
# Dataset class distribution:
#   oa: 573
#   ra: 115
#   uncertain: 620
#   oa, ra: 8
#   normal: 748
#   gout: 267
#   combination of oa, ra: 3
#   ref.prev: 60
#
# Number of training samples:   1915
# Number of validation samples: 239
# Number of test samples:       240
# Total samples:                2394
# INFO:timm.models._builder:Loading pretrained weights from Hugging Face hub (timm/swin_base_patch4_window7_224.ms_in22k_ft_in1k)
# INFO:timm.models._hub:[timm/swin_base_patch4_window7_224.ms_in22k_ft_in1k] Safe alternative available for 'pytorch_model.bin' (as 'model.safetensors'). Loading weights using safetensors.
# INFO:timm.models._builder:Loading pretrained weights from Hugging Face hub (timm/resnet50.a1_in1k)
# INFO:timm.models._hub:[timm/resnet50.a1_in1k] Safe alternative available for 'pytorch_model.bin' (as 'model.safetensors'). Loading weights using safetensors.
# Some weights of GPT2LMHeadModel were not initialized from the model checkpoint at gpt2 and are newly initialized: ['h.0.crossattention.c_attn.bias', 'h.0.crossattention.c_attn.weight', 'h.0.crossattention.c_proj.bias', 'h.0.crossattention.c_proj.weight', 'h.0.crossattention.q_attn.bias', 'h.0.crossattention.q_attn.weight', 'h.0.ln_cross_attn.bias', 'h.0.ln_cross_attn.weight', 'h.1.crossattention.c_attn.bias', 'h.1.crossattention.c_attn.weight', 'h.1.crossattention.c_proj.bias', 'h.1.crossattention.c_proj.weight', 'h.1.crossattention.q_attn.bias', 'h.1.crossattention.q_attn.weight', 'h.1.ln_cross_attn.bias', 'h.1.ln_cross_attn.weight', 'h.10.crossattention.c_attn.bias', 'h.10.crossattention.c_attn.weight', 'h.10.crossattention.c_proj.bias', 'h.10.crossattention.c_proj.weight', 'h.10.crossattention.q_attn.bias', 'h.10.crossattention.q_attn.weight', 'h.10.ln_cross_attn.bias', 'h.10.ln_cross_attn.weight', 'h.11.crossattention.c_attn.bias', 'h.11.crossattention.c_attn.weight', 'h.11.crossattention.c_proj.bias', 'h.11.crossattention.c_proj.weight', 'h.11.crossattention.q_attn.bias', 'h.11.crossattention.q_attn.weight', 'h.11.ln_cross_attn.bias', 'h.11.ln_cross_attn.weight', 'h.2.crossattention.c_attn.bias', 'h.2.crossattention.c_attn.weight', 'h.2.crossattention.c_proj.bias', 'h.2.crossattention.c_proj.weight', 'h.2.crossattention.q_attn.bias', 'h.2.crossattention.q_attn.weight', 'h.2.ln_cross_attn.bias', 'h.2.ln_cross_attn.weight', 'h.3.crossattention.c_attn.bias', 'h.3.crossattention.c_attn.weight', 'h.3.crossattention.c_proj.bias', 'h.3.crossattention.c_proj.weight', 'h.3.crossattention.q_attn.bias', 'h.3.crossattention.q_attn.weight', 'h.3.ln_cross_attn.bias', 'h.3.ln_cross_attn.weight', 'h.4.crossattention.c_attn.bias', 'h.4.crossattention.c_attn.weight', 'h.4.crossattention.c_proj.bias', 'h.4.crossattention.c_proj.weight', 'h.4.crossattention.q_attn.bias', 'h.4.crossattention.q_attn.weight', 'h.4.ln_cross_attn.bias', 'h.4.ln_cross_attn.weight', 'h.5.crossattention.c_attn.bias', 'h.5.crossattention.c_attn.weight', 'h.5.crossattention.c_proj.bias', 'h.5.crossattention.c_proj.weight', 'h.5.crossattention.q_attn.bias', 'h.5.crossattention.q_attn.weight', 'h.5.ln_cross_attn.bias', 'h.5.ln_cross_attn.weight', 'h.6.crossattention.c_attn.bias', 'h.6.crossattention.c_attn.weight', 'h.6.crossattention.c_proj.bias', 'h.6.crossattention.c_proj.weight', 'h.6.crossattention.q_attn.bias', 'h.6.crossattention.q_attn.weight', 'h.6.ln_cross_attn.bias', 'h.6.ln_cross_attn.weight', 'h.7.crossattention.c_attn.bias', 'h.7.crossattention.c_attn.weight', 'h.7.crossattention.c_proj.bias', 'h.7.crossattention.c_proj.weight', 'h.7.crossattention.q_attn.bias', 'h.7.crossattention.q_attn.weight', 'h.7.ln_cross_attn.bias', 'h.7.ln_cross_attn.weight', 'h.8.crossattention.c_attn.bias', 'h.8.crossattention.c_attn.weight', 'h.8.crossattention.c_proj.bias', 'h.8.crossattention.c_proj.weight', 'h.8.crossattention.q_attn.bias', 'h.8.crossattention.q_attn.weight', 'h.8.ln_cross_attn.bias', 'h.8.ln_cross_attn.weight', 'h.9.crossattention.c_attn.bias', 'h.9.crossattention.c_attn.weight', 'h.9.crossattention.c_proj.bias', 'h.9.crossattention.c_proj.weight', 'h.9.crossattention.q_attn.bias', 'h.9.crossattention.q_attn.weight', 'h.9.ln_cross_attn.bias', 'h.9.ln_cross_attn.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /tmp/ipykernel_44858/314011083.py:484: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler()
# Epoch 1/1
# Training:   0%|          | 0/479 [00:00<?, ?it/s]/tmp/ipykernel_44858/314011083.py:347: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# Evaluating:   2%|▏         | 1/60 [00:00<00:17,  3.46it/s]
# ---------In Evaluate---------
# Prompt = tensor([[   13],
#         [ 3919],
#         [ 2949],
#         [27734]], device='cuda:0')
# Evaluating:   3%|▎         | 2/60 [00:00<00:15,  3.72it/s]
# ---------In Evaluate---------
# Prompt = tensor([[16885],
#         [   76],
#         [   44],
#         [ 3919]], device='cuda:0')
# Evaluating:   5%|▌         | 3/60 [00:00<00:16,  3.53it/s]
# ---------In Evaluate---------
# Prompt = tensor([[49578],
#         [ 3919],
#         [   49],
#         [ 3919]], device='cuda:0')
# Evaluating:   7%|▋         | 4/60 [00:01<00:16,  3.44it/s]
# ---------In Evaluate---------
# Prompt = tensor([[   49],
#         [16885],
#         [ 4215],
#         [47189]], device='cuda:0')
# Evaluating:   8%|▊         | 5/60 [00:01<00:15,  3.47it/s]
# ---------In Evaluate---------
# Prompt = tensor([[ 2949],
#         [16885],
#         [ 3919],
#         [49578]], device='cuda:0')
# Evaluating:  10%|█         | 6/60 [00:01<00:14,  3.64it/s]
# ---------In Evaluate---------
# Prompt = tensor([[13500],
#         [26069],
#         [ 3919],
#         [ 3919]], device='cuda:0')
# Evaluating:  12%|█▏        | 7/60 [00:01<00:14,  3.69it/s]
# ---------In Evaluate---------
# Prompt = tensor([[ 3919],
#         [13500],
#         [   38],
#         [13500]], device='cuda:0')
# Evaluating:  13%|█▎        | 8/60 [00:02<00:14,  3.68it/s]
# ---------In Evaluate---------
# Prompt = tensor([[13500],
#         [   12],
#         [   49],
#         [ 2949]], device='cuda:0')
# Evaluating:  15%|█▌        | 9/60 [00:02<00:13,  3.67it/s]
# ---------In Evaluate---------
# Prompt = tensor([[ 3919],
#         [ 4653],
#         [40409],
#         [10265]], device='cuda:0')
# Evaluating:  17%|█▋        | 10/60 [00:02<00:14,  3.55it/s]
# ---------In Evaluate---------
# Prompt = tensor([[18323],
#         [   49],
#         [ 2949],
#         [   12]], device='cuda:0')
# Evaluating:  18%|█▊        | 11/60 [00:03<00:13,  3.61it/s]
# ---------In Evaluate---------
# Prompt = tensor([[ 2949],
#         [13500],
#         [   12],
#         [   12]], device='cuda:0')
# Evaluating:  20%|██        | 12/60 [00:03<00:12,  3.72it/s]
# ---------In Evaluate---------
# Prompt = tensor([[ 2949],
#         [ 3919],
#         [16885],
#         [18380]], device='cuda:0')
# Evaluating:  22%|██▏       | 13/60 [00:03<00:12,  3.84it/s]
# ---------In Evaluate---------
# Prompt = tensor([[  76],
#         [2949],
#         [3919],
#         [3919]], device='cuda:0')
# Evaluating:  23%|██▎       | 14/60 [00:03<00:11,  3.97it/s]
# ---------In Evaluate---------
# Prompt = tensor([[ 2949],
#         [ 3919],
#         [ 2949],
#         [40409]], device='cuda:0')
# Evaluating:  25%|██▌       | 15/60 [00:04<00:11,  3.93it/s]
# ---------In Evaluate---------
# Prompt = tensor([[49578],
#         [   49],
#         [ 5005],
#         [16885]], device='cuda:0')
# Evaluating:  27%|██▋       | 16/60 [00:04<00:11,  3.79it/s]
# ---------In Evaluate---------
# Prompt = tensor([[26069],
#         [ 4215],
#         [ 3919],
#         [ 1084]], device='cuda:0')
# Evaluating:  28%|██▊       | 17/60 [00:04<00:11,  3.79it/s]
# ---------In Evaluate---------
# Prompt = tensor([[   49],
#         [ 2949],
#         [ 1676],
#         [40409]], device='cuda:0')
# Evaluating:  30%|███       | 18/60 [00:04<00:11,  3.80it/s]
# ---------In Evaluate---------
# Prompt = tensor([[  49],
#         [2949],
#         [  12],
#         [2949]], device='cuda:0')
# Evaluating:  32%|███▏      | 19/60 [00:05<00:10,  3.73it/s]
# ---------In Evaluate---------
# Prompt = tensor([[   12],
#         [12272],
#         [ 3919],
#         [ 4215]], device='cuda:0')
# Evaluating:  33%|███▎      | 20/60 [00:05<00:11,  3.54it/s]
# ---------In Evaluate---------
# Prompt = tensor([[26069],
#         [49578],
#         [   13],
#         [ 3919]], device='cuda:0')
# Evaluating:  35%|███▌      | 21/60 [00:05<00:10,  3.76it/s]
# ---------In Evaluate---------
# Prompt = tensor([[ 3919],
#         [ 2949],
#         [16885],
#         [ 2949]], device='cuda:0')
# Evaluating:  37%|███▋      | 22/60 [00:05<00:10,  3.74it/s]
# ---------In Evaluate---------
# Prompt = tensor([[ 3919],
#         [   76],
#         [ 7004],
#         [49578]], device='cuda:0')
# Evaluating:  38%|███▊      | 23/60 [00:06<00:10,  3.69it/s]
# ---------In Evaluate---------
# Prompt = tensor([[4215],
#         [3919],
#         [  16],
#         [  12]], device='cuda:0')
# Evaluating:  40%|████      | 24/60 [00:06<00:09,  3.60it/s]
# ---------In Evaluate---------
# Prompt = tensor([[3919],
#         [  83],
#         [  35],
#         [  70]], device='cuda:0')
# Evaluating:  42%|████▏     | 25/60 [00:06<00:09,  3.81it/s]
# ---------In Evaluate---------
# Prompt = tensor([[ 3919],
#         [ 3919],
#         [26069],
#         [40409]], device='cuda:0')
# Evaluating:  43%|████▎     | 26/60 [00:07<00:09,  3.63it/s]
# ---------In Evaluate---------
# Prompt = tensor([[ 2949],
#         [ 2949],
#         [13500],
#         [   49]], device='cuda:0')
# Evaluating:  45%|████▌     | 27/60 [00:07<00:09,  3.58it/s]
# ---------In Evaluate---------
# Prompt = tensor([[16885],
#         [   76],
#         [ 3919],
#         [13500]], device='cuda:0')
# Evaluating:  47%|████▋     | 28/60 [00:07<00:08,  3.59it/s]
# ---------In Evaluate---------
# Prompt = tensor([[  46],
#         [  16],
#         [  49],
#         [2949]], device='cuda:0')
# Evaluating:  48%|████▊     | 29/60 [00:07<00:08,  3.54it/s]
# ---------In Evaluate---------
# Prompt = tensor([[13500],
#         [   67],
#         [13500],
#         [   16]], device='cuda:0')
# Evaluating:  50%|█████     | 30/60 [00:08<00:08,  3.63it/s]
# ---------In Evaluate---------
# Prompt = tensor([[   70],
#         [ 2949],
#         [18380],
#         [ 3919]], device='cuda:0')
# Evaluating:  52%|█████▏    | 31/60 [00:08<00:07,  3.69it/s]
# ---------In Evaluate---------
# Prompt = tensor([[   36],
#         [49578],
#         [13500],
#         [ 3919]], device='cuda:0')
# Evaluating:  53%|█████▎    | 32/60 [00:08<00:07,  3.79it/s]
# ---------In Evaluate---------
# Prompt = tensor([[3919],
#         [2949],
#         [  76],
#         [  49]], device='cuda:0')
# Evaluating:  55%|█████▌    | 33/60 [00:08<00:06,  3.86it/s]
# ---------In Evaluate---------
# Prompt = tensor([[13500],
#         [16748],
#         [ 3919],
#         [ 2949]], device='cuda:0')
# Evaluating:  57%|█████▋    | 34/60 [00:09<00:06,  3.97it/s]
# ---------In Evaluate---------
# Prompt = tensor([[13500],
#         [13500],
#         [   35],
#         [ 3919]], device='cuda:0')
# Evaluating:  58%|█████▊    | 35/60 [00:09<00:06,  3.86it/s]
# ---------In Evaluate---------
# Prompt = tensor([[13500],
#         [47189],
#         [ 3919],
#         [ 2949]], device='cuda:0')
# Evaluating:  60%|██████    | 36/60 [00:09<00:06,  3.76it/s]
# ---------In Evaluate---------
# Prompt = tensor([[16885],
#         [   50],
#         [   35],
#         [28813]], device='cuda:0')
# Evaluating:  62%|██████▏   | 37/60 [00:09<00:06,  3.69it/s]
# ---------In Evaluate---------
# Prompt = tensor([[ 2949],
#         [ 3919],
#         [  525],
#         [16885]], device='cuda:0')
# Evaluating:  63%|██████▎   | 38/60 [00:10<00:05,  3.79it/s]
# ---------In Evaluate---------
# Prompt = tensor([[18323],
#         [13500],
#         [34194],
#         [ 2949]], device='cuda:0')
# Evaluating:  65%|██████▌   | 39/60 [00:10<00:05,  3.55it/s]
# ---------In Evaluate---------
# Prompt = tensor([[  455],
#         [16885],
#         [15992],
#         [26069]], device='cuda:0')
# Evaluating:  67%|██████▋   | 40/60 [00:10<00:05,  3.49it/s]
# ---------In Evaluate---------
# Prompt = tensor([[26069],
#         [18323],
#         [16885],
#         [40409]], device='cuda:0')
# Evaluating:  68%|██████▊   | 41/60 [00:11<00:05,  3.52it/s]
# ---------In Evaluate---------
# Prompt = tensor([[ 2949],
#         [34194],
#         [   12],
#         [   49]], device='cuda:0')
# Evaluating:  70%|███████   | 42/60 [00:11<00:05,  3.53it/s]
# ---------In Evaluate---------
# Prompt = tensor([[16885],
#         [ 3919],
#         [13500],
#         [   49]], device='cuda:0')
# Evaluating:  72%|███████▏  | 43/60 [00:11<00:04,  3.58it/s]
# ---------In Evaluate---------
# Prompt = tensor([[ 2949],
#         [ 3919],
#         [38568],
#         [49578]], device='cuda:0')
# Evaluating:  73%|███████▎  | 44/60 [00:11<00:04,  3.65it/s]
# ---------In Evaluate---------
# Prompt = tensor([[13500],
#         [ 2949],
#         [ 3919],
#         [   36]], device='cuda:0')
# Evaluating:  75%|███████▌  | 45/60 [00:12<00:04,  3.50it/s]
# ---------In Evaluate---------
# Prompt = tensor([[   66],
#         [  525],
#         [  455],
#         [26069]], device='cuda:0')
# Evaluating:  77%|███████▋  | 46/60 [00:12<00:04,  3.40it/s]
# ---------In Evaluate---------
# Prompt = tensor([[18380],
#         [ 3919],
#         [ 3919],
#         [40409]], device='cuda:0')
# Evaluating:  78%|███████▊  | 47/60 [00:12<00:03,  3.53it/s]
# ---------In Evaluate---------
# Prompt = tensor([[13500],
#         [13500],
#         [ 3849],
#         [13500]], device='cuda:0')
# Evaluating:  80%|████████  | 48/60 [00:13<00:03,  3.59it/s]
# ---------In Evaluate---------
# Prompt = tensor([[   49],
#         [   37],
#         [13500],
#         [13500]], device='cuda:0')
# Evaluating:  82%|████████▏ | 49/60 [00:13<00:03,  3.65it/s]
# ---------In Evaluate---------
# Prompt = tensor([[ 525],
#         [  35],
#         [3919],
#         [  35]], device='cuda:0')
# Evaluating:  83%|████████▎ | 50/60 [00:13<00:02,  3.73it/s]
# ---------In Evaluate---------
# Prompt = tensor([[ 3919],
#         [18380],
#         [13500],
#         [34194]], device='cuda:0')
# Evaluating:  85%|████████▌ | 51/60 [00:13<00:02,  3.78it/s]
# ---------In Evaluate---------
# Prompt = tensor([[   46],
#         [12272],
#         [   35],
#         [   50]], device='cuda:0')
# Evaluating:  87%|████████▋ | 52/60 [00:14<00:02,  3.88it/s]
# ---------In Evaluate---------
# Prompt = tensor([[15992],
#         [ 3919],
#         [ 3919],
#         [26069]], device='cuda:0')
# Evaluating:  88%|████████▊ | 53/60 [00:14<00:01,  3.65it/s]
# ---------In Evaluate---------
# Prompt = tensor([[   49],
#         [   12],
#         [12272],
#         [34194]], device='cuda:0')
# Evaluating:  90%|█████████ | 54/60 [00:14<00:01,  3.67it/s]
# ---------In Evaluate---------
# Prompt = tensor([[  12],
#         [2949],
#         [  65],
#         [3919]], device='cuda:0')
# Evaluating:  92%|█████████▏| 55/60 [00:14<00:01,  3.74it/s]
# ---------In Evaluate---------
# Prompt = tensor([[16885],
#         [ 3919],
#         [ 2949],
#         [13500]], device='cuda:0')
# Evaluating:  93%|█████████▎| 56/60 [00:15<00:01,  3.63it/s]
# ---------In Evaluate---------
# Prompt = tensor([[   70],
#         [49578],
#         [ 3861],
#         [   49]], device='cuda:0')
# Evaluating:  95%|█████████▌| 57/60 [00:15<00:00,  3.65it/s]
# ---------In Evaluate---------
# Prompt = tensor([[ 3919],
#         [ 2949],
#         [16885],
#         [17470]], device='cuda:0')
# Evaluating:  97%|█████████▋| 58/60 [00:15<00:00,  3.71it/s]
# ---------In Evaluate---------
# Prompt = tensor([[ 2949],
#         [   75],
#         [ 3919],
#         [13500]], device='cuda:0')
# Evaluating:  98%|█████████▊| 59/60 [00:16<00:00,  3.73it/s]
# ---------In Evaluate---------
# Prompt = tensor([[2949],
#         [  65],
#         [ 418],
#         [  66]], device='cuda:0')
# INFO:sentence_transformers.SentenceTransformer:Use pytorch device_name: cuda
# INFO:sentence_transformers.SentenceTransformer:Load pretrained SentenceTransformer: all-MiniLM-L6-v2
# ---------In Evaluate---------
# Prompt = tensor([[13500],
#         [   49],
#         [ 2949]], device='cuda:0')
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
#   Train Loss          : 1.3056
#   Validation Loss     : 0.8484
#   Semantic Similarity : 0.5049
# Evaluating:   2%|▏         | 1/60 [00:00<00:14,  4.02it/s]
# ---------In Evaluate---------
# Prompt = tensor([[13500],
#         [ 3919],
#         [ 3919],
#         [ 3919]], device='cuda:0')
# Evaluating:   3%|▎         | 2/60 [00:00<00:15,  3.81it/s]
# ---------In Evaluate---------
# Prompt = tensor([[18819],
#         [26069],
#         [ 1676],
#         [13500]], device='cuda:0')
# Evaluating:   5%|▌         | 3/60 [00:00<00:14,  4.03it/s]
# ---------In Evaluate---------
# Prompt = tensor([[26069],
#         [ 3861],
#         [ 2949],
#         [ 3919]], device='cuda:0')
# Evaluating:   7%|▋         | 4/60 [00:01<00:14,  3.97it/s]
# ---------In Evaluate---------
# Prompt = tensor([[  49],
#         [3919],
#         [3919],
#         [  13]], device='cuda:0')
# Evaluating:   8%|▊         | 5/60 [00:01<00:13,  4.08it/s]
# ---------In Evaluate---------
# Prompt = tensor([[ 2949],
#         [41629],
#         [   49],
#         [ 3163]], device='cuda:0')
# Evaluating:  10%|█         | 6/60 [00:01<00:14,  3.82it/s]
# ---------In Evaluate---------
# Prompt = tensor([[13500],
#         [13500],
#         [49578],
#         [26069]], device='cuda:0')
# Evaluating:  12%|█▏        | 7/60 [00:01<00:13,  3.84it/s]
# ---------In Evaluate---------
# Prompt = tensor([[49578],
#         [ 2949],
#         [ 1676],
#         [23621]], device='cuda:0')
# Evaluating:  13%|█▎        | 8/60 [00:02<00:13,  3.87it/s]
# ---------In Evaluate---------
# Prompt = tensor([[   75],
#         [18380],
#         [ 2949],
#         [ 1676]], device='cuda:0')
# Evaluating:  15%|█▌        | 9/60 [00:02<00:13,  3.84it/s]
# ---------In Evaluate---------
# Prompt = tensor([[12272],
#         [49578],
#         [13500],
#         [15060]], device='cuda:0')
# Evaluating:  17%|█▋        | 10/60 [00:02<00:12,  3.88it/s]
# ---------In Evaluate---------
# Prompt = tensor([[ 2949],
#         [ 2949],
#         [26069],
#         [18323]], device='cuda:0')
# Evaluating:  18%|█▊        | 11/60 [00:02<00:13,  3.75it/s]
# ---------In Evaluate---------
# Prompt = tensor([[47189],
#         [16885],
#         [   12],
#         [ 3919]], device='cuda:0')
# Evaluating:  20%|██        | 12/60 [00:03<00:12,  3.73it/s]
# ---------In Evaluate---------
# Prompt = tensor([[   79],
#         [   76],
#         [34194],
#         [16885]], device='cuda:0')
# Evaluating:  22%|██▏       | 13/60 [00:03<00:12,  3.69it/s]
# ---------In Evaluate---------
# Prompt = tensor([[   81],
#         [13500],
#         [ 2949],
#         [13500]], device='cuda:0')
# Evaluating:  23%|██▎       | 14/60 [00:03<00:12,  3.74it/s]
# ---------In Evaluate---------
# Prompt = tensor([[9781],
#         [  49],
#         [  79],
#         [3861]], device='cuda:0')
# Evaluating:  25%|██▌       | 15/60 [00:03<00:12,  3.59it/s]
# ---------In Evaluate---------
# Prompt = tensor([[3919],
#         [9948],
#         [  49],
#         [1676]], device='cuda:0')
# Evaluating:  27%|██▋       | 16/60 [00:04<00:12,  3.52it/s]
# ---------In Evaluate---------
# Prompt = tensor([[   12],
#         [16885],
#         [ 1084],
#         [  455]], device='cuda:0')
# Evaluating:  28%|██▊       | 17/60 [00:04<00:11,  3.67it/s]
# ---------In Evaluate---------
# Prompt = tensor([[13500],
#         [ 2949],
#         [13500],
#         [ 3919]], device='cuda:0')
# Evaluating:  30%|███       | 18/60 [00:04<00:11,  3.66it/s]
# ---------In Evaluate---------
# Prompt = tensor([[   49],
#         [ 3919],
#         [   83],
#         [13500]], device='cuda:0')
# Evaluating:  32%|███▏      | 19/60 [00:05<00:10,  3.77it/s]
# ---------In Evaluate---------
# Prompt = tensor([[ 2949],
#         [18712],
#         [ 2949],
#         [ 3919]], device='cuda:0')
# Evaluating:  33%|███▎      | 20/60 [00:05<00:10,  3.88it/s]
# ---------In Evaluate---------
# Prompt = tensor([[ 3919],
#         [   35],
#         [12404],
#         [13500]], device='cuda:0')
# Evaluating:  35%|███▌      | 21/60 [00:05<00:09,  3.95it/s]
# ---------In Evaluate---------
# Prompt = tensor([[26069],
#         [ 2302],
#         [13500],
#         [ 3919]], device='cuda:0')
# Evaluating:  37%|███▋      | 22/60 [00:05<00:09,  3.86it/s]
# ---------In Evaluate---------
# Prompt = tensor([[ 2949],
#         [   35],
#         [   76],
#         [13500]], device='cuda:0')
# Evaluating:  38%|███▊      | 23/60 [00:06<00:09,  3.92it/s]
# ---------In Evaluate---------
# Prompt = tensor([[16885],
#         [   16],
#         [ 2949],
#         [13500]], device='cuda:0')
# Evaluating:  40%|████      | 24/60 [00:06<00:09,  3.95it/s]
# ---------In Evaluate---------
# Prompt = tensor([[16885],
#         [ 3919],
#         [15992],
#         [15060]], device='cuda:0')
# Evaluating:  42%|████▏     | 25/60 [00:06<00:09,  3.63it/s]
# ---------In Evaluate---------
# Prompt = tensor([[  70],
#         [  34],
#         [2949],
#         [2949]], device='cuda:0')
# Evaluating:  43%|████▎     | 26/60 [00:06<00:09,  3.71it/s]
# ---------In Evaluate---------
# Prompt = tensor([[16],
#         [49],
#         [49],
#         [76]], device='cuda:0')
# Evaluating:  45%|████▌     | 27/60 [00:07<00:08,  3.70it/s]
# ---------In Evaluate---------
# Prompt = tensor([[13500],
#         [   79],
#         [ 3919],
#         [   13]], device='cuda:0')
# Evaluating:  47%|████▋     | 28/60 [00:07<00:09,  3.50it/s]
# ---------In Evaluate---------
# Prompt = tensor([[15992],
#         [ 3919],
#         [26069],
#         [   76]], device='cuda:0')
# Evaluating:  48%|████▊     | 29/60 [00:07<00:08,  3.52it/s]
# ---------In Evaluate---------
# Prompt = tensor([[ 7266],
#         [49578],
#         [13500],
#         [ 2949]], device='cuda:0')
# Evaluating:  50%|█████     | 30/60 [00:08<00:08,  3.58it/s]
# ---------In Evaluate---------
# Prompt = tensor([[   76],
#         [13500],
#         [ 3919],
#         [13500]], device='cuda:0')
# Evaluating:  52%|█████▏    | 31/60 [00:08<00:08,  3.49it/s]
# ---------In Evaluate---------
# Prompt = tensor([[15992],
#         [   49],
#         [   65],
#         [26069]], device='cuda:0')
# Evaluating:  53%|█████▎    | 32/60 [00:08<00:07,  3.53it/s]
# ---------In Evaluate---------
# Prompt = tensor([[ 3919],
#         [   79],
#         [ 2949],
#         [16885]], device='cuda:0')
# Evaluating:  55%|█████▌    | 33/60 [00:08<00:07,  3.76it/s]
# ---------In Evaluate---------
# Prompt = tensor([[34194],
#         [ 2949],
#         [43070],
#         [   12]], device='cuda:0')
# Evaluating:  57%|█████▋    | 34/60 [00:09<00:06,  3.76it/s]
# ---------In Evaluate---------
# Prompt = tensor([[16885],
#         [   12],
#         [   12],
#         [13500]], device='cuda:0')
# Evaluating:  58%|█████▊    | 35/60 [00:09<00:06,  3.86it/s]
# ---------In Evaluate---------
# Prompt = tensor([[13500],
#         [ 3919],
#         [ 3919],
#         [16885]], device='cuda:0')
# Evaluating:  60%|██████    | 36/60 [00:09<00:06,  3.93it/s]
# ---------In Evaluate---------
# Prompt = tensor([[13500],
#         [13500],
#         [24159],
#         [18712]], device='cuda:0')
# Evaluating:  62%|██████▏   | 37/60 [00:09<00:05,  3.93it/s]
# ---------In Evaluate---------
# Prompt = tensor([[18323],
#         [18323],
#         [31217],
#         [ 2949]], device='cuda:0')
# Evaluating:  63%|██████▎   | 38/60 [00:10<00:05,  3.95it/s]
# ---------In Evaluate---------
# Prompt = tensor([[13500],
#         [ 2949],
#         [   16],
#         [ 3919]], device='cuda:0')
# Evaluating:  65%|██████▌   | 39/60 [00:10<00:05,  3.78it/s]
# ---------In Evaluate---------
# Prompt = tensor([[15526],
#         [ 3919],
#         [13500],
#         [ 9771]], device='cuda:0')
# Evaluating:  67%|██████▋   | 40/60 [00:10<00:05,  3.73it/s]
# ---------In Evaluate---------
# Prompt = tensor([[3919],
#         [2949],
#         [  35],
#         [3919]], device='cuda:0')
# Evaluating:  68%|██████▊   | 41/60 [00:10<00:04,  3.81it/s]
# ---------In Evaluate---------
# Prompt = tensor([[ 3919],
#         [18323],
#         [ 3919],
#         [ 1662]], device='cuda:0')
# Evaluating:  70%|███████   | 42/60 [00:11<00:04,  3.64it/s]
# ---------In Evaluate---------
# Prompt = tensor([[18380],
#         [16885],
#         [   49],
#         [   16]], device='cuda:0')
# Evaluating:  72%|███████▏  | 43/60 [00:11<00:04,  3.71it/s]
# ---------In Evaluate---------
# Prompt = tensor([[13500],
#         [13500],
#         [   76],
#         [   34]], device='cuda:0')
# Evaluating:  73%|███████▎  | 44/60 [00:11<00:04,  3.72it/s]
# ---------In Evaluate---------
# Prompt = tensor([[   35],
#         [49578],
#         [ 2949],
#         [13500]], device='cuda:0')
# Evaluating:  75%|███████▌  | 45/60 [00:12<00:04,  3.62it/s]
# ---------In Evaluate---------
# Prompt = tensor([[13500],
#         [16885],
#         [ 2949],
#         [27498]], device='cuda:0')
# Evaluating:  77%|███████▋  | 46/60 [00:12<00:03,  3.70it/s]
# ---------In Evaluate---------
# Prompt = tensor([[2949],
#         [2949],
#         [  76],
#         [5589]], device='cuda:0')
# Evaluating:  78%|███████▊  | 47/60 [00:12<00:03,  3.66it/s]
# ---------In Evaluate---------
# Prompt = tensor([[ 3919],
#         [13500],
#         [   16],
#         [   46]], device='cuda:0')
# Evaluating:  80%|████████  | 48/60 [00:12<00:03,  3.65it/s]
# ---------In Evaluate---------
# Prompt = tensor([[13500],
#         [ 3849],
#         [   12],
#         [   13]], device='cuda:0')
# Evaluating:  82%|████████▏ | 49/60 [00:13<00:02,  3.70it/s]
# ---------In Evaluate---------
# Prompt = tensor([[   76],
#         [15410],
#         [   49],
#         [ 3861]], device='cuda:0')
# Evaluating:  83%|████████▎ | 50/60 [00:13<00:02,  3.59it/s]
# ---------In Evaluate---------
# Prompt = tensor([[27734],
#         [  418],
#         [31217],
#         [13500]], device='cuda:0')
# Evaluating:  85%|████████▌ | 51/60 [00:13<00:02,  3.74it/s]
# ---------In Evaluate---------
# Prompt = tensor([[12272],
#         [ 9771],
#         [ 3919],
#         [ 3919]], device='cuda:0')
# Evaluating:  87%|████████▋ | 52/60 [00:13<00:02,  3.76it/s]
# ---------In Evaluate---------
# Prompt = tensor([[ 3919],
#         [26069],
#         [   50],
#         [ 3919]], device='cuda:0')
# Evaluating:  88%|████████▊ | 53/60 [00:14<00:01,  3.84it/s]
# ---------In Evaluate---------
# Prompt = tensor([[3919],
#         [3919],
#         [3919],
#         [2949]], device='cuda:0')
# Evaluating:  90%|█████████ | 54/60 [00:14<00:01,  3.81it/s]
# ---------In Evaluate---------
# Prompt = tensor([[   49],
#         [26069],
#         [ 2949],
#         [   82]], device='cuda:0')
# Evaluating:  92%|█████████▏| 55/60 [00:14<00:01,  3.60it/s]
# ---------In Evaluate---------
# Prompt = tensor([[ 3919],
#         [27498],
#         [13500],
#         [ 9771]], device='cuda:0')
# Evaluating:  93%|█████████▎| 56/60 [00:14<00:01,  3.59it/s]
# ---------In Evaluate---------
# Prompt = tensor([[   49],
#         [   12],
#         [49578],
#         [ 3919]], device='cuda:0')
# Evaluating:  95%|█████████▌| 57/60 [00:15<00:00,  3.49it/s]
# ---------In Evaluate---------
# Prompt = tensor([[16885],
#         [ 3919],
#         [ 2949],
#         [26069]], device='cuda:0')
# Evaluating:  97%|█████████▋| 58/60 [00:15<00:00,  3.49it/s]
# ---------In Evaluate---------
# Prompt = tensor([[13500],
#         [ 3919],
#         [ 3919],
#         [13500]], device='cuda:0')
# Evaluating:  98%|█████████▊| 59/60 [00:15<00:00,  3.69it/s]
# ---------In Evaluate---------
# Prompt = tensor([[13500],
#         [ 2302],
#         [ 3919],
#         [   12]], device='cuda:0')
# INFO:sentence_transformers.SentenceTransformer:Use pytorch device_name: cuda
# INFO:sentence_transformers.SentenceTransformer:Load pretrained SentenceTransformer: all-MiniLM-L6-v2
# ---------In Evaluate---------
# Prompt = tensor([[ 3919],
#         [ 2949],
#         [13500],
#         [13500]], device='cuda:0')
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# ========== TEST RESULTS ==========
# Test Loss          : 0.8943
# Test Semantic Sim  : 0.5301
#
# ===== RANDOM TEST EXAMPLES =====
#
# --------In Test--------
#
# Prompt = tensor([[16885]], device='cuda:0')
#
# --- Example 177 ---
# Raw Report       :
# [ Finding ]_x000D_
# both talus, accessory ossicle._x000D_
# _x000D_
# [ Conclusion ]_x000D_
# both talus, accessory ossicle._x000D_
# _x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# both talus, accessory ossicle. <|endoftext|>
# Generated Report :
# both bony lesion.
#
# --------In Test--------
#
# Prompt = tensor([[13500]], device='cuda:0')
#
# --- Example 34 ---
# Raw Report       :
# [ Finding ]_x000D_
# degenerative change._x000D_
# [ Conclusion ]_x000D_
# degenerative change._x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# degenerative change. <|endoftext|>
# Generated Report :
# degenerative change of both feet.
#
# --------In Test--------
#
# Prompt = tensor([[27734]], device='cuda:0')
#
# --- Example 196 ---
# Raw Report       :
# [ Finding ]_x000D_
# LT. os trigonum._x000D_
# degeenrative both feet._x000D_
# [ Conclusion ]_x000D_
# LT. os trigonum._x000D_
# degeenrative both feet._x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# LT. os trigonum. degeenrative both feet. <|endoftext|>
# Generated Report :
# LT. 1st MTP joint, R/O gout
#
# --------In Test--------
#
# Prompt = tensor([[76]], device='cuda:0')
#
# --- Example 103 ---
# Raw Report       :
# [FINDING       ]_x000D_mild degenerative change_x000D__x000D_[CONCLUSION    ]_x000D_mild degenerative change_x000D__x000D_[RECOMMENDATION]_x000D_-
# Cleaned Report   :
# mild degenerative change <|endoftext|>
# Generated Report :
# mild degenerative change
#
# --------In Test--------
#
# Prompt = tensor([[18380]], device='cuda:0')
#
# --- Example 29 ---
# Raw Report       :
# [ Finding ]_x000D_
# _x000D_
# [ Diagnosis ]_x000D_
# Soft tissue swelling in dorsal aspect of left foot._x000D_
# No significant bony abnormality._x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# Soft tissue swelling in dorsal aspect of left foot. No significant bony abnormality. <|endoftext|>
# Generated Report :
# Soft tissue swelling in both 1st MTP.
#
# --------In Test--------
#
# Prompt = tensor([[79]], device='cuda:0')
#
# --- Example 54 ---
# Raw Report       :
# [ Finding ]_x000D_
# possible gout, left big toe._x000D_
# [ Conclusion ]_x000D_
# possible gout, left big toe._x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# possible gout, left big toe. <|endoftext|>
# Generated Report :
# possible bony abnormality
#
# --------In Test--------
#
# Prompt = tensor([[2949]], device='cuda:0')
#
# --- Example 237 ---
# Raw Report       :
# [ Finding ]_x000D_
# No bony abnormality._x000D_
# [ Diagnosis ]_x000D_
# No bony abnormality._x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# No bony abnormality. No bony abnormality. <|endoftext|>
# Generated Report :
# No bony abnormality
#
# --------In Test--------
#
# Prompt = tensor([[3919]], device='cuda:0')
#
# --- Example 118 ---
# Raw Report       :
# [ Finding ]_x000D_
# no significant bony lesion on radiographs._x000D_
# _x000D_
# [ Conclusion ]_x000D_
# no significant bony lesion on radiographs._x000D_
# _x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# no significant bony lesion on radiographs. <|endoftext|>
# Generated Report :
# no bony lesion.
#
# --------In Test--------
#
# Prompt = tensor([[13500]], device='cuda:0')
#
# --- Example 169 ---
# Raw Report       :
# [ Finding ]_x000D_
# degenerative change_x000D_
# Lt tibia, postop. state_x000D_
# [ Conclusion ]_x000D_
# degenerative change_x000D_
# Lt tibia, postop. state_x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# degenerative change Lt tibia, postop. state <|endoftext|>
# Generated Report :
# degenerative change.
#
# --------In Test--------
#
# Prompt = tensor([[18323]], device='cuda:0')
#
# --- Example 144 ---
# Raw Report       :
# [FINDING       ]_x000D_hallux valgus, both
# degenerative change _x000D__x000D_[CONCLUSION    ]_x000D_hallux valgus, both
# degenerative change _x000D__x000D_[RECOMMENDATION]_x000D_-
# Cleaned Report   :
# hallux valgus, both degenerative change <|endoftext|>
# Generated Report :
# hallux valgus, both.

# %%
import os
import re
import json
import logging
import unicodedata
import random
from collections import defaultdict, Counter

import numpy as np
import cv2
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, random_split
from PIL import Image
from torchvision import transforms
from tqdm import tqdm
import timm
from transformers import GPT2Tokenizer, GPT2LMHeadModel
from sentence_transformers import SentenceTransformer
import matplotlib.pyplot as plt

logging.basicConfig(level=logging.INFO)

# =============================================================================
# Utility functions
# =============================================================================

def count_labels(data, target_classes, cfg):
    class_counts = defaultdict(int)
    data_by_class = defaultdict(list)
    for entry in tqdm(data.values(), desc="Counting dataset"):
        lbl = entry.get('class_label', '').lower()
        if lbl in target_classes and os.path.exists(entry['file_path']):
            class_counts[lbl] += 1
            data_by_class[lbl].append(entry)
    return class_counts, data_by_class

def prepare_abnormal_normal_data(data, cfg):
    random.seed(42)
    abnormal = ['ra', 'oa', 'gout']
    normal = ['normal']
    class_counts, data_by_class = count_labels(data, abnormal + normal, cfg)
    combined = {
        'abnormal': sum((data_by_class[c] for c in abnormal), []),
        'normal': data_by_class['normal']
    }
    combined_counts = {
        'abnormal': sum(class_counts[c] for c in abnormal),
        'normal': class_counts['normal']
    }
    if not cfg.DATASET.BALANCE and not cfg.DATASET.AUGMENT:
        return sum(combined.values(), []), combined_counts, combined_counts
    min_count = min(combined_counts.values())
    balanced = []
    final_counts = {}
    for lbl, items in combined.items():
        sampled = random.sample(items, min_count)
        balanced.extend(sampled)
        final_counts[lbl] = min_count
    if cfg.DATASET.AUGMENT:
        balanced *= 2
    return balanced, combined_counts, final_counts

def prepare_data(data, target_classes, cfg, is_binary=False):
    random.seed(42)
    if len(target_classes) == 2 and 'abnormal' in target_classes and 'normal' in target_classes:
        logging.info("Using abnormal-vs-normal logic")
        return prepare_abnormal_normal_data(data, cfg)
    class_counts, data_by_class = count_labels(data, target_classes, cfg)
    logging.info(f"Original class distribution: {class_counts}")
    if not cfg.DATASET.BALANCE and not cfg.DATASET.AUGMENT:
        return sum(data_by_class.values(), []), class_counts, class_counts
    min_count = min(class_counts.values())
    balanced, final_counts = [], {}
    for lbl in target_classes:
        sampled = random.sample(data_by_class[lbl], min_count)
        balanced.extend(sampled)
        final_counts[lbl] = min_count
    logging.info(f"Balanced class distribution: {final_counts}")
    if cfg.DATASET.AUGMENT:
        balanced *= 2
    return balanced, class_counts, final_counts

# =============================================================================
# Transforms
# =============================================================================

imagenet_mean = [0.485, 0.456, 0.406]
imagenet_std = [0.229, 0.224, 0.225]

train_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(imagenet_mean, imagenet_std)
])

patch_transform = transforms.Compose([
    transforms.Resize((112, 112)),
    transforms.ToTensor(),
    transforms.Normalize(imagenet_mean, imagenet_std)
])

# =============================================================================
# Dataset
# =============================================================================

class FinalSamplesDataset(Dataset):
    def __init__(self, cfg, image_transform=train_transform, patch_transform=patch_transform):
        self.cfg = cfg
        self.image_transform = image_transform
        self.patch_transform = patch_transform

        self.target_classes = cfg.DATASET.TARGET_CLASSES
        if isinstance(self.target_classes, str):
            self.target_classes = self.target_classes.split(",")

        self.is_binary = len(self.target_classes) == 2
        self.abnormal_classify = self.is_binary and 'abnormal' in self.target_classes
        self.abnormal_mapping = (
            {'ra': 'abnormal', 'oa': 'abnormal', 'gout': 'abnormal', 'normal': 'normal'}
            if self.abnormal_classify else None
        )

        with open(cfg.DATASET.JSON, 'r') as f:
            raw_list = json.load(f)

        filtered = []
        for item in raw_list:
            merged = item.get('merged_image_path', '')
            fp = item.get('file_paths', [])
            if isinstance(fp, str):
                fp = [fp]
            paths = [merged] + fp
            if any(os.path.exists(p) for p in paths):
                filtered.append((merged, fp, item))

        self.data = {}
        for i, (merged, fp, item) in enumerate(filtered):
            cls = item.get('class', 'unknown').lower()
            if self.abnormal_mapping:
                cls = self.abnormal_mapping.get(cls, cls)
            self.data[i] = {
                'file_path': merged,
                'left_right_file_path': fp,
                'class_label': cls,
                'diagnosis': item.get('diagnosis', ''),
                'keypoints': item.get('keypoints', {})
            }

        if self.is_binary:
            balanced, _, _ = prepare_data(self.data, self.target_classes, cfg, True)
            self.data = {i: e for i, e in enumerate(balanced)}

        # EOS token placeholder, set later
        self.eos_token = None

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        e = self.data[idx]
        img = Image.open(e['file_path']).convert('RGB')
        img = self.image_transform(img)

        patches = self._gen_patches(e['left_right_file_path'], e['keypoints'])
        pt = [self.patch_transform(Image.fromarray(p)) for p in patches]
        patches_tensor = torch.stack(pt, 0) if pt else torch.zeros(34, 3, 112, 112)

        raw = e.get('diagnosis', '')
        clean = self._clean_report(raw)
        tok = tokenizer(clean, truncation=True, max_length=512, return_tensors='pt')

        return {
            'full_img': img,
            'patches': patches_tensor,
            'raw_report': raw,
            'cleaned_report': clean,
            'input_ids': tok['input_ids'].squeeze(0),
            'attention_mask': tok['attention_mask'].squeeze(0)
        }

    def _gen_patches(self, paths, kps_dict, crop_size=(200, 300), patch_size=(112, 112)):
        def extract(arr, side_kps):
            lst = []
            pts = side_kps[0]['keypoints']
            for i in range(17):
                x, y, s = int(pts[3*i]), int(pts[3*i+1]), pts[3*i+2]
                if s > 0:
                    x0 = max(x - crop_size[0]//2, 0)
                    y0 = max(y - crop_size[1]//2, 0)
                    x1 = min(x + crop_size[0]//2, arr.shape[1])
                    y1 = min(y + crop_size[1]//2, arr.shape[0])
                    c = arr[y0:y1, x0:x1]
                    if c.size:
                        lst.append(cv2.resize(c, patch_size))
            return lst

        def pad17(lst):
            black = np.zeros((patch_size[1], patch_size[0], 3), np.uint8)
            while len(lst) < 17:
                lst.append(black)
            return lst[:17]

        left, right = [], []
        if len(paths) == 1:
            pth = paths[0]
            if not pth or not os.path.exists(pth):
                return pad17([]) + pad17([])
            img_arr = cv2.imread(pth)
            if img_arr is None:
                return pad17([]) + pad17([])
            arr = cv2.cvtColor(img_arr, cv2.COLOR_BGR2RGB)
            if kps_dict.get('left'): left = extract(arr, kps_dict['left'])
            if kps_dict.get('right'): right = extract(arr, kps_dict['right'])
        else:
            for side, pth in zip(['left', 'right'], paths):
                if pth and os.path.exists(pth):
                    img_arr = cv2.imread(pth)
                    if img_arr is not None:
                        arr = cv2.cvtColor(img_arr, cv2.COLOR_BGR2RGB)
                        if kps_dict.get(side):
                            lst = extract(arr, kps_dict[side])
                            if side == 'left': left = lst
                            else: right = lst

        if left and not right:
            right = [cv2.flip(p, 1) for p in left]
        if right and not left:
            left = [cv2.flip(p, 1) for p in right]
        if not left and not right:
            return pad17([]) + pad17([])

        return pad17(left) + pad17(right)

    def _clean_report(self, text):
        # normalize & strip unwanted bits
        text = unicodedata.normalize('NFKC', text or '')
        text = re.sub(r'(?m)^-+\s*$', '', text)
        text = re.sub(r'[^\x00-\x7F]+', ' ', text)
        text = re.sub(r'([.!?]){2,}', r'\1', text)
        text = re.sub(r'\[\s*finding\s*\]', '[FINDING]', text, flags=re.IGNORECASE)
        text = re.sub(r'\[\s*conclusion\s*\]', '[CONCLUSION]', text, flags=re.IGNORECASE)
        text = re.sub(r'\[\s*diagnosis\s*\]', '[DIAGNOSIS]', text, flags=re.IGNORECASE)

        # drop recommendation section
        parts = re.split(r'\[\s*recommend(?:ation)?\s*\]', text, flags=re.IGNORECASE)
        text = parts[0]

        # collapse duplicate finding/conclusion
        fm = re.search(r'\[FINDING\](.*?)(?=\[|$)', text, flags=re.IGNORECASE | re.DOTALL)
        cm = re.search(r'\[CONCLUSION\](.*?)(?=\[|$)', text, flags=re.IGNORECASE | re.DOTALL)
        if fm and cm and fm.group(1).strip().lower() == cm.group(1).strip().lower():
            text = re.sub(r'\[CONCLUSION\].*?(?=\[|$)', '', text, flags=re.IGNORECASE | re.DOTALL)

        # strip remaining tags and clean whitespace
        text = re.sub(r'\[\s*(FINDING|CONCLUSION|DIAGNOSIS)\s*\]', '', text, flags=re.IGNORECASE)
        text = text.replace('_x000D_', ' ')
        text = re.sub(r'\s+', ' ', text).strip()

        # wrap with EOS token at both beginning and end
        if text:
            core = re.sub(re.escape(self.eos_token), '', text).strip()
            text = f"{self.eos_token} {core} {self.eos_token}"
        return text

# =============================================================================
# Collate function
# =============================================================================

def collate_fn(batch):
    imgs = torch.stack([b['full_img'] for b in batch])
    pts = [b['patches'] for b in batch]
    max_p = max(p.shape[0] for p in pts)
    pads = []
    for p in pts:
        if p.shape[0] < max_p:
            pad = torch.zeros((max_p - p.shape[0], *p.shape[1:]))
            p = torch.cat([p, pad], dim=0)
        pads.append(p)
    patches = torch.stack(pads, 0)

    ids = [b['input_ids'] for b in batch]
    masks = [b['attention_mask'] for b in batch]
    ids = nn.utils.rnn.pad_sequence(ids, batch_first=True, padding_value=tokenizer.pad_token_id)
    masks = nn.utils.rnn.pad_sequence(masks, batch_first=True, padding_value=0)

    return {
        'full_imgs': imgs,
        'patches': patches,
        'input_ids': ids,
        'attention_mask': masks,
        'raw_reports': [b['raw_report'] for b in batch],
        'cleaned_reports': [b['cleaned_report'] for b in batch]
    }

# =============================================================================
# Model
# =============================================================================

class MultiModalModel(nn.Module):
    def __init__(self, gpt2_model_name='gpt2'):
        super().__init__()
        self.global_encoder = timm.create_model('swin_base_patch4_window7_224', pretrained=True)
        self.global_encoder.reset_classifier(0)
        self.global_proj = nn.Linear(self.global_encoder.num_features, 768)

        self.patch_encoder = timm.create_model('resnet50', pretrained=True)
        self.patch_encoder.fc = nn.Identity()
        self.patch_proj = nn.Linear(self.patch_encoder.num_features, 768)

        self.attn = nn.MultiheadAttention(embed_dim=768, num_heads=8, batch_first=True)
        self.norm = nn.LayerNorm(768)

        self.decoder = GPT2LMHeadModel.from_pretrained(gpt2_model_name, add_cross_attention=True)

    def _pool(self, feats):
        return feats.mean(dim=[2, 3]) if feats.ndim > 2 else feats

    def forward(self, imgs, patches, input_ids, attention_mask, decoder_labels=None):
        g = self.global_encoder(imgs)
        g = self.global_proj(g).unsqueeze(1)

        B, N, C, H, W = patches.shape
        p = patches.view(B * N, C, H, W)
        pf = (self.patch_encoder.forward_features(p)
              if hasattr(self.patch_encoder, 'forward_features')
              else self.patch_encoder(p))
        pf = self._pool(pf)
        pf = self.patch_proj(pf)
        pf = pf.view(B, N, 768)

        cat = torch.cat([g, pf], dim=1)
        comb, _ = self.attn(cat, cat, cat)
        comb = self.norm(comb)

        return self.decoder(
            input_ids=input_ids,
            attention_mask=attention_mask,
            encoder_hidden_states=comb,
            labels=decoder_labels
        )

# =============================================================================
# Train / Eval helpers
# =============================================================================

def train_epoch(model, loader, optimizer, scaler, device):
    model.train()
    total_loss = 0.0
    for b in tqdm(loader, desc="Training", leave=False):
        imgs = b['full_imgs'].to(device)
        pts = b['patches'].to(device)
        ids = b['input_ids'].to(device)
        msk = b['attention_mask'].to(device)

        optimizer.zero_grad()
        with torch.cuda.amp.autocast():
            out = model(imgs, pts, ids, msk, decoder_labels=ids)
            loss = out.loss
        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()
        total_loss += loss.item()
    return total_loss / len(loader)

def evaluate(model, loader, device):
    model.eval()
    total_loss = 0.0
    all_gen, all_gt = [], []

    for b in tqdm(loader, desc="Evaluating", leave=False):
        imgs = b['full_imgs'].to(device)
        pts = b['patches'].to(device)
        ids = b['input_ids'].to(device)
        msk = b['attention_mask'].to(device)

        with torch.no_grad():
            out = model(imgs, pts, ids, msk, decoder_labels=ids)
            total_loss += out.loss.item()

            prompt = ids[:, :1]
            #print(f'-- Prompt : {prompt}')

            g = model.global_encoder(imgs)
            g = model.global_proj(g).unsqueeze(1)

            B, N, C, H, W = pts.shape
            p = pts.view(B * N, C, H, W)
            pf = (model.patch_encoder.forward_features(p)
                  if hasattr(model.patch_encoder, 'forward_features')
                  else model.patch_encoder(p))
            pf = model._pool(pf)
            pf = model.patch_proj(pf)
            pf = pf.view(B, N, 768)

            cat = torch.cat([g, pf], dim=1)
            comb, _ = model.attn(cat, cat, cat)
            comb = model.norm(comb)

            gen_ids = model.decoder.generate(
                input_ids=prompt,
                encoder_hidden_states=comb,
                attention_mask=torch.ones_like(prompt),
                max_length=100,
                do_sample=True,
                top_k=50,
                top_p=0.95,
                temperature=0.7,
                repetition_penalty=1.2,
                eos_token_id=tokenizer.eos_token_id,
                pad_token_id=tokenizer.eos_token_id
            )

            gen_txt = [tokenizer.decode(g_, skip_special_tokens=True) for g_ in gen_ids]
            gt_txt = [tokenizer.decode(i_, skip_special_tokens=True) for i_ in ids]
            all_gen.extend(gen_txt)
            all_gt.extend(gt_txt)

    return total_loss / len(loader), all_gen, all_gt

def compute_semantic_similarity(gen, gt):
    stm = SentenceTransformer('all-MiniLM-L6-v2')
    e1 = stm.encode(gen, convert_to_tensor=True)
    e2 = stm.encode(gt, convert_to_tensor=True)
    return nn.functional.cosine_similarity(e1, e2).mean().item()

def plot_metrics(train_losses, val_losses, sems):
    epochs = range(1, len(train_losses) + 1)
    plt.figure(figsize=(12, 5))

    plt.subplot(1, 2, 1)
    plt.plot(epochs, train_losses, label="Train Loss")
    plt.plot(epochs, val_losses, label="Validation Loss")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(epochs, sems, label="Semantic Similarity")
    plt.xlabel("Epoch")
    plt.ylabel("Similarity")
    plt.legend()

    plt.tight_layout()
    plt.show()

# =============================================================================
# MAIN
# =============================================================================

class Cfg: pass
cfg = Cfg()
cfg.DATASET = Cfg()
cfg.DATASET.JSON = 'final_samples_both_only_v2.json'
cfg.DATASET.USE_RAW = True
cfg.DATASET.USE_PATCH = True
cfg.DATASET.REPORT = True
cfg.DATASET.TARGET_CLASSES = ['ra', 'oa', 'gout', 'normal', 'uncertain', 'ref.prev']
cfg.DATASET.BALANCE = False
cfg.DATASET.AUGMENT = False

tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
tokenizer.pad_token = tokenizer.eos_token
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

dataset = FinalSamplesDataset(cfg)
# now that dataset exists, set its eos_token for cleaning
dataset.eos_token = tokenizer.eos_token

dist = Counter(e['class_label'] for e in dataset.data.values())
print("\nDataset class distribution:")
for cls, cnt in dist.items():
    print(f"  {cls}: {cnt}")

# split into train / val / test
n = len(dataset)
n_train = int(0.8 * n)
n_val = int(0.1 * n)
n_test = n - n_train - n_val

train_ds, val_ds, test_ds = random_split(dataset, [n_train, n_val, n_test])

print(f"\nNumber of training samples:   {len(train_ds)}")
print(f"Number of validation samples: {len(val_ds)}")
print(f"Number of test samples:       {len(test_ds)}")
print(f"Total samples:                {len(train_ds) + len(val_ds) + len(test_ds)}\n")

train_loader = DataLoader(train_ds, batch_size=4, shuffle=True, collate_fn=collate_fn)
val_loader = DataLoader(val_ds, batch_size=4, shuffle=False, collate_fn=collate_fn)
test_loader = DataLoader(test_ds, batch_size=4, shuffle=False, collate_fn=collate_fn)

model = MultiModalModel().to(device)
optimizer = optim.AdamW(model.parameters(), lr=5e-5)
scheduler = torch.optim.lr_scheduler.CosineAnnealingWarmRestarts(optimizer, T_0=10, T_mult=2)
scaler = torch.cuda.amp.GradScaler()

num_epochs = 10
train_losses, val_losses, sems = [], [], []

for epoch in range(num_epochs):
    print(f"\nEpoch {epoch + 1}/{num_epochs}")
    train_loss = train_epoch(model, train_loader, optimizer, scaler, device)
    val_loss, gen_txt, gt_txt = evaluate(model, val_loader, device)
    sem = compute_semantic_similarity(gen_txt, gt_txt)

    train_losses.append(train_loss)
    val_losses.append(val_loss)
    sems.append(sem)

    print(f"  Train Loss          : {train_loss:.4f}")
    print(f"  Validation Loss     : {val_loss:.4f}")
    print(f"  Semantic Similarity : {sem:.4f}")
    scheduler.step()

plot_metrics(train_losses, val_losses, sems)

test_loss, test_gen, test_gt = evaluate(model, test_loader, device)
test_sem = compute_semantic_similarity(test_gen, test_gt)

print("\n========== TEST RESULTS ==========")
print(f"Test Loss          : {test_loss:.4f}")
print(f"Test Semantic Sim  : {test_sem:.4f}")

print("\n===== RANDOM TEST EXAMPLES =====")
for idx in random.sample(range(len(test_ds)), min(10, len(test_ds))):
    ex = test_ds[idx]
    raw = ex['raw_report']
    clean = ex['cleaned_report']
    fi = ex['full_img'].unsqueeze(0).to(device)
    pa = ex['patches'].unsqueeze(0).to(device)
    prompt = ex['input_ids'][:1].unsqueeze(0).to(device)

    print(f'Prompt = {prompt}')

    g = model.global_encoder(fi)
    g = model.global_proj(g).unsqueeze(1)
    B, N, C, H, W = pa.shape
    p = pa.view(B * N, C, H, W)
    pf = model.patch_encoder(p)
    pf = model._pool(pf)
    pf = model.patch_proj(pf)
    pf = pf.view(B, N, 768)

    cat = torch.cat([g, pf], dim=1)
    comb, _ = model.attn(cat, cat, cat)
    comb = model.norm(comb)

    gen_ids = model.decoder.generate(
        input_ids=prompt,
        encoder_hidden_states=comb,
        attention_mask=torch.ones_like(prompt),
        max_length=120,
        do_sample=True,
        top_k=40,
        top_p=0.95,
        temperature=0.5,
        repetition_penalty=1.3,
        eos_token_id=tokenizer.eos_token_id,
        pad_token_id=tokenizer.eos_token_id
    )

    gen = tokenizer.decode(gen_ids[0], skip_special_tokens=True)

    print(f"\n--- Example {idx} ---")
    print(f"Raw Report       : \n{raw}")
    print(f"Cleaned Report   : \n{clean}")
    print(f"Generated Report : \n{gen}")
# Out:
# Using device: cuda
#
# Dataset class distribution:
#   oa: 573
#   ra: 115
#   uncertain: 620
#   oa, ra: 8
#   normal: 748
#   gout: 267
#   combination of oa, ra: 3
#   ref.prev: 60
#
# Number of training samples:   1915
# Number of validation samples: 239
# Number of test samples:       240
# Total samples:                2394
# INFO:timm.models._builder:Loading pretrained weights from Hugging Face hub (timm/swin_base_patch4_window7_224.ms_in22k_ft_in1k)
# INFO:timm.models._hub:[timm/swin_base_patch4_window7_224.ms_in22k_ft_in1k] Safe alternative available for 'pytorch_model.bin' (as 'model.safetensors'). Loading weights using safetensors.
# INFO:timm.models._builder:Loading pretrained weights from Hugging Face hub (timm/resnet50.a1_in1k)
# INFO:timm.models._hub:[timm/resnet50.a1_in1k] Safe alternative available for 'pytorch_model.bin' (as 'model.safetensors'). Loading weights using safetensors.
# Some weights of GPT2LMHeadModel were not initialized from the model checkpoint at gpt2 and are newly initialized: ['h.0.crossattention.c_attn.bias', 'h.0.crossattention.c_attn.weight', 'h.0.crossattention.c_proj.bias', 'h.0.crossattention.c_proj.weight', 'h.0.crossattention.q_attn.bias', 'h.0.crossattention.q_attn.weight', 'h.0.ln_cross_attn.bias', 'h.0.ln_cross_attn.weight', 'h.1.crossattention.c_attn.bias', 'h.1.crossattention.c_attn.weight', 'h.1.crossattention.c_proj.bias', 'h.1.crossattention.c_proj.weight', 'h.1.crossattention.q_attn.bias', 'h.1.crossattention.q_attn.weight', 'h.1.ln_cross_attn.bias', 'h.1.ln_cross_attn.weight', 'h.10.crossattention.c_attn.bias', 'h.10.crossattention.c_attn.weight', 'h.10.crossattention.c_proj.bias', 'h.10.crossattention.c_proj.weight', 'h.10.crossattention.q_attn.bias', 'h.10.crossattention.q_attn.weight', 'h.10.ln_cross_attn.bias', 'h.10.ln_cross_attn.weight', 'h.11.crossattention.c_attn.bias', 'h.11.crossattention.c_attn.weight', 'h.11.crossattention.c_proj.bias', 'h.11.crossattention.c_proj.weight', 'h.11.crossattention.q_attn.bias', 'h.11.crossattention.q_attn.weight', 'h.11.ln_cross_attn.bias', 'h.11.ln_cross_attn.weight', 'h.2.crossattention.c_attn.bias', 'h.2.crossattention.c_attn.weight', 'h.2.crossattention.c_proj.bias', 'h.2.crossattention.c_proj.weight', 'h.2.crossattention.q_attn.bias', 'h.2.crossattention.q_attn.weight', 'h.2.ln_cross_attn.bias', 'h.2.ln_cross_attn.weight', 'h.3.crossattention.c_attn.bias', 'h.3.crossattention.c_attn.weight', 'h.3.crossattention.c_proj.bias', 'h.3.crossattention.c_proj.weight', 'h.3.crossattention.q_attn.bias', 'h.3.crossattention.q_attn.weight', 'h.3.ln_cross_attn.bias', 'h.3.ln_cross_attn.weight', 'h.4.crossattention.c_attn.bias', 'h.4.crossattention.c_attn.weight', 'h.4.crossattention.c_proj.bias', 'h.4.crossattention.c_proj.weight', 'h.4.crossattention.q_attn.bias', 'h.4.crossattention.q_attn.weight', 'h.4.ln_cross_attn.bias', 'h.4.ln_cross_attn.weight', 'h.5.crossattention.c_attn.bias', 'h.5.crossattention.c_attn.weight', 'h.5.crossattention.c_proj.bias', 'h.5.crossattention.c_proj.weight', 'h.5.crossattention.q_attn.bias', 'h.5.crossattention.q_attn.weight', 'h.5.ln_cross_attn.bias', 'h.5.ln_cross_attn.weight', 'h.6.crossattention.c_attn.bias', 'h.6.crossattention.c_attn.weight', 'h.6.crossattention.c_proj.bias', 'h.6.crossattention.c_proj.weight', 'h.6.crossattention.q_attn.bias', 'h.6.crossattention.q_attn.weight', 'h.6.ln_cross_attn.bias', 'h.6.ln_cross_attn.weight', 'h.7.crossattention.c_attn.bias', 'h.7.crossattention.c_attn.weight', 'h.7.crossattention.c_proj.bias', 'h.7.crossattention.c_proj.weight', 'h.7.crossattention.q_attn.bias', 'h.7.crossattention.q_attn.weight', 'h.7.ln_cross_attn.bias', 'h.7.ln_cross_attn.weight', 'h.8.crossattention.c_attn.bias', 'h.8.crossattention.c_attn.weight', 'h.8.crossattention.c_proj.bias', 'h.8.crossattention.c_proj.weight', 'h.8.crossattention.q_attn.bias', 'h.8.crossattention.q_attn.weight', 'h.8.ln_cross_attn.bias', 'h.8.ln_cross_attn.weight', 'h.9.crossattention.c_attn.bias', 'h.9.crossattention.c_attn.weight', 'h.9.crossattention.c_proj.bias', 'h.9.crossattention.c_proj.weight', 'h.9.crossattention.q_attn.bias', 'h.9.crossattention.q_attn.weight', 'h.9.ln_cross_attn.bias', 'h.9.ln_cross_attn.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /tmp/ipykernel_44858/1818317765.py:497: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler()
# Epoch 1/10
# Training:   0%|          | 0/479 [00:00<?, ?it/s]/tmp/ipykernel_44858/1818317765.py:358: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# Evaluating:   0%|          | 0/60 [00:00<?, ?it/s]         A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:   2%|▏         | 1/60 [00:00<00:34,  1.73it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:   3%|▎         | 2/60 [00:01<00:32,  1.78it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:   5%|▌         | 3/60 [00:01<00:31,  1.80it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:   7%|▋         | 4/60 [00:02<00:31,  1.78it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:   8%|▊         | 5/60 [00:02<00:30,  1.79it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  10%|█         | 6/60 [00:03<00:30,  1.79it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  12%|█▏        | 7/60 [00:03<00:29,  1.79it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  13%|█▎        | 8/60 [00:04<00:29,  1.79it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  15%|█▌        | 9/60 [00:05<00:28,  1.78it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  17%|█▋        | 10/60 [00:05<00:28,  1.76it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  18%|█▊        | 11/60 [00:06<00:27,  1.76it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  20%|██        | 12/60 [00:06<00:27,  1.77it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  22%|██▏       | 13/60 [00:07<00:26,  1.75it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  23%|██▎       | 14/60 [00:07<00:26,  1.72it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  25%|██▌       | 15/60 [00:08<00:25,  1.74it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  27%|██▋       | 16/60 [00:09<00:25,  1.73it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  28%|██▊       | 17/60 [00:09<00:24,  1.75it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  30%|███       | 18/60 [00:10<00:24,  1.74it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  32%|███▏      | 19/60 [00:10<00:23,  1.77it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  33%|███▎      | 20/60 [00:11<00:22,  1.74it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  35%|███▌      | 21/60 [00:11<00:22,  1.76it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  37%|███▋      | 22/60 [00:12<00:21,  1.77it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  38%|███▊      | 23/60 [00:13<00:20,  1.78it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  40%|████      | 24/60 [00:13<00:20,  1.75it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  42%|████▏     | 25/60 [00:14<00:19,  1.76it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  43%|████▎     | 26/60 [00:14<00:19,  1.73it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  45%|████▌     | 27/60 [00:15<00:18,  1.74it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  47%|████▋     | 28/60 [00:15<00:18,  1.75it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  48%|████▊     | 29/60 [00:16<00:17,  1.77it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  50%|█████     | 30/60 [00:17<00:16,  1.77it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  52%|█████▏    | 31/60 [00:17<00:16,  1.78it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  53%|█████▎    | 32/60 [00:18<00:15,  1.75it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  55%|█████▌    | 33/60 [00:18<00:15,  1.73it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  57%|█████▋    | 34/60 [00:19<00:14,  1.74it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  58%|█████▊    | 35/60 [00:19<00:14,  1.74it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  60%|██████    | 36/60 [00:20<00:13,  1.74it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  62%|██████▏   | 37/60 [00:21<00:13,  1.76it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  63%|██████▎   | 38/60 [00:21<00:12,  1.78it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  65%|██████▌   | 39/60 [00:22<00:11,  1.78it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  67%|██████▋   | 40/60 [00:22<00:11,  1.75it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  68%|██████▊   | 41/60 [00:23<00:10,  1.75it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  70%|███████   | 42/60 [00:23<00:10,  1.76it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  72%|███████▏  | 43/60 [00:24<00:09,  1.75it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  73%|███████▎  | 44/60 [00:25<00:09,  1.74it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  75%|███████▌  | 45/60 [00:25<00:08,  1.71it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  77%|███████▋  | 46/60 [00:26<00:08,  1.72it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  78%|███████▊  | 47/60 [00:26<00:07,  1.74it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  80%|████████  | 48/60 [00:27<00:06,  1.72it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  82%|████████▏ | 49/60 [00:27<00:06,  1.74it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  83%|████████▎ | 50/60 [00:28<00:05,  1.75it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  85%|████████▌ | 51/60 [00:29<00:05,  1.75it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  87%|████████▋ | 52/60 [00:29<00:04,  1.73it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  88%|████████▊ | 53/60 [00:30<00:04,  1.75it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  90%|█████████ | 54/60 [00:30<00:03,  1.76it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  92%|█████████▏| 55/60 [00:31<00:02,  1.78it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  93%|█████████▎| 56/60 [00:31<00:02,  1.78it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  95%|█████████▌| 57/60 [00:32<00:01,  1.79it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  97%|█████████▋| 58/60 [00:33<00:01,  1.75it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  98%|█████████▊| 59/60 [00:33<00:00,  1.76it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# INFO:sentence_transformers.SentenceTransformer:Use pytorch device_name: cuda
# INFO:sentence_transformers.SentenceTransformer:Load pretrained SentenceTransformer: all-MiniLM-L6-v2
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
#   Train Loss          : 1.3412
#   Validation Loss     : 0.8367
#   Semantic Similarity : 0.4243
#
# Epoch 2/10
# Evaluating:   0%|          | 0/60 [00:00<?, ?it/s]         A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:   2%|▏         | 1/60 [00:00<00:33,  1.77it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:   3%|▎         | 2/60 [00:01<00:32,  1.80it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:   5%|▌         | 3/60 [00:01<00:31,  1.80it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:   7%|▋         | 4/60 [00:02<00:31,  1.77it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:   8%|▊         | 5/60 [00:02<00:30,  1.79it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  10%|█         | 6/60 [00:03<00:30,  1.76it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  12%|█▏        | 7/60 [00:03<00:29,  1.78it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  13%|█▎        | 8/60 [00:04<00:29,  1.78it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  15%|█▌        | 9/60 [00:05<00:28,  1.78it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  17%|█▋        | 10/60 [00:05<00:28,  1.76it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  18%|█▊        | 11/60 [00:06<00:27,  1.75it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  20%|██        | 12/60 [00:06<00:27,  1.77it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  22%|██▏       | 13/60 [00:07<00:26,  1.75it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  23%|██▎       | 14/60 [00:07<00:26,  1.72it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  25%|██▌       | 15/60 [00:08<00:25,  1.74it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  27%|██▋       | 16/60 [00:09<00:25,  1.73it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  28%|██▊       | 17/60 [00:09<00:24,  1.75it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  30%|███       | 18/60 [00:10<00:24,  1.74it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  32%|███▏      | 19/60 [00:10<00:23,  1.77it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  33%|███▎      | 20/60 [00:11<00:22,  1.74it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  35%|███▌      | 21/60 [00:11<00:22,  1.76it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  37%|███▋      | 22/60 [00:12<00:21,  1.76it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  38%|███▊      | 23/60 [00:13<00:21,  1.76it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  40%|████      | 24/60 [00:13<00:20,  1.72it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  42%|████▏     | 25/60 [00:14<00:20,  1.72it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  43%|████▎     | 26/60 [00:14<00:20,  1.70it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  45%|████▌     | 27/60 [00:15<00:19,  1.72it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  47%|████▋     | 28/60 [00:15<00:18,  1.74it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  48%|████▊     | 29/60 [00:16<00:17,  1.77it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  50%|█████     | 30/60 [00:17<00:16,  1.78it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  52%|█████▏    | 31/60 [00:17<00:16,  1.78it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  53%|█████▎    | 32/60 [00:18<00:15,  1.76it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  55%|█████▌    | 33/60 [00:18<00:15,  1.73it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  57%|█████▋    | 34/60 [00:19<00:14,  1.74it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  58%|█████▊    | 35/60 [00:19<00:14,  1.75it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  60%|██████    | 36/60 [00:20<00:14,  1.69it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  62%|██████▏   | 37/60 [00:21<00:13,  1.69it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  63%|██████▎   | 38/60 [00:21<00:12,  1.71it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  65%|██████▌   | 39/60 [00:22<00:12,  1.73it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  67%|██████▋   | 40/60 [00:22<00:11,  1.72it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  68%|██████▊   | 41/60 [00:23<00:10,  1.74it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  70%|███████   | 42/60 [00:24<00:10,  1.76it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  72%|███████▏  | 43/60 [00:24<00:09,  1.75it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  73%|███████▎  | 44/60 [00:25<00:09,  1.75it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  75%|███████▌  | 45/60 [00:25<00:08,  1.72it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  77%|███████▋  | 46/60 [00:26<00:08,  1.73it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  78%|███████▊  | 47/60 [00:26<00:07,  1.75it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  80%|████████  | 48/60 [00:27<00:06,  1.73it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  82%|████████▏ | 49/60 [00:28<00:06,  1.76it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  83%|████████▎ | 50/60 [00:28<00:05,  1.76it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  85%|████████▌ | 51/60 [00:29<00:05,  1.76it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  87%|████████▋ | 52/60 [00:29<00:04,  1.74it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  88%|████████▊ | 53/60 [00:30<00:03,  1.76it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  90%|█████████ | 54/60 [00:30<00:03,  1.78it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  92%|█████████▏| 55/60 [00:31<00:02,  1.80it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  93%|█████████▎| 56/60 [00:31<00:02,  1.80it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  95%|█████████▌| 57/60 [00:32<00:01,  1.79it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  97%|█████████▋| 58/60 [00:33<00:01,  1.76it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  98%|█████████▊| 59/60 [00:33<00:00,  1.77it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# INFO:sentence_transformers.SentenceTransformer:Use pytorch device_name: cuda
# INFO:sentence_transformers.SentenceTransformer:Load pretrained SentenceTransformer: all-MiniLM-L6-v2
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
#   Train Loss          : 0.8580
#   Validation Loss     : 0.7611
#   Semantic Similarity : 0.4346
#
# Epoch 3/10
# Evaluating:   0%|          | 0/60 [00:00<?, ?it/s]         A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:   2%|▏         | 1/60 [00:00<00:33,  1.76it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:   3%|▎         | 2/60 [00:01<00:32,  1.79it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:   5%|▌         | 3/60 [00:01<00:31,  1.80it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:   7%|▋         | 4/60 [00:02<00:31,  1.77it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:   8%|▊         | 5/60 [00:02<00:30,  1.79it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  10%|█         | 6/60 [00:03<00:30,  1.79it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  12%|█▏        | 7/60 [00:03<00:29,  1.79it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  13%|█▎        | 8/60 [00:04<00:29,  1.79it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  15%|█▌        | 9/60 [00:05<00:28,  1.78it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  17%|█▋        | 10/60 [00:05<00:28,  1.76it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  18%|█▊        | 11/60 [00:06<00:27,  1.76it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  20%|██        | 12/60 [00:06<00:27,  1.77it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  22%|██▏       | 13/60 [00:07<00:26,  1.76it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  23%|██▎       | 14/60 [00:07<00:26,  1.72it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  25%|██▌       | 15/60 [00:08<00:25,  1.74it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  27%|██▋       | 16/60 [00:09<00:25,  1.73it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  28%|██▊       | 17/60 [00:09<00:24,  1.75it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  30%|███       | 18/60 [00:10<00:24,  1.73it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  32%|███▏      | 19/60 [00:10<00:23,  1.76it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  33%|███▎      | 20/60 [00:11<00:22,  1.74it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  35%|███▌      | 21/60 [00:11<00:22,  1.76it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  37%|███▋      | 22/60 [00:12<00:21,  1.77it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  38%|███▊      | 23/60 [00:13<00:20,  1.77it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  40%|████      | 24/60 [00:13<00:20,  1.75it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  42%|████▏     | 25/60 [00:14<00:19,  1.76it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  43%|████▎     | 26/60 [00:14<00:19,  1.72it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  45%|████▌     | 27/60 [00:15<00:19,  1.74it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  47%|████▋     | 28/60 [00:15<00:18,  1.75it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  48%|████▊     | 29/60 [00:16<00:17,  1.77it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  50%|█████     | 30/60 [00:17<00:16,  1.78it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  52%|█████▏    | 31/60 [00:17<00:16,  1.78it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  53%|█████▎    | 32/60 [00:18<00:15,  1.76it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  55%|█████▌    | 33/60 [00:18<00:15,  1.74it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  57%|█████▋    | 34/60 [00:19<00:14,  1.74it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  58%|█████▊    | 35/60 [00:19<00:14,  1.75it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  60%|██████    | 36/60 [00:20<00:13,  1.75it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  62%|██████▏   | 37/60 [00:21<00:13,  1.76it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  63%|██████▎   | 38/60 [00:21<00:12,  1.78it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  65%|██████▌   | 39/60 [00:22<00:11,  1.77it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  67%|██████▋   | 40/60 [00:22<00:11,  1.75it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  68%|██████▊   | 41/60 [00:23<00:10,  1.75it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  70%|███████   | 42/60 [00:23<00:10,  1.77it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  72%|███████▏  | 43/60 [00:24<00:09,  1.75it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  73%|███████▎  | 44/60 [00:25<00:09,  1.74it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  75%|███████▌  | 45/60 [00:25<00:08,  1.71it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  77%|███████▋  | 46/60 [00:26<00:08,  1.72it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  78%|███████▊  | 47/60 [00:26<00:07,  1.74it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  80%|████████  | 48/60 [00:27<00:06,  1.72it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  82%|████████▏ | 49/60 [00:27<00:06,  1.74it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  83%|████████▎ | 50/60 [00:28<00:05,  1.75it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  85%|████████▌ | 51/60 [00:29<00:05,  1.75it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  87%|████████▋ | 52/60 [00:29<00:04,  1.73it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  88%|████████▊ | 53/60 [00:30<00:04,  1.74it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  90%|█████████ | 54/60 [00:30<00:03,  1.77it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  92%|█████████▏| 55/60 [00:31<00:02,  1.79it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  93%|█████████▎| 56/60 [00:31<00:02,  1.79it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  95%|█████████▌| 57/60 [00:32<00:01,  1.79it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  97%|█████████▋| 58/60 [00:33<00:01,  1.75it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  98%|█████████▊| 59/60 [00:33<00:00,  1.76it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# INFO:sentence_transformers.SentenceTransformer:Use pytorch device_name: cuda
# INFO:sentence_transformers.SentenceTransformer:Load pretrained SentenceTransformer: all-MiniLM-L6-v2
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
#   Train Loss          : 0.7515
#   Validation Loss     : 0.7439
#   Semantic Similarity : 0.4213
#
# Epoch 4/10
# Evaluating:   0%|          | 0/60 [00:00<?, ?it/s]         A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# ...
# Evaluating:  45%|████▌     | 27/60 [00:14<00:18,  1.79it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  47%|████▋     | 28/60 [00:15<00:17,  1.82it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  48%|████▊     | 29/60 [00:15<00:17,  1.81it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  50%|█████     | 30/60 [00:16<00:16,  1.79it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  52%|█████▏    | 31/60 [00:17<00:16,  1.79it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  53%|█████▎    | 32/60 [00:17<00:15,  1.76it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  55%|█████▌    | 33/60 [00:18<00:15,  1.76it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  57%|█████▋    | 34/60 [00:18<00:14,  1.77it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  58%|█████▊    | 35/60 [00:19<00:14,  1.78it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  60%|██████    | 36/60 [00:19<00:13,  1.79it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  62%|██████▏   | 37/60 [00:20<00:12,  1.80it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  63%|██████▎   | 38/60 [00:21<00:12,  1.81it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  65%|██████▌   | 39/60 [00:21<00:09,  2.18it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  67%|██████▋   | 40/60 [00:21<00:09,  2.05it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  68%|██████▊   | 41/60 [00:22<00:09,  1.97it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  70%|███████   | 42/60 [00:22<00:09,  1.93it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  72%|███████▏  | 43/60 [00:23<00:07,  2.26it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  73%|███████▎  | 44/60 [00:23<00:07,  2.11it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  75%|███████▌  | 45/60 [00:24<00:07,  1.98it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  77%|███████▋  | 46/60 [00:24<00:07,  1.92it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  78%|███████▊  | 47/60 [00:25<00:06,  1.89it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  80%|████████  | 48/60 [00:25<00:06,  1.89it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  82%|████████▏ | 49/60 [00:26<00:05,  1.86it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  83%|████████▎ | 50/60 [00:27<00:05,  1.84it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  85%|████████▌ | 51/60 [00:27<00:04,  1.84it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  87%|████████▋ | 52/60 [00:27<00:03,  2.08it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  88%|████████▊ | 53/60 [00:28<00:02,  2.36it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  90%|█████████ | 54/60 [00:28<00:02,  2.11it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  92%|█████████▏| 55/60 [00:29<00:02,  2.00it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  93%|█████████▎| 56/60 [00:29<00:02,  1.92it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  95%|█████████▌| 57/60 [00:30<00:01,  2.25it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  97%|█████████▋| 58/60 [00:30<00:00,  2.04it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  98%|█████████▊| 59/60 [00:31<00:00,  1.99it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# INFO:sentence_transformers.SentenceTransformer:Use pytorch device_name: cuda
# INFO:sentence_transformers.SentenceTransformer:Load pretrained SentenceTransformer: all-MiniLM-L6-v2
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# ========== TEST RESULTS ==========
# Test Loss          : 0.8039
# Test Semantic Sim  : 0.4240
#
# ===== RANDOM TEST EXAMPLES =====
# Prompt = tensor([[50256]], device='cuda:0')
#
# --- Example 66 ---
# Raw Report       :
# [ Finding ]_x000D_
# _x000D_
# [ Diagnosis ]_x000D_
# tiny osteophyte of right 1st MTP joint._x000D_
# enthesophytes of both calcaneal tuberosity._x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# <|endoftext|> tiny osteophyte of right 1st MTP joint. enthesophytes of both calcaneal tuberosity. <|endoftext|>
# Generated Report :
#  no bony lesion. -------- No interval change since last study: possible gout, both feet or ankles with soft tissue swelling --> R/O stress fracture vs. old avulsion injury such as achilles tendon insertion site-related bone erosion rather than sclerotic rim involvement at latissimus dorsi and intertarsal joints -> RA related degenerative changes cannot be excluded otherwise without significant body mass abnormality on multiple radiographs of tibiotalar joint space narrowing in medial aspect (right 1st IP). --- rec) clinical correlation base subluxation periart
# Prompt = tensor([[50256]], device='cuda:0')
#
# --- Example 180 ---
# Raw Report       :
# [FINDING       ]_x000D_gout arthritis, both 1st MTP joints._x000D__x000D_[CONCLUSION    ]_x000D_gout arthritis, both 1st MTP joints._x000D__x000D_[RECOMMENDATION]_x000D_-
# Cleaned Report   :
# <|endoftext|> gout arthritis, both 1st MTP joints. <|endoftext|>
# Generated Report :
#  degenerative change -------- hallux valgus, both Degenerous cystic changes diffuse osteopenia suspicious erosion at Rt 1st MTP joint -> r/o inflammatory arthritis involvement tophi - tibia and possibly fibular old fracture with union improved soft tissue swelling around Lt 5th MT head base --> gouty mild traumatic syndrome (RT) severe OA , advanced RA patient condition progressed state since last study no significant interval increase sinde rec> consider F-I Diffuse ankle deformity flat foot disease such as erosions or subluxation Halluc
# Prompt = tensor([[50256]], device='cuda:0')
#
# --- Example 179 ---
# Raw Report       :
# [ Finding ]_x000D_
# Soft tissue swelling in lateral aspect of left ankle._x000D_
# small osteophyte, both 1st MTP joints._x000D_
# [ Diagnosis ]_x000D_
# _x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# <|endoftext|> Soft tissue swelling in lateral aspect of left ankle. small osteophyte, both 1st MTP joints. <|endoftext|>
# Generated Report :
#  No bony abnormality. -------- bone . soft tissue , no significant interval change since last study. Rt. 1st MTP joint, suspicious gout involvement of both feet and hands with subtle increased opacity --> Possible bipartite medial sesamoid rather than fracture or osteopenia vs. old avulsion injury such as achilles tendon insertion siteopathy --- Rec) clinical correlation cannot be excluded at large size (R/O RA patient). Suggested GIP joints for visualization: Drosophagitis in righ 2nd to 5th MT head level Lt.)
# Prompt = tensor([[50256]], device='cuda:0')
#
# --- Example 176 ---
# Raw Report       :
# [ Finding ]_x000D_
# No bony abnormality_x000D_
# [ Diagnosis ]_x000D_
# _x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# <|endoftext|> No bony abnormality <|endoftext|>
# Generated Report :
#  No bony abnormality. -------- bone . soft tissue , loose bodies suggested otherwise no significant interval change since last study. Suspicious erosion at Rt 1st MTP joint -> r/o gouty arthritis, probably mild degenerative hcange of both feet and hands with tophi : sesamoid osteoma tendon insertion site suggestive os subfibulare or enthesophyte rather than fracture involvement(s) --> RA vs inflammatory process such as multiple sclerosis cannot be excluded in a large portion possible coalition involving others on radiographs --- REC> clinical correlation Hallux
# Prompt = tensor([[50256]], device='cuda:0')
#
# --- Example 157 ---
# Raw Report       :
# [ Finding ]_x000D_
# both ankles and feet soft tissue swelling._x000D_
# _x000D_
# [ Conclusion ]_x000D_
# both ankles and feet soft tissue swelling._x000D_
# _x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# <|endoftext|> both ankles and feet soft tissue swelling. <|endoftext|>
# Generated Report :
#  no significant bony lesion on radiographs. -------- bone island, Rt 1st MT head suspicious erosion at Lt 2nd MTP joint -> r/o gouty arthritis or osteopenia degenerative change sinde last study No signficant interval progression since 2013-02 - REC) clinical correlation both knee OA with subluxation of right ankle and foot Both hallux valgus : RA involvement Degenerous cystic changes in medial portion (right 3rd IP & left 5th PP) Suspicious soft tissue swelling around lateral malleolar area
# Prompt = tensor([[50256]], device='cuda:0')
#
# --- Example 17 ---
# Raw Report       :
# [FINDING       ]_x000D_degenerative change_x000D__x000D_[CONCLUSION    ]_x000D_degenerative change_x000D__x000D_[RECOMMENDATION]_x000D_-
# Cleaned Report   :
# <|endoftext|> degenerative change <|endoftext|>
# Generated Report :
#  - degenerative change
# Prompt = tensor([[50256]], device='cuda:0')
#
# --- Example 109 ---
# Raw Report       :
# [ Finding ]_x000D_
# _x000D_
# No bony abnormalities._x000D_
# [ Diagnosis ]_x000D_
# _x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# <|endoftext|> No bony abnormalities. <|endoftext|>
# Generated Report :
#  No bony abnormality. -------- no significant interval change since last study. Both feet, soft tissue swelling and erosion --> R/O gout arthritis cannot be excluded as possible RA involvement rather than suspicious bone erosions at both 1st MTP joint level with subtle increased density in medial portion of right 5th metatarsal head . ----------------------------------------------------------------------- Small osteophyte adjacent to left 2nd distimal phalanx - suggestive ossification or old fracture vs stress fractures -> Probable exostosis patient base area --- Rec) clinical correlation Hallux valgus OA Lt lateral
# Prompt = tensor([[50256]], device='cuda:0')
#
# --- Example 206 ---
# Raw Report       :
# [ Finding ]_x000D_
# Accessory navicular bone type2, both_x000D_
# _x000D_
# both knee soft tissue swelling._x000D_
# _x000D_
# Lt. calcaneus, bony erosion._x000D_
#   --> gout vs. enthesitis._x000D_
# [ Conclusion ]_x000D_
# Accessory navicular bone type2, both_x000D_
# _x000D_
# both knee soft tissue swelling._x000D_
# _x000D_
# Lt. calcaneus, bony erosion._x000D_
#   --> gout vs. enthesitis._x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# <|endoftext|> Accessory navicular bone type2, both both knee soft tissue swelling. Lt. calcaneus, bony erosion. --> gout vs. enthesitis. <|endoftext|>
# Generated Report :
#  no significant bony lesion on radiographs. -------- No remarkable abnormality, both feet and ankles. osteophyte in right 1st MTP joint level with subtle radiolucent lesions of left ankle --> R/O gout involvement cannot be excluded."
# Prompt = tensor([[50256]], device='cuda:0')
#
# --- Example 62 ---
# Raw Report       :
# [ Finding ]_x000D_
# degenerative change._x000D_
# [ Conclusion ]_x000D_
# degenerative change._x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# <|endoftext|> degenerative change. <|endoftext|>
# Generated Report :
#  No bony abnormality. -------- bone . soft tissue ." Soft body , left 1st MTP joint level and medial side of right 5th metatarsal head -------------- Suspicious subchondral cysts in dorsal aspect of both ankle, suggesting os naviculare rather than humeral callus involvement or fracture with bones fragmenting at Lt lateral malleolucent lesion -> R/O gouty arthritis Mild hallux valgiform change (right 3rd DIP). Suggested inflammatory state such as RA related to rheumatoid process vs mild degener
# Prompt = tensor([[50256]], device='cuda:0')
#
# --- Example 100 ---
# Raw Report       :
# [ Finding ]_x000D_
# both ankle OA._x000D_
# _x000D_
# [ Conclusion ]_x000D_
# both ankle OA._x000D_
# _x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# <|endoftext|> both ankle OA. <|endoftext|>
# Generated Report :
#  no significant bony lesion on radiographs. -------- bone island, left big toe and both 1st toes (compared favorably)."

# %%
for idx in random.sample(range(len(test_ds)), min(20, len(test_ds))):
    ex = test_ds[idx]
    raw = ex['raw_report']
    clean = ex['cleaned_report']
    fi = ex['full_img'].unsqueeze(0).to(device)
    pa = ex['patches'].unsqueeze(0).to(device)
    prompt = ex['input_ids'][:1].unsqueeze(0).to(device)

    print(f'Prompt = {prompt}')

    g = model.global_encoder(fi)
    g = model.global_proj(g).unsqueeze(1)
    B, N, C, H, W = pa.shape
    p = pa.view(B * N, C, H, W)
    pf = model.patch_encoder(p)
    pf = model._pool(pf)
    pf = model.patch_proj(pf)
    pf = pf.view(B, N, 768)

    cat = torch.cat([g, pf], dim=1)
    comb, _ = model.attn(cat, cat, cat)
    comb = model.norm(comb)

    gen_ids = model.decoder.generate(
        input_ids=prompt,
        encoder_hidden_states=comb,
        attention_mask=torch.ones_like(prompt),
        max_length=120,
        do_sample=True,
        top_k=40,
        top_p=0.95,
        temperature=0.5,
        repetition_penalty=1.3,
        eos_token_id=tokenizer.eos_token_id,
        pad_token_id=tokenizer.eos_token_id
    )

    gen = tokenizer.decode(gen_ids[0], skip_special_tokens=True)

    print(f"\n--- Example {idx} ---")
    print(f"Raw Report       : \n{raw}")
    print(f"Cleaned Report   : \n{clean}")
    print(f"Generated Report : \n{gen}")
# Out:
# Prompt = tensor([[50256]], device='cuda:0')
#
# --- Example 110 ---
# Raw Report       :
# [ Finding ]_x000D_
# _x000D_
# [ Diagnosis ]_x000D_
# hallux valgus, right._x000D_
# tiny osteophyte of left 1st MTP joint._x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# <|endoftext|> hallux valgus, right. tiny osteophyte of left 1st MTP joint. <|endoftext|>
# Generated Report :
#  degenerative change. -------- bone erosion, left 1st MTP joint level and right 3rd PIP joints --- possible gouty arthritis rather than old fracture with soft tissue swelling of both lateral malleolus or ankle --> R/O stressor vs. mild radiopaque lesion such as rheumatoid ligament syndrome (Rt>Lt) suggested.) rec). clinical correlation no bony abnormality since last study . ------------------------------------------------------------------------------ osteopenia Lt. knee loose body suggestive os naviculare type III otherwise cannot be excluded at large size sinde previous
# Prompt = tensor([[50256]], device='cuda:0')
#
# --- Example 219 ---
# Raw Report       :
#  임시판독 결과 입니다 추후에 판독결과가 수정 될수 있으므로 확인 바랍니다._x000D_
# ------------------------------------------------------------------------ _x000D_
# [ Finding ]_x000D_
# 포함된 bone에 이상소견은 보이지 않음._x000D_
# 보이는 한도내에 soft tissue에 이상소견 보이지 않음._x000D_
# [ Diagnosis ]_x000D_
# No bony abnormality_x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# <|endoftext|> . ------------------------------------------------------------------------ bone . soft tissue . No bony abnormality <|endoftext|>
# Generated Report :
#  No bony abnormality. -------- bone . soft tissue , both ankle and foot no significant interval change since last study. Suspicious erosion, right 1st MTP joint level with calcifications around left 2nd metatarsal head base --> R/O gout arthritis cannot be excluded as suggested in previous post-op discussion. Suggested healing state: rheumatoid or osteopenia of Achilles tendon insertion site vs. old fracture involving lateral malleolus rather than proximal phalanx (Rt). Otherwise unremarkable bipartite sesamoidal coalition between tal
# Prompt = tensor([[50256]], device='cuda:0')
#
# --- Example 227 ---
# Raw Report       :
# [ Finding ]_x000D_
# both ankle degenerative change and erosions._x000D_
#   --> R/O gout_x000D_
# [ Conclusion ]_x000D_
# both ankle degenerative change and erosions._x000D_
#   --> R/O gout_x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# <|endoftext|> both ankle degenerative change and erosions. --> R/O gout <|endoftext|>
# Generated Report :
#  degenerative change. -------- bone erosions at both 1st MTP joint and Lt 2nd PIP joints with probable tophi -> r/o inflammatory arthritis involvement, probably mild hallux valgus syndrome Rt 3rd D-spines cystic lesion --> gouty old fracture vs severe OA related subluxation diffuse osteopenia no significant bony abnormality since last study suspicious erosion or calcification adjacent to talonavicular coalition rather than underlying cortical thickening rec> clinical correlation No interval progression of RA involvements in os naviculare &
# Prompt = tensor([[50256]], device='cuda:0')
#
# --- Example 57 ---
# Raw Report       :
# [ Finding ]_x000D_
# both accessory navicular bone, type II_x000D_
# both ankle OA_x000D_
# [ Conclusion ]_x000D_
# both accessory navicular bone, type II_x000D_
# both ankle OA_x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# <|endoftext|> both accessory navicular bone, type II both ankle OA <|endoftext|>
# Generated Report :
#  no significant bony lesion on radiographs. -------- bone island, left big toe and lateral malleolus both hands with soft tissue swelling --> R/O gout arthritis Both accessory navicular bones (Rt.) __________________ Small enthesophyte in plantar aspect of right calcaneal tuberosity vs smooth muscle hypertrophy induced partial fusion at latissimus dorsi tendon insertion site Suggested OA progression since 2010-11 Degenerative change(right 5th MTP joint) Rec> clinical correlation No remarkable finding sinde last study Lt. tal
# Prompt = tensor([[50256]], device='cuda:0')
#
# --- Example 205 ---
# Raw Report       :
# [ Finding ]_x000D_
# _x000D_
# [ Diagnosis ]_x000D_
# pes planus, both._x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# <|endoftext|> pes planus, both. <|endoftext|>
# Generated Report :
#  no bony lesion. -------- No interval change since last study: possible gout, left ankle and lateral malleolar area both 1st MTP joint soft tissue swelling --> R/O stress fracture or old avulsion injury vs. osteopenia such as an Achilles tendon insertion siteopathy cannot be excluded with clinical correlation of ulnar positive variance rather than disease involvement(e) rec> consider Fx.: RA patient coalition at Lt elbow OA hallux valgus deformity (Lt knee > rt medial sesamoid bone). moderate radiopaque impingement
# Prompt = tensor([[50256]], device='cuda:0')
#
# --- Example 192 ---
# Raw Report       :
# [FINDING       ]_x000D_no significant bony lesion on radiographs.
# bilateral os intermetatarseum (+)_x000D__x000D_[CONCLUSION    ]_x000D_no significant bony lesion on radiographs.
# bilateral os intermetatarseum (+)_x000D__x000D_[RECOMMENDATION]_x000D_-
# Cleaned Report   :
# <|endoftext|> no significant bony lesion on radiographs. bilateral os intermetatarseum (+) <|endoftext|>
# Generated Report :
#  no significant bony abnormality -------- No signficant interval change since last study. - suspicious erosions at both 1st MTP joint with bone fragment --> R/O gout involvement, probably mild degenerative changes diffuse osteopenia hallux valgus deformity or bipartite sesamoid type III Lt ankle soft tissue swelling and calcifications -> rheumatoidal arthritis cannot be excluded as possible multiple sclerosis rather than RA related inflammatory lesion such old fracture vs severe OA (+) talonavicular coalition os trigonum(right-left)-
# Prompt = tensor([[50256]], device='cuda:0')
#
# --- Example 158 ---
# Raw Report       :
# [ Finding ]_x000D_
# degenerative change_x000D_
# [ Conclusion ]_x000D_
# degenerative change_x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# <|endoftext|> degenerative change <|endoftext|>
# Generated Report :
#  No bony abnormality. -------- no significant interval change since last study. Both accessory navicular bone, type II with bipartite medial sesamoid and Rt 1st MT head erosion --> gout arthritis cannot be excluded as suggested in previous findings. GOUT RA involvement of both feet (mainly left). REC) Clinical correlation . Suggestive ossifications on radiographs rather than otherwise finding evidence of healing state at MTP joint level or subchondral cysts adjacent to Lt talonavus(right/left)). Rec> clinical correlatonitis --- rec
# Prompt = tensor([[50256]], device='cuda:0')
#
# --- Example 151 ---
# Raw Report       :
#  임시판독 결과 입니다 추후에 판독결과가 수정 될수 있으므로 확인 바랍니다._x000D_
# ------------------------------------------------------------------------ _x000D_
# [ Finding ]_x000D_
# No bony abnormality_x000D_
# _x000D_
# [ Diagnosis ]_x000D_
# No bony abnormality_x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# <|endoftext|> . ------------------------------------------------------------------------ No bony abnormality No bony abnormality <|endoftext|>
# Generated Report :
#  No bony abnormality. -------- bone island, right 1st proximal phalanx and achilles tendon insertion site of an ossification around Rt 2nd MTP joint with soft tissue swelling --> gout arthritis suggested
# Prompt = tensor([[50256]], device='cuda:0')
#
# --- Example 84 ---
# Raw Report       :
# [ Finding ]_x000D_
# _x000D_
# [ Diagnosis ]_x000D_
# Calcaneal spur, both._x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# <|endoftext|> Calcaneal spur, both. <|endoftext|>
# Generated Report :
#  degenerative change. -------- bone erosions, esp> right 1st MTP joint and left 5th PIP joints with soft tissue swelling --> R/O gout arthritis cannot be excluded since both accessory navicular bones are subchondral cysts rather than osteophytes or calcifications(Rt). os trigonum such as Lt.) rec) clinical correlation vs. radiography findings otherwise no significant bony lesion on radiolucentographs at Mueller-Weiss syndrome site (right MT base -> rheumatoid process)). possible old fracture of the medial
# Prompt = tensor([[50256]], device='cuda:0')
#
# --- Example 122 ---
# Raw Report       :
# [ Finding ]_x000D_
# _x000D_
# [ Diagnosis ]_x000D_
# Gouty arthritis in Rt 1st and left 5th MTP._x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# <|endoftext|> Gouty arthritis in Rt 1st and left 5th MTP. <|endoftext|>
# Generated Report :
#  no significant bony lesion on radiographs. -------- No remarkable abnormality, both feet and ankles.
# Prompt = tensor([[50256]], device='cuda:0')
#
# --- Example 58 ---
# Raw Report       :
# [ Finding ]_x000D_
# _x000D_
# [ Diagnosis ]_x000D_
# Os naviculare, type I, right._x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# <|endoftext|> Os naviculare, type I, right. <|endoftext|>
# Generated Report :
#  No bony abnormality. -------- no significant interval change since last study. Both hallux valgus, both otherwise unremarkable on radiographs or CTx . osteophyte in right 1st MTP joint and posterior calcaneal tuberosity with soft tissue swelling --> R/O gout arthritis cannot be excluded as suggested overhanging edge at Lt medial side of left ankle (Lt >Rt). Enthesitis such bone erosion rather than plantar spur involvement are not likely to diffuse disease progression sinde old fracture vs. infectious process involving multiple sclerosis(Sydney
# Prompt = tensor([[50256]], device='cuda:0')
#
# --- Example 35 ---
# Raw Report       :
# [ Finding ]_x000D_
# Rt. knee soft tissue swelling._x000D_
# both navicular bone, subchondral cyst._x000D_
# both 1st MTP joint, osteolytic lesion_x000D_
#   --> R/O gout_x000D_
# [ Conclusion ]_x000D_
# Rt. knee soft tissue swelling._x000D_
# both navicular bone, subchondral cyst._x000D_
# both 1st MTP joint, osteolytic lesion_x000D_
#   --> R/O gout_x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# <|endoftext|> Rt. knee soft tissue swelling. both navicular bone, subchondral cyst. both 1st MTP joint, osteolytic lesion --> R/O gout <|endoftext|>
# Generated Report :
#  no bony lesion. -------- No interval change since last study: gout, right 2nd MTP joint and left 3rd MCP joints with soft tissue swelling vs. old fracture or sclerotic rim --> R/O stressor both 1st toe Os naviculare type III (right) Lt os trigonum Bilateral accessory ossicle rather than calcification on lateral view Diffuse osteopenia Multiple OA in tibiotalar area Subluxation of talocalcaneal coalition Accessory bone DIP Joint effusion Both ankle degenerative changes
# Prompt = tensor([[50256]], device='cuda:0')
#
# --- Example 77 ---
# Raw Report       :
# [FINDING       ]_x000D_mild degenerative change_x000D__x000D_[CONCLUSION    ]_x000D_mild degenerative change_x000D__x000D_[RECOMMENDATION]_x000D_-
# Cleaned Report   :
# <|endoftext|> mild degenerative change <|endoftext|>
# Generated Report :
#  - No significant interval change Advertisements, both 1st MTP joint soft tissue swelling and erosions at Rt 3rd MT head -> r/o inflammatory arthritis involvement or suspicious old fracture with bone fragment --> gouty mild degenerative changes hallux valgus , Lt 5th metatarsal shaft diffuse osteopenia pes planum flat foot severe OA in tibiotalar joints (Rx >Lt) probable erosion of right 2nd IP base subluxation state (+/- stress fractures tophi such as PP-1225T intermetritis syndrome rather than simple
# Prompt = tensor([[50256]], device='cuda:0')
#
# --- Example 186 ---
# Raw Report       :
# [ Finding ]_x000D_
# C.I.: gout, RA patient_x000D_
# _x000D_
# Erosive change in DIP joint of left 3rd toe and multiple DIP joints of right 2nd to 5th fingers_x000D_
#  -- Probable RA > degenerative OA_x000D_
# _x000D_
# Disc space collapse, C3-4_x000D_
# Retrolisthesis, C3 onc4_x000D_
# Degenerative spondylosis, C-spines_x000D_
# [ Conclusion ]_x000D_
# Erosive change in DIP joint of left 3rd toe and multiple DIP joints of right 2nd to 5th fingers_x000D_
#  -- Probable RA > degenerative OA_x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# <|endoftext|> C.I.: gout, RA patient Erosive change in DIP joint of left 3rd toe and multiple DIP joints of right 2nd to 5th fingers -- Probable RA > degenerative OA Disc space collapse, C3-4 Retrolisthesis, C3 onc4 Degenerative spondylosis, C-spines Erosive change in DIP joint of left 3rd toe and multiple DIP joints of right 2nd to 5th fingers -- Probable RA > degenerative OA <|endoftext|>
# Generated Report :
#  no significant bony lesion on radiographs. -------- No remarkable abnormality both feet, intertarsal joints and tibiotalar joint space narrowing --> R/O gout arthritis or bipartite sesamoid bone disease involvement.: possible old fracture with nonunion rather than accessory ossicle vs. osteopenia: REC) clinical correlation of FBs 1-5 ---------------------------------------------------------------------- rec> Clinical correlaton interval progression to PIP hallux valgus deformity Lt elbow soft tissue swelling (RTP). moderate OA in righ 5th MCP area(
# Prompt = tensor([[50256]], device='cuda:0')
#
# --- Example 102 ---
# Raw Report       :
# [ Finding ]_x000D_
# no bony lesion._x000D_
# [ Diagnosis ]_x000D_
# no bony lesion._x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# <|endoftext|> no bony lesion. no bony lesion. <|endoftext|>
# Generated Report :
#  no significant bony lesion on radiographs. -------- No remarkable abnormality, both feet and ankles otherwise --> R/O gout involvement of left navicular bone (Lt>Rt). rec) clinical correlation with HLA B27U1-2
# Prompt = tensor([[50256]], device='cuda:0')
#
# --- Example 144 ---
# Raw Report       :
# [ Finding ]_x000D_
# no bony lesion._x000D_
# [ Conclusion ]_x000D_
# no bony lesion._x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# <|endoftext|> no bony lesion. <|endoftext|>
# Generated Report :
#  no bony lesion. -------- No interval change since last study: calcifications, intertarsal joints and soft tissue swelling in dorsum of both foot . ---------------------------------------------------------------------- Suggestive gout arthritis with bone erosion at R/O tophi cannot be excluded --- rec) clinical correlation rather than disease progression or underlying condition such as osteopenia-related joint space narrowing vs. plantar spur involvement(s). probable old fracture involving left medial malleolus (Lt>Rd)). Suspicious periarticular cyst growing adjacent right 1nd metatarsonoid head -->
# Prompt = tensor([[50256]], device='cuda:0')
#
# --- Example 159 ---
# Raw Report       :
# [ Finding ]_x000D_
# possible RA._x000D_
# _x000D_
# [ Conclusion ]_x000D_
# possible RA._x000D_
# _x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# <|endoftext|> possible RA. <|endoftext|>
# Generated Report :
#  degenerative change. -------- bone erosions at both 1st MTP joint, with more likely to be subcortical cysts -> r/o gouty arthritis involvement mild hallux valgus deformity --> Rt ankle OA Lt 5th finger amputation state and soft tissue swelling diffuse osteopenia moderate RA involvements such as knee joints or hands (e) interval progression of healing process vs old fracture(s)/suspicious inflammatory lesions progressed narrowing in tarsometatarsal bones & TMT areas periarticular calcifications (+/-). rec>
# Prompt = tensor([[50256]], device='cuda:0')
#
# --- Example 229 ---
# Raw Report       :
# [ Finding ]_x000D_
# degenerative change of both feet_x000D_
# [ Conclusion ]_x000D_
# degenerative change of both feet_x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# <|endoftext|> degenerative change of both feet <|endoftext|>
# Generated Report :
#  no significant bony lesion on radiographs. -------- No remarkable abnormality, both feet and ankles. Lt ankle soft tissue swelling --> R/O gout arthritis cannot be excluded since otherwise such a large portion of the body with tophi in medial aspect (right > left). rec> clinical correlation vs. old fracture or os subfibulare infection.: REC) Clinical correlaton sinde last study(Seductive osteophyte -> rheumatoid process involvement.) Reconditioning findings: calcification at right distal fibular area (+ possibility of healing state
# Prompt = tensor([[50256]], device='cuda:0')
#
# --- Example 60 ---
# Raw Report       :
# [ Finding ]_x000D_
# _x000D_
# [ Diagnosis ]_x000D_
# pes planus, both._x000D_
# plantar calcaneal spur, right._x000D_
# degenerative change of both ankle._x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# <|endoftext|> pes planus, both. plantar calcaneal spur, right. degenerative change of both ankle. <|endoftext|>
# Generated Report :
#  degenerative change. -------- bone erosions at both 1st MTP joint and Lt 5th MT head -> r/o gouty arthritis, likely mild hallux valgus with OA in tibiotalar joints Rt 3rd DIP base fracture subluxation of right medial malleolucent lesion --> RA involvement rather than inflammatory or infectious disease such as chondrocalcinosis vs ulnar positive variance Degenerous cystic changes Both accessory navicular bones type II (Rx>Lt) Diffuse osteopenia Multiple bony erosion on
# Prompt = tensor([[50256]], device='cuda:0')
#
# --- Example 112 ---
# Raw Report       :
# [ Finding ]_x000D_
# diffuse osteopenia._x000D_
# hallux valgus._x000D_
# degenerative change._x000D_
# [ Conclusion ]_x000D_
# severe OA, both knee joints._x000D_
# diffuse osteopenia_x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# <|endoftext|> diffuse osteopenia. hallux valgus. degenerative change. severe OA, both knee joints. diffuse osteopenia <|endoftext|>
# Generated Report :
#  no significant interval change since last study. -------- bone erosions at both 1st MTP joint, with more likely to be subluxation of Rt 4th MT head -> RA involvement degenerative changes diffuse osteopenia mild hallux valgus deformity and soft tissue swelling vs severe OA related knee pain Hallucinosis process suspicious erosion in TMT joints - r/o old fracture or os trigonum Degenerous cystic lesion --> inflammatory arthritis cannot possibly suggest otherwise Both hands (right > left) sclerotic margin loose bodies around Lt 2nd

# %% [markdown]
# # New

# %%
import os
import re
import json
import logging
import unicodedata
import random
from collections import defaultdict, Counter

import numpy as np
import cv2
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, random_split
from PIL import Image
from torchvision import transforms
from tqdm import tqdm
import timm
from transformers import GPT2Tokenizer, GPT2LMHeadModel
from sentence_transformers import SentenceTransformer
import matplotlib.pyplot as plt

logging.basicConfig(level=logging.INFO)

# =============================================================================
# Utility functions
# =============================================================================

def count_labels(data, target_classes, cfg):
    class_counts = defaultdict(int)
    data_by_class = defaultdict(list)
    for entry in tqdm(data.values(), desc="Counting dataset"):
        lbl = entry.get('class_label', '').lower()
        if lbl in target_classes and os.path.exists(entry['file_path']):
            class_counts[lbl] += 1
            data_by_class[lbl].append(entry)
    return class_counts, data_by_class

def prepare_abnormal_normal_data(data, cfg):
    random.seed(42)
    abnormal = ['ra', 'oa', 'gout']
    normal = ['normal']
    class_counts, data_by_class = count_labels(data, abnormal + normal, cfg)
    combined = {
        'abnormal': sum((data_by_class[c] for c in abnormal), []),
        'normal': data_by_class['normal']
    }
    combined_counts = {
        'abnormal': sum(class_counts[c] for c in abnormal),
        'normal': class_counts['normal']
    }
    if not cfg.DATASET.BALANCE and not cfg.DATASET.AUGMENT:
        return sum(combined.values(), []), combined_counts, combined_counts
    min_count = min(combined_counts.values())
    balanced = []
    final_counts = {}
    for lbl, items in combined.items():
        sampled = random.sample(items, min_count)
        balanced.extend(sampled)
        final_counts[lbl] = min_count
    if cfg.DATASET.AUGMENT:
        balanced *= 2
    return balanced, combined_counts, final_counts

def prepare_data(data, target_classes, cfg, is_binary=False):
    random.seed(42)
    if len(target_classes) == 2 and 'abnormal' in target_classes and 'normal' in target_classes:
        logging.info("Using abnormal-vs-normal logic")
        return prepare_abnormal_normal_data(data, cfg)
    class_counts, data_by_class = count_labels(data, target_classes, cfg)
    logging.info(f"Original class distribution: {class_counts}")
    if not cfg.DATASET.BALANCE and not cfg.DATASET.AUGMENT:
        return sum(data_by_class.values(), []), class_counts, class_counts
    min_count = min(class_counts.values())
    balanced, final_counts = [], {}
    for lbl in target_classes:
        sampled = random.sample(data_by_class[lbl], min_count)
        balanced.extend(sampled)
        final_counts[lbl] = min_count
    logging.info(f"Balanced class distribution: {final_counts}")
    if cfg.DATASET.AUGMENT:
        balanced *= 2
    return balanced, class_counts, final_counts

# =============================================================================
# Transforms
# =============================================================================

imagenet_mean = [0.485, 0.456, 0.406]
imagenet_std = [0.229, 0.224, 0.225]

train_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(imagenet_mean, imagenet_std)
])

patch_transform = transforms.Compose([
    transforms.Resize((112, 112)),
    transforms.ToTensor(),
    transforms.Normalize(imagenet_mean, imagenet_std)
])

# =============================================================================
# Dataset
# =============================================================================

class FinalSamplesDataset(Dataset):
    def __init__(self, cfg, tokenizer, image_transform=train_transform, patch_transform=patch_transform):
        self.cfg = cfg
        self.tokenizer = tokenizer
        self.image_transform = image_transform
        self.patch_transform = patch_transform

        # use real BOS token, not the EOS
        self.bos_token_id = tokenizer.bos_token_id
        self.eos_token_id = tokenizer.eos_token_id

        self.target_classes = cfg.DATASET.TARGET_CLASSES
        if isinstance(self.target_classes, str):
            self.target_classes = self.target_classes.split(",")

        self.is_binary = len(self.target_classes) == 2
        self.abnormal_classify = self.is_binary and 'abnormal' in self.target_classes
        self.abnormal_mapping = (
            {'ra': 'abnormal', 'oa': 'abnormal', 'gout': 'abnormal', 'normal': 'normal'}
            if self.abnormal_classify else None
        )

        with open(cfg.DATASET.JSON, 'r') as f:
            raw_list = json.load(f)

        filtered = []
        for item in raw_list:
            merged = item.get('merged_image_path', '')
            fp = item.get('file_paths', [])
            if isinstance(fp, str):
                fp = [fp]
            paths = [merged] + fp
            if any(os.path.exists(p) for p in paths):
                filtered.append((merged, fp, item))

        self.data = {}
        for i, (merged, fp, item) in enumerate(filtered):
            cls = item.get('class', 'unknown').lower()
            if self.abnormal_mapping:
                cls = self.abnormal_mapping.get(cls, cls)
            self.data[i] = {
                'file_path': merged,
                'left_right_file_path': fp,
                'class_label': cls,
                'diagnosis': item.get('diagnosis', ''),
                'keypoints': item.get('keypoints', {})
            }

        if self.is_binary:
            balanced, _, _ = prepare_data(self.data, self.target_classes, cfg, True)
            self.data = {i: e for i, e in enumerate(balanced)}

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        e = self.data[idx]
        img = Image.open(e['file_path']).convert('RGB')
        img = self.image_transform(img)

        patches = self._gen_patches(e['left_right_file_path'], e['keypoints'])
        pt = [self.patch_transform(Image.fromarray(p)) for p in patches]
        patches_tensor = torch.stack(pt, 0) if pt else torch.zeros(34, 3, 112, 112)

        raw = e.get('diagnosis', '')
        clean = self._clean_report(raw)

        # tokenize without special tokens, then wrap with BOS/EOS
        token_ids = self.tokenizer.encode(
            clean,
            truncation=True,
            max_length=self.tokenizer.model_max_length - 2,
            add_special_tokens=False
        )
        full_ids = [self.bos_token_id] + token_ids + [self.eos_token_id]
        input_ids = torch.tensor(full_ids, dtype=torch.long)
        attention_mask = torch.ones_like(input_ids)

        return {
            'full_img': img,
            'patches': patches_tensor,
            'raw_report': raw,
            'cleaned_report': clean,
            'input_ids': input_ids,
            'attention_mask': attention_mask
        }

    def _gen_patches(self, paths, kps_dict, crop_size=(200, 300), patch_size=(112, 112)):
        def extract(arr, side_kps):
            lst = []
            pts = side_kps[0]['keypoints']
            for i in range(17):
                x, y, s = int(pts[3*i]), int(pts[3*i+1]), pts[3*i+2]
                if s > 0:
                    x0 = max(x - crop_size[0]//2, 0)
                    y0 = max(y - crop_size[1]//2, 0)
                    x1 = min(x + crop_size[0]//2, arr.shape[1])
                    y1 = min(y + crop_size[1]//2, arr.shape[0])
                    c = arr[y0:y1, x0:x1]
                    if c.size:
                        lst.append(cv2.resize(c, patch_size))
            return lst

        def pad17(lst):
            black = np.zeros((patch_size[1], patch_size[0], 3), np.uint8)
            while len(lst) < 17:
                lst.append(black)
            return lst[:17]

        left, right = [], []
        if len(paths) == 1:
            pth = paths[0]
            if not pth or not os.path.exists(pth):
                return pad17([]) + pad17([])
            img_arr = cv2.imread(pth)
            if img_arr is None:
                return pad17([]) + pad17([])
            arr = cv2.cvtColor(img_arr, cv2.COLOR_BGR2RGB)
            if kps_dict.get('left'): left = extract(arr, kps_dict['left'])
            if kps_dict.get('right'): right = extract(arr, kps_dict['right'])
        else:
            for side, pth in zip(['left', 'right'], paths):
                if pth and os.path.exists(pth):
                    img_arr = cv2.imread(pth)
                    if img_arr is not None:
                        arr = cv2.cvtColor(img_arr, cv2.COLOR_BGR2RGB)
                        if kps_dict.get(side):
                            lst = extract(arr, kps_dict[side])
                            if side == 'left': left = lst
                            else: right = lst

        if left and not right:
            right = [cv2.flip(p, 1) for p in left]
        if right and not left:
            left = [cv2.flip(p, 1) for p in right]
        if not left and not right:
            return pad17([]) + pad17([])
        return pad17(left) + pad17(right)

    def _clean_report(self, text):
        text = unicodedata.normalize('NFKC', text or '')
        text = re.sub(r'(?m)^-+\s*$', '', text)
        text = re.sub(r'[^\x00-\x7F]+', ' ', text)
        text = re.sub(r'([.!?]){2,}', r'\1', text)
        text = re.sub(r'\[\s*finding\s*\]', '[FINDING]', text, flags=re.IGNORECASE)
        text = re.sub(r'\[\s*conclusion\s*\]', '[CONCLUSION]', text, flags=re.IGNORECASE)
        text = re.sub(r'\[\s*diagnosis\s*\]', '[DIAGNOSIS]', text, flags=re.IGNORECASE)
        parts = re.split(r'\[\s*recommend(?:ation)?\s*\]', text, flags=re.IGNORECASE)
        text = parts[0]
        fm = re.search(r'\[FINDING\](.*?)(?=\[|$)', text, flags=re.IGNORECASE | re.DOTALL)
        cm = re.search(r'\[CONCLUSION\](.*?)(?=\[|$)', text, flags=re.IGNORECASE | re.DOTALL)
        if fm and cm and fm.group(1).strip().lower() == cm.group(1).strip().lower():
            text = re.sub(r'\[CONCLUSION\].*?(?=\[|$)', '', text, flags=re.IGNORECASE | re.DOTALL)
        text = re.sub(r'\[\s*(FINDING|CONCLUSION|DIAGNOSIS)\s*\]', '', text, flags=re.IGNORECASE)
        text = text.replace('_x000D_', ' ')
        text = re.sub(r'\s+', ' ', text).strip()
        return text

# =============================================================================
# Collate function
# =============================================================================

def collate_fn(batch):
    imgs = torch.stack([b['full_img'] for b in batch])
    pts = [b['patches'] for b in batch]
    max_p = max(p.shape[0] for p in pts)
    pads = []
    for p in pts:
        if p.shape[0] < max_p:
            pad = torch.zeros((max_p - p.shape[0], *p.shape[1:]))
            p = torch.cat([p, pad], dim=0)
        pads.append(p)
    patches = torch.stack(pads, 0)

    ids = [b['input_ids'] for b in batch]
    masks = [b['attention_mask'] for b in batch]
    ids = nn.utils.rnn.pad_sequence(ids, batch_first=True, padding_value=tokenizer.pad_token_id)
    masks = nn.utils.rnn.pad_sequence(masks, batch_first=True, padding_value=0)

    return {
        'full_imgs': imgs,
        'patches': patches,
        'input_ids': ids,
        'attention_mask': masks,
        'raw_reports': [b['raw_report'] for b in batch],
        'cleaned_reports': [b['cleaned_report'] for b in batch]
    }

# =============================================================================
# Model
# =============================================================================

class MultiModalModel(nn.Module):
    def __init__(self, gpt2_model_name='gpt2'):
        super().__init__()
        self.global_encoder = timm.create_model('swin_base_patch4_window7_224', pretrained=True)
        self.global_encoder.reset_classifier(0)
        self.global_proj = nn.Linear(self.global_encoder.num_features, 768)

        self.patch_encoder = timm.create_model('resnet50', pretrained=True)
        self.patch_encoder.fc = nn.Identity()
        self.patch_proj = nn.Linear(self.patch_encoder.num_features, 768)

        self.attn = nn.MultiheadAttention(embed_dim=768, num_heads=8, batch_first=True)
        self.norm = nn.LayerNorm(768)

        self.decoder = GPT2LMHeadModel.from_pretrained(gpt2_model_name, add_cross_attention=True)

    def _pool(self, feats):
        return feats.mean(dim=[2, 3]) if feats.ndim > 2 else feats

    def forward(self, imgs, patches, input_ids, attention_mask, decoder_labels=None):
        g = self.global_encoder(imgs)
        g = self.global_proj(g).unsqueeze(1)

        B, N, C, H, W = patches.shape
        p = patches.view(B * N, C, H, W)
        pf = (self.patch_encoder.forward_features(p)
              if hasattr(self.patch_encoder, 'forward_features')
              else self.patch_encoder(p))
        pf = self._pool(pf)
        pf = self.patch_proj(pf)
        pf = pf.view(B, N, 768)

        cat = torch.cat([g, pf], dim=1)
        comb, _ = self.attn(cat, cat, cat)
        comb = self.norm(comb)

        return self.decoder(
            input_ids=input_ids,
            attention_mask=attention_mask,
            encoder_hidden_states=comb,
            labels=decoder_labels
        )

# =============================================================================
# Train / Eval Helpers
# =============================================================================

def train_epoch(model, loader, optimizer, scaler, device):
    model.train()
    total_loss = 0.0
    for b in tqdm(loader, desc="Training", leave=False):
        imgs = b['full_imgs'].to(device)
        pts = b['patches'].to(device)
        ids = b['input_ids'].to(device)
        msk = b['attention_mask'].to(device)

        optimizer.zero_grad()
        with torch.cuda.amp.autocast():
            out = model(imgs, pts, ids, msk, decoder_labels=ids)
            loss = out.loss
        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()
        total_loss += loss.item()
    return total_loss / len(loader)

def evaluate(model, loader, device):
    model.eval()
    total_loss = 0.0
    all_gen, all_gt = [], []

    for b in tqdm(loader, desc="Evaluating", leave=False):
        imgs = b['full_imgs'].to(device)
        pts  = b['patches'].to(device)
        ids  = b['input_ids'].to(device)
        msk  = b['attention_mask'].to(device)

        with torch.no_grad():
            out = model(imgs, pts, ids, msk, decoder_labels=ids)
            total_loss += out.loss.item()

            # build encoder states
            g = model.global_encoder(imgs)
            g = model.global_proj(g).unsqueeze(1)
            B, N, C, H, W = pts.shape
            p = pts.view(B * N, C, H, W)
            pf = model.patch_encoder(p)
            pf = model._pool(pf)
            pf = model.patch_proj(pf)
            pf = pf.view(B, N, 768)

            cat, _ = model.attn(torch.cat([g, pf], dim=1),
                                torch.cat([g, pf], dim=1),
                                torch.cat([g, pf], dim=1))
            comb = model.norm(cat)

            # No prompt tensor, start from real BOS
            gen_ids = model.decoder.generate(
                input_ids=None,
                encoder_hidden_states=comb,
                decoder_start_token_id=tokenizer.bos_token_id,
                eos_token_id=tokenizer.eos_token_id,
                pad_token_id=tokenizer.eos_token_id,
                max_length=100,
                do_sample=True,
                top_k=50,
                top_p=0.95,
                temperature=0.7,
                repetition_penalty=1.2,
            )

            gen_txt = [tokenizer.decode(g_, skip_special_tokens=True) for g_ in gen_ids]
            gt_txt  = [tokenizer.decode(i_, skip_special_tokens=True) for i_ in ids]
            all_gen.extend(gen_txt)
            all_gt.extend(gt_txt)

    return total_loss / len(loader), all_gen, all_gt


def compute_semantic_similarity(gen, gt):
    stm = SentenceTransformer('all-MiniLM-L6-v2')
    e1 = stm.encode(gen, convert_to_tensor=True)
    e2 = stm.encode(gt, convert_to_tensor=True)
    return nn.functional.cosine_similarity(e1, e2).mean().item()

def plot_metrics(train_losses, val_losses, sems):
    epochs = range(1, len(train_losses) + 1)
    plt.figure(figsize=(12, 5))

    plt.subplot(1, 2, 1)
    plt.plot(epochs, train_losses, label="Train Loss")
    plt.plot(epochs, val_losses, label="Validation Loss")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(epochs, sems, label="Semantic Similarity")
    plt.xlabel("Epoch")
    plt.ylabel("Similarity")
    plt.legend()

    plt.tight_layout()
    plt.show()

# =============================================================================
# MAIN
# =============================================================================

class Cfg: pass
cfg = Cfg()
cfg.DATASET = Cfg()
cfg.DATASET.JSON = 'final_samples_both_only_v2.json'
cfg.DATASET.USE_RAW = True
cfg.DATASET.USE_PATCH = True
cfg.DATASET.REPORT = True
cfg.DATASET.TARGET_CLASSES = ['ra', 'oa', 'gout', 'normal', 'uncertain', 'ref.prev']
cfg.DATASET.BALANCE = False
cfg.DATASET.AUGMENT = False

tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
# add a real BOS token
tokenizer.add_special_tokens({'bos_token': '<bos>'})
tokenizer.pad_token = tokenizer.eos_token
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

dataset = FinalSamplesDataset(cfg, tokenizer)

dist = Counter(e['class_label'] for e in dataset.data.values())
print("\nDataset class distribution:")
for cls, cnt in dist.items():
    print(f"  {cls}: {cnt}")

n = len(dataset)
n_train = int(0.8 * n)
n_val = int(0.1 * n)
n_test = n - n_train - n_val

train_ds, val_ds, test_ds = random_split(dataset, [n_train, n_val, n_test])

train_loader = DataLoader(train_ds, batch_size=4, shuffle=True, collate_fn=collate_fn)
val_loader = DataLoader(val_ds, batch_size=4, shuffle=False, collate_fn=collate_fn)
test_loader = DataLoader(test_ds, batch_size=4, shuffle=False, collate_fn=collate_fn)

model = MultiModalModel().to(device)
# resize to include the new BOS token
model.decoder.resize_token_embeddings(len(tokenizer))
optimizer = optim.AdamW(model.parameters(), lr=5e-5)
scheduler = torch.optim.lr_scheduler.CosineAnnealingWarmRestarts(optimizer, T_0=10, T_mult=2)
scaler = torch.cuda.amp.GradScaler()

num_epochs = 5
train_losses, val_losses, sems = [], [], []

for epoch in range(num_epochs):
    print(f"\nEpoch {epoch + 1}/{num_epochs}")
    train_loss = train_epoch(model, train_loader, optimizer, scaler, device)
    val_loss, gen_txt, gt_txt = evaluate(model, val_loader, device)
    sem = compute_semantic_similarity(gen_txt, gt_txt)

    train_losses.append(train_loss)
    val_losses.append(val_loss)
    sems.append(sem)

    print(f"  Train Loss          : {train_loss:.4f}")
    print(f"  Validation Loss     : {val_loss:.4f}")
    print(f"  Semantic Similarity : {sem:.4f}")
    scheduler.step()

plot_metrics(train_losses, val_losses, sems)

test_loss, test_gen, test_gt = evaluate(model, test_loader, device)
test_sem = compute_semantic_similarity(test_gen, test_gt)

print("\n========== TEST RESULTS ==========")
print(f"Test Loss              : {test_loss:.4f}")
print(f"Test Semantic Sim     : {test_sem:.4f}")

print("\n===== RANDOM TEST EXAMPLES =====")
for idx in random.sample(range(len(test_ds)), min(10, len(test_ds))):
    ex = test_ds[idx]
    raw   = ex['raw_report']
    clean = ex['cleaned_report']
    fi    = ex['full_img'].unsqueeze(0).to(device)
    pa    = ex['patches'].unsqueeze(0).to(device)

    # build encoder states
    g = model.global_encoder(fi)
    g = model.global_proj(g).unsqueeze(1)
    B, N, C, H, W = pa.shape
    p = pa.view(B * N, C, H, W)
    pf = model.patch_encoder(p)
    pf = model._pool(pf)
    pf = model.patch_proj(pf)
    pf = pf.view(B, N, 768)

    cat, _ = model.attn(torch.cat([g, pf], dim=1),
                        torch.cat([g, pf], dim=1),
                        torch.cat([g, pf], dim=1))
    comb = model.norm(cat)

    # generate with decoder_start_token_id
    gen_ids = model.decoder.generate(
        input_ids=None,
        encoder_hidden_states=comb,
        decoder_start_token_id=tokenizer.bos_token_id,
        eos_token_id=tokenizer.eos_token_id,
        pad_token_id=tokenizer.eos_token_id,
        max_length=120,
        do_sample=True,
        top_k=40,
        top_p=0.95,
        temperature=0.5,
        repetition_penalty=1.3,
    )

    gen = tokenizer.decode(gen_ids[0], skip_special_tokens=True)

    print(f"\n--- Example {idx} ---")
    print(f"Raw Report       : \n{raw}")
    print(f"Cleaned Report   : \n{clean}")
    print(f"Generated Report : \n{gen}")
# Out:
# 2025-05-09 11:36:54.868993: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-05-09 11:36:54.875585: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746815814.883342   59127 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746815814.885714   59127 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1746815814.891833   59127 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1746815814.891842   59127 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1746815814.891843   59127 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1746815814.891843   59127 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-05-09 11:36:54.894128: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Using device: cuda
#
# Dataset class distribution:
#   oa: 573
#   ra: 115
#   uncertain: 620
#   oa, ra: 8
#   normal: 748
#   gout: 267
#   combination of oa, ra: 3
#   ref.prev: 60
# INFO:timm.models._builder:Loading pretrained weights from Hugging Face hub (timm/swin_base_patch4_window7_224.ms_in22k_ft_in1k)
# INFO:timm.models._hub:[timm/swin_base_patch4_window7_224.ms_in22k_ft_in1k] Safe alternative available for 'pytorch_model.bin' (as 'model.safetensors'). Loading weights using safetensors.
# INFO:timm.models._builder:Loading pretrained weights from Hugging Face hub (timm/resnet50.a1_in1k)
# INFO:timm.models._hub:[timm/resnet50.a1_in1k] Safe alternative available for 'pytorch_model.bin' (as 'model.safetensors'). Loading weights using safetensors.
# Some weights of GPT2LMHeadModel were not initialized from the model checkpoint at gpt2 and are newly initialized: ['h.0.crossattention.c_attn.bias', 'h.0.crossattention.c_attn.weight', 'h.0.crossattention.c_proj.bias', 'h.0.crossattention.c_proj.weight', 'h.0.crossattention.q_attn.bias', 'h.0.crossattention.q_attn.weight', 'h.0.ln_cross_attn.bias', 'h.0.ln_cross_attn.weight', 'h.1.crossattention.c_attn.bias', 'h.1.crossattention.c_attn.weight', 'h.1.crossattention.c_proj.bias', 'h.1.crossattention.c_proj.weight', 'h.1.crossattention.q_attn.bias', 'h.1.crossattention.q_attn.weight', 'h.1.ln_cross_attn.bias', 'h.1.ln_cross_attn.weight', 'h.10.crossattention.c_attn.bias', 'h.10.crossattention.c_attn.weight', 'h.10.crossattention.c_proj.bias', 'h.10.crossattention.c_proj.weight', 'h.10.crossattention.q_attn.bias', 'h.10.crossattention.q_attn.weight', 'h.10.ln_cross_attn.bias', 'h.10.ln_cross_attn.weight', 'h.11.crossattention.c_attn.bias', 'h.11.crossattention.c_attn.weight', 'h.11.crossattention.c_proj.bias', 'h.11.crossattention.c_proj.weight', 'h.11.crossattention.q_attn.bias', 'h.11.crossattention.q_attn.weight', 'h.11.ln_cross_attn.bias', 'h.11.ln_cross_attn.weight', 'h.2.crossattention.c_attn.bias', 'h.2.crossattention.c_attn.weight', 'h.2.crossattention.c_proj.bias', 'h.2.crossattention.c_proj.weight', 'h.2.crossattention.q_attn.bias', 'h.2.crossattention.q_attn.weight', 'h.2.ln_cross_attn.bias', 'h.2.ln_cross_attn.weight', 'h.3.crossattention.c_attn.bias', 'h.3.crossattention.c_attn.weight', 'h.3.crossattention.c_proj.bias', 'h.3.crossattention.c_proj.weight', 'h.3.crossattention.q_attn.bias', 'h.3.crossattention.q_attn.weight', 'h.3.ln_cross_attn.bias', 'h.3.ln_cross_attn.weight', 'h.4.crossattention.c_attn.bias', 'h.4.crossattention.c_attn.weight', 'h.4.crossattention.c_proj.bias', 'h.4.crossattention.c_proj.weight', 'h.4.crossattention.q_attn.bias', 'h.4.crossattention.q_attn.weight', 'h.4.ln_cross_attn.bias', 'h.4.ln_cross_attn.weight', 'h.5.crossattention.c_attn.bias', 'h.5.crossattention.c_attn.weight', 'h.5.crossattention.c_proj.bias', 'h.5.crossattention.c_proj.weight', 'h.5.crossattention.q_attn.bias', 'h.5.crossattention.q_attn.weight', 'h.5.ln_cross_attn.bias', 'h.5.ln_cross_attn.weight', 'h.6.crossattention.c_attn.bias', 'h.6.crossattention.c_attn.weight', 'h.6.crossattention.c_proj.bias', 'h.6.crossattention.c_proj.weight', 'h.6.crossattention.q_attn.bias', 'h.6.crossattention.q_attn.weight', 'h.6.ln_cross_attn.bias', 'h.6.ln_cross_attn.weight', 'h.7.crossattention.c_attn.bias', 'h.7.crossattention.c_attn.weight', 'h.7.crossattention.c_proj.bias', 'h.7.crossattention.c_proj.weight', 'h.7.crossattention.q_attn.bias', 'h.7.crossattention.q_attn.weight', 'h.7.ln_cross_attn.bias', 'h.7.ln_cross_attn.weight', 'h.8.crossattention.c_attn.bias', 'h.8.crossattention.c_attn.weight', 'h.8.crossattention.c_proj.bias', 'h.8.crossattention.c_proj.weight', 'h.8.crossattention.q_attn.bias', 'h.8.crossattention.q_attn.weight', 'h.8.ln_cross_attn.bias', 'h.8.ln_cross_attn.weight', 'h.9.crossattention.c_attn.bias', 'h.9.crossattention.c_attn.weight', 'h.9.crossattention.c_proj.bias', 'h.9.crossattention.c_proj.weight', 'h.9.crossattention.q_attn.bias', 'h.9.crossattention.q_attn.weight', 'h.9.ln_cross_attn.bias', 'h.9.ln_cross_attn.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# The new embeddings will be initialized from a multivariate normal distribution that has old embeddings' mean and covariance. As described in this article: https://nlp.stanford.edu/~johnhew/vocab-expansion.html. To disable this, use `mean_resizing=False`
# /tmp/ipykernel_59127/3158277561.py:490: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler()
# Epoch 1/5
# Training:   0%|          | 0/479 [00:00<?, ?it/s]/tmp/ipykernel_59127/3158277561.py:357: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# Evaluating:   0%|          | 0/60 [00:00<?, ?it/s]         The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:   2%|▏         | 1/60 [00:00<00:36,  1.63it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:   3%|▎         | 2/60 [00:01<00:34,  1.70it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:   5%|▌         | 3/60 [00:01<00:32,  1.76it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:   7%|▋         | 4/60 [00:02<00:31,  1.78it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:   8%|▊         | 5/60 [00:02<00:30,  1.81it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  10%|█         | 6/60 [00:03<00:29,  1.84it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  12%|█▏        | 7/60 [00:03<00:28,  1.84it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  13%|█▎        | 8/60 [00:04<00:28,  1.83it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  15%|█▌        | 9/60 [00:04<00:27,  1.82it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  17%|█▋        | 10/60 [00:05<00:27,  1.81it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  18%|█▊        | 11/60 [00:06<00:27,  1.81it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  20%|██        | 12/60 [00:06<00:26,  1.79it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  22%|██▏       | 13/60 [00:07<00:26,  1.80it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  23%|██▎       | 14/60 [00:07<00:25,  1.80it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  25%|██▌       | 15/60 [00:08<00:24,  1.81it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  27%|██▋       | 16/60 [00:08<00:24,  1.83it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  28%|██▊       | 17/60 [00:09<00:23,  1.83it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  30%|███       | 18/60 [00:09<00:22,  1.84it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  32%|███▏      | 19/60 [00:10<00:22,  1.84it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  33%|███▎      | 20/60 [00:11<00:22,  1.81it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  35%|███▌      | 21/60 [00:11<00:21,  1.79it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  37%|███▋      | 22/60 [00:12<00:20,  1.82it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  38%|███▊      | 23/60 [00:12<00:20,  1.81it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  40%|████      | 24/60 [00:13<00:20,  1.78it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  42%|████▏     | 25/60 [00:13<00:19,  1.79it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  43%|████▎     | 26/60 [00:14<00:18,  1.79it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  45%|████▌     | 27/60 [00:14<00:18,  1.77it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  47%|████▋     | 28/60 [00:15<00:17,  1.79it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  48%|████▊     | 29/60 [00:16<00:17,  1.78it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  50%|█████     | 30/60 [00:16<00:16,  1.77it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  52%|█████▏    | 31/60 [00:17<00:16,  1.76it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  53%|█████▎    | 32/60 [00:17<00:15,  1.79it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  55%|█████▌    | 33/60 [00:18<00:14,  1.80it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  57%|█████▋    | 34/60 [00:18<00:14,  1.80it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  58%|█████▊    | 35/60 [00:19<00:13,  1.83it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  60%|██████    | 36/60 [00:19<00:13,  1.82it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  62%|██████▏   | 37/60 [00:20<00:12,  1.82it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  63%|██████▎   | 38/60 [00:21<00:12,  1.82it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  65%|██████▌   | 39/60 [00:21<00:11,  1.83it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  67%|██████▋   | 40/60 [00:22<00:10,  1.84it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  68%|██████▊   | 41/60 [00:22<00:10,  1.81it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  70%|███████   | 42/60 [00:23<00:09,  1.80it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  72%|███████▏  | 43/60 [00:23<00:09,  1.80it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  73%|███████▎  | 44/60 [00:24<00:08,  1.79it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  75%|███████▌  | 45/60 [00:24<00:08,  1.80it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  77%|███████▋  | 46/60 [00:25<00:07,  1.81it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  78%|███████▊  | 47/60 [00:26<00:07,  1.79it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  80%|████████  | 48/60 [00:26<00:06,  1.81it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  82%|████████▏ | 49/60 [00:27<00:06,  1.83it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  83%|████████▎ | 50/60 [00:27<00:05,  1.83it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  85%|████████▌ | 51/60 [00:28<00:04,  1.84it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  87%|████████▋ | 52/60 [00:28<00:04,  1.85it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  88%|████████▊ | 53/60 [00:29<00:03,  1.83it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  90%|█████████ | 54/60 [00:29<00:03,  1.81it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  92%|█████████▏| 55/60 [00:30<00:02,  1.83it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  93%|█████████▎| 56/60 [00:30<00:02,  1.84it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  95%|█████████▌| 57/60 [00:31<00:01,  1.83it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  97%|█████████▋| 58/60 [00:32<00:01,  1.82it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  98%|█████████▊| 59/60 [00:32<00:00,  1.84it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# INFO:sentence_transformers.SentenceTransformer:Use pytorch device_name: cuda
# INFO:sentence_transformers.SentenceTransformer:Load pretrained SentenceTransformer: all-MiniLM-L6-v2
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
#   Train Loss          : 1.3889
#   Validation Loss     : 0.9626
#   Semantic Similarity : 0.4185
#
# Epoch 2/5
# Evaluating:   0%|          | 0/60 [00:00<?, ?it/s]         A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:   2%|▏         | 1/60 [00:00<00:34,  1.72it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:   3%|▎         | 2/60 [00:01<00:33,  1.74it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:   5%|▌         | 3/60 [00:01<00:31,  1.80it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:   7%|▋         | 4/60 [00:02<00:31,  1.80it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:   8%|▊         | 5/60 [00:02<00:30,  1.82it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  10%|█         | 6/60 [00:03<00:29,  1.83it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  12%|█▏        | 7/60 [00:03<00:29,  1.82it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  13%|█▎        | 8/60 [00:04<00:28,  1.80it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  15%|█▌        | 9/60 [00:05<00:28,  1.79it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  17%|█▋        | 10/60 [00:05<00:28,  1.78it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  18%|█▊        | 11/60 [00:06<00:27,  1.78it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  20%|██        | 12/60 [00:06<00:27,  1.75it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  22%|██▏       | 13/60 [00:07<00:26,  1.75it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  23%|██▎       | 14/60 [00:07<00:26,  1.76it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  25%|██▌       | 15/60 [00:08<00:25,  1.77it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  27%|██▋       | 16/60 [00:08<00:24,  1.80it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  28%|██▊       | 17/60 [00:09<00:23,  1.80it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  30%|███       | 18/60 [00:10<00:23,  1.81it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  32%|███▏      | 19/60 [00:10<00:22,  1.81it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  33%|███▎      | 20/60 [00:11<00:22,  1.80it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  35%|███▌      | 21/60 [00:11<00:22,  1.77it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  37%|███▋      | 22/60 [00:12<00:21,  1.80it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  38%|███▊      | 23/60 [00:12<00:20,  1.78it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  40%|████      | 24/60 [00:13<00:20,  1.76it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  42%|████▏     | 25/60 [00:13<00:19,  1.78it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  43%|████▎     | 26/60 [00:14<00:19,  1.77it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  45%|████▌     | 27/60 [00:15<00:18,  1.75it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  47%|████▋     | 28/60 [00:15<00:18,  1.78it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  48%|████▊     | 29/60 [00:16<00:17,  1.74it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  50%|█████     | 30/60 [00:16<00:17,  1.73it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  52%|█████▏    | 31/60 [00:17<00:16,  1.73it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  53%|█████▎    | 32/60 [00:18<00:15,  1.76it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  55%|█████▌    | 33/60 [00:18<00:15,  1.78it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  57%|█████▋    | 34/60 [00:19<00:14,  1.78it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  58%|█████▊    | 35/60 [00:19<00:13,  1.81it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  60%|██████    | 36/60 [00:20<00:13,  1.80it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  62%|██████▏   | 37/60 [00:20<00:12,  1.80it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  63%|██████▎   | 38/60 [00:21<00:12,  1.81it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  65%|██████▌   | 39/60 [00:21<00:11,  1.80it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  67%|██████▋   | 40/60 [00:22<00:10,  1.83it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  68%|██████▊   | 41/60 [00:22<00:10,  1.78it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  70%|███████   | 42/60 [00:23<00:10,  1.78it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  72%|███████▏  | 43/60 [00:24<00:09,  1.78it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  73%|███████▎  | 44/60 [00:24<00:09,  1.77it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  75%|███████▌  | 45/60 [00:25<00:08,  1.79it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  77%|███████▋  | 46/60 [00:25<00:07,  1.80it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  78%|███████▊  | 47/60 [00:26<00:07,  1.79it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  80%|████████  | 48/60 [00:26<00:06,  1.80it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  82%|████████▏ | 49/60 [00:27<00:06,  1.83it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  83%|████████▎ | 50/60 [00:27<00:05,  1.82it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  85%|████████▌ | 51/60 [00:28<00:04,  1.84it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  87%|████████▋ | 52/60 [00:29<00:04,  1.84it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  88%|████████▊ | 53/60 [00:29<00:03,  1.83it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  90%|█████████ | 54/60 [00:30<00:03,  1.79it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  92%|█████████▏| 55/60 [00:30<00:02,  1.81it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  93%|█████████▎| 56/60 [00:31<00:02,  1.84it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  95%|█████████▌| 57/60 [00:31<00:01,  1.82it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  97%|█████████▋| 58/60 [00:32<00:01,  1.80it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  98%|█████████▊| 59/60 [00:32<00:00,  1.82it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# INFO:sentence_transformers.SentenceTransformer:Use pytorch device_name: cuda
# INFO:sentence_transformers.SentenceTransformer:Load pretrained SentenceTransformer: all-MiniLM-L6-v2
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
#   Train Loss          : 0.9036
#   Validation Loss     : 0.8991
#   Semantic Similarity : 0.4268
#
# Epoch 3/5
# Evaluating:   0%|          | 0/60 [00:00<?, ?it/s]         A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:   2%|▏         | 1/60 [00:00<00:34,  1.72it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:   3%|▎         | 2/60 [00:01<00:33,  1.74it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:   5%|▌         | 3/60 [00:01<00:31,  1.81it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:   7%|▋         | 4/60 [00:02<00:31,  1.80it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:   8%|▊         | 5/60 [00:02<00:30,  1.82it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  10%|█         | 6/60 [00:03<00:29,  1.83it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  12%|█▏        | 7/60 [00:03<00:29,  1.83it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  13%|█▎        | 8/60 [00:04<00:28,  1.80it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  15%|█▌        | 9/60 [00:05<00:28,  1.79it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  17%|█▋        | 10/60 [00:05<00:28,  1.76it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  18%|█▊        | 11/60 [00:06<00:27,  1.78it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  20%|██        | 12/60 [00:06<00:27,  1.75it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  22%|██▏       | 13/60 [00:07<00:26,  1.75it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  23%|██▎       | 14/60 [00:07<00:26,  1.73it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  25%|██▌       | 15/60 [00:08<00:25,  1.76it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  27%|██▋       | 16/60 [00:08<00:24,  1.78it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  28%|██▊       | 17/60 [00:09<00:24,  1.79it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  30%|███       | 18/60 [00:10<00:23,  1.79it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  32%|███▏      | 19/60 [00:10<00:22,  1.80it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  33%|███▎      | 20/60 [00:11<00:22,  1.77it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  35%|███▌      | 21/60 [00:11<00:22,  1.75it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  37%|███▋      | 22/60 [00:12<00:21,  1.78it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  38%|███▊      | 23/60 [00:12<00:20,  1.77it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  40%|████      | 24/60 [00:13<00:20,  1.75it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  42%|████▏     | 25/60 [00:14<00:19,  1.76it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  43%|████▎     | 26/60 [00:14<00:19,  1.77it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  45%|████▌     | 27/60 [00:15<00:19,  1.72it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  47%|████▋     | 28/60 [00:15<00:18,  1.74it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  48%|████▊     | 29/60 [00:16<00:17,  1.74it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  50%|█████     | 30/60 [00:16<00:17,  1.72it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  52%|█████▏    | 31/60 [00:17<00:16,  1.72it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  53%|█████▎    | 32/60 [00:18<00:15,  1.75it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  55%|█████▌    | 33/60 [00:18<00:15,  1.77it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  57%|█████▋    | 34/60 [00:19<00:14,  1.77it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  58%|█████▊    | 35/60 [00:19<00:13,  1.80it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  60%|██████    | 36/60 [00:20<00:13,  1.79it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  62%|██████▏   | 37/60 [00:20<00:12,  1.80it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  63%|██████▎   | 38/60 [00:21<00:12,  1.80it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  65%|██████▌   | 39/60 [00:22<00:11,  1.78it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  67%|██████▋   | 40/60 [00:22<00:11,  1.80it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  68%|██████▊   | 41/60 [00:23<00:10,  1.75it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  70%|███████   | 42/60 [00:23<00:10,  1.75it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  72%|███████▏  | 43/60 [00:24<00:09,  1.76it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  73%|███████▎  | 44/60 [00:24<00:09,  1.75it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  75%|███████▌  | 45/60 [00:25<00:08,  1.76it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  77%|███████▋  | 46/60 [00:25<00:07,  1.78it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  78%|███████▊  | 47/60 [00:26<00:07,  1.74it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  80%|████████  | 48/60 [00:27<00:06,  1.74it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  82%|████████▏ | 49/60 [00:27<00:06,  1.78it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  83%|████████▎ | 50/60 [00:28<00:05,  1.78it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  85%|████████▌ | 51/60 [00:28<00:04,  1.81it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  87%|████████▋ | 52/60 [00:29<00:04,  1.83it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# ...
# Evaluating:  42%|████▏     | 25/60 [00:13<00:19,  1.83it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  43%|████▎     | 26/60 [00:14<00:18,  1.80it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  45%|████▌     | 27/60 [00:14<00:18,  1.79it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  47%|████▋     | 28/60 [00:15<00:17,  1.81it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  48%|████▊     | 29/60 [00:15<00:16,  1.83it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  50%|█████     | 30/60 [00:16<00:16,  1.80it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  52%|█████▏    | 31/60 [00:17<00:15,  1.82it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  53%|█████▎    | 32/60 [00:17<00:15,  1.79it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  55%|█████▌    | 33/60 [00:18<00:15,  1.79it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  57%|█████▋    | 34/60 [00:18<00:14,  1.78it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  58%|█████▊    | 35/60 [00:19<00:14,  1.77it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  60%|██████    | 36/60 [00:19<00:13,  1.74it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  62%|██████▏   | 37/60 [00:20<00:12,  1.78it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  63%|██████▎   | 38/60 [00:21<00:12,  1.77it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  65%|██████▌   | 39/60 [00:21<00:11,  1.76it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  67%|██████▋   | 40/60 [00:22<00:11,  1.78it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  68%|██████▊   | 41/60 [00:22<00:10,  1.75it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  70%|███████   | 42/60 [00:23<00:10,  1.76it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  72%|███████▏  | 43/60 [00:23<00:09,  1.79it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  73%|███████▎  | 44/60 [00:24<00:08,  1.80it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  75%|███████▌  | 45/60 [00:24<00:08,  1.81it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  77%|███████▋  | 46/60 [00:25<00:07,  1.82it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  78%|███████▊  | 47/60 [00:26<00:07,  1.83it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  80%|████████  | 48/60 [00:26<00:06,  1.84it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  82%|████████▏ | 49/60 [00:27<00:06,  1.83it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  83%|████████▎ | 50/60 [00:27<00:05,  1.82it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  85%|████████▌ | 51/60 [00:28<00:04,  1.82it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  87%|████████▋ | 52/60 [00:28<00:04,  1.80it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  88%|████████▊ | 53/60 [00:29<00:03,  1.80it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  90%|█████████ | 54/60 [00:29<00:03,  1.81it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  92%|█████████▏| 55/60 [00:30<00:02,  1.82it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  93%|█████████▎| 56/60 [00:31<00:02,  1.79it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  95%|█████████▌| 57/60 [00:31<00:01,  1.77it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  97%|█████████▋| 58/60 [00:32<00:01,  1.79it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# Evaluating:  98%|█████████▊| 59/60 [00:32<00:00,  1.77it/s]A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# INFO:sentence_transformers.SentenceTransformer:Use pytorch device_name: cuda
# INFO:sentence_transformers.SentenceTransformer:Load pretrained SentenceTransformer: all-MiniLM-L6-v2
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# ========== TEST RESULTS ==========
# Test Loss              : 0.7793
# Test Semantic Sim     : 0.4309
#
# ===== RANDOM TEST EXAMPLES =====
#
# --- Example 48 ---
# Raw Report       :
# [ Finding ]_x000D_
# diffuse osteopenia._x000D_
# both hands and feet, degenerative change._x000D_
# _x000D_
# [ Conclusion ]_x000D_
# diffuse osteopenia._x000D_
# both hands and feet, degenerative change._x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# diffuse osteopenia. both hands and feet, degenerative change. diffuse osteopenia. both hands and feet, degenerative change.
# Generated Report :
# no significant bony abnormality sinde last study. no definite interval change since previous findings, both feet and hands with erosions at Lt 1st MTP joint -> RA involvement or suspicious gouty arthritis more likely degenerative changes of Rt 2nd MT head diffuse osteopenia flat foot OA mild hallux valgus deformity otherwise unremarkable fracture site erosion adjacent to right fibula probable old age progression rather than bone disease rec> clinical correlation No additional finding suggested periarticular soft tissue swelling around left 3rd proximal phalangea Small enthes
#
# --- Example 128 ---
# Raw Report       :
# [FINDING       ]_x000D_No significant interval change_x000D__x000D_[CONCLUSION    ]_x000D_No significant interval change_x000D__x000D_[RECOMMENDATION]_x000D_-
# Cleaned Report   :
# No significant interval change
# Generated Report :
# degenerative change. degeneratory changes, both feet and hands diffuse osteopenia hallux valgus deformity mild OA Rt 1st MTP joint soft tissue swelling --> r/o gout involvement more likely severe RA with erosions at TMT joints -> advanced state of significant erosion or inflammatory arthritis vs old fracture progression progressed to Lt 3rd PIP - > probable subluxation periarticular sclerosis type 2 flat footed-flat otherwise no interval increase in size since last study rec> clinical correlation (+) moderate DLA such as pes planus suspicious marginal
#
# --- Example 36 ---
# Raw Report       :
# [ Finding ]_x000D_
# both feet, OA._x000D_
# [ Conclusion ]_x000D_
# both feet, OA._x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# both feet, OA.
# Generated Report :
# No significant interval change since last study. No definite body abnormality, both feet and hands Both hallux valgus Diffuse osteopenia OA Hallux sesamoid bone type II Os naviculare Degenerative changes Rt 1st MTP joint Accessory calcaneal spur Probable old fracture with union --> RA involvement Subluxation of right fibula Severe degeneracondyly soft tissue swelling in lateral portion CMC joints Calcification or healing at r/o anterior malleolus DIP base Suspicious accessory ossicle - Lt
#
# --- Example 236 ---
# Raw Report       :
# [ Finding ]_x000D_
# no bony lesion._x000D_
# [ Diagnosis ]_x000D_
# no bony lesion._x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# no bony lesion. no bony lesion.
# Generated Report :
# no significant interval change since last study. no definite bony lesion on radiographs and bone . No other finding of abnormality suspicious tophis in right 1st MTP joint, both talus neck area with soft tissue swelling --> R/O RA involvement or old fracture vs ulnar negative variance sinde previous findings , medial navicular bones -> rheumatoid arthritis likely degenerative changes diffuse osteopenia hallux valgus deformity erosive instability Osteophytes at calcaneal tuberosity Lt ankle loose body Suspicious gouty mild avulsion state around
#
# --- Example 169 ---
# Raw Report       :
# [ Finding ]_x000D_
# No bony abnormality_x000D_
# _x000D_
# [ Diagnosis ]_x000D_
# No bony abnormality_x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# No bony abnormality No bony abnormality
# Generated Report :
# No bony abnormality. No bone abnormalities, both feet and hands. Both 1st MTP joint soft tissue swelling with increased density in medial portion of right ankle head Slightly advanced RA involvement level at Rt 2nd MT shaft Soft tissue bulging around Lt knee joints Hallus valgus deformity Probable gouty arthritis or osteopenia Degenerative change Suspicious subchondral cysts adjacent to left 3rd metatarsal base OA Pes planis DIPOA Diffuse fracture vs ulnar negative variance Rec) clinical correlation otherwise no significant interval changes since last
#
# --- Example 53 ---
# Raw Report       :
# [ Finding ]_x000D_
# no bony lesion._x000D_
# [ Conclusion ]_x000D_
# no bony lesion._x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# no bony lesion.
# Generated Report :
# No bony abnormality. No bone abnormalities, both feet and hands.
# no significant interval change since last study :D
#
# --- Example 6 ---
# Raw Report       :
# [ Finding ]_x000D_
# 포함된 bone에 이상소견은 보이지 않음._x000D_
# 보이는 한도내에 soft tissue에 이상소견 보이지 않음._x000D_
# [ Diagnosis ]_x000D_
# No bony abnormality_x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# bone . soft tissue . No bony abnormality
# Generated Report :
# No bony abnormality No bone abnormalities
#
# --- Example 87 ---
# Raw Report       :
# [ Finding ]_x000D_
# mild degenerative change_x000D_
# [ Conclusion ]_x000D_
# mild degenerative change_x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# mild degenerative change
# Generated Report :
# No significant interval change since last study. No signficant abnormality of both feet, hands and wrists with erosions at Rt 1st MTP joint or Lt 5th MT head -> r/o gout involvement Suspicious periarticular osteopenia Both accessory naviuclar bone type II Degenerative changes OA Hallux valgus deformity Subluxation Os trigonum Calcification in right calcaneal tuberosity Erosion on radiographs Flat foot DIP joints Joint space narrowing --> RA vs tibiotalitis TMT &
#
# --- Example 91 ---
# Raw Report       :
# [ Finding ]_x000D_
# Enthesophyte of calcaneal insertion site of achilles tendon, both._x000D_
# [ Diagnosis ]_x000D_
# _x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# Enthesophyte of calcaneal insertion site of achilles tendon, both.
# Generated Report :
# degenerative change. degeneratory changes of both feet, hands and wrists since last study : REC) clinical correlation with Rt 1st MTP joint erosion --> rec> consider F/E gout arthritis or osteopenia Lt ankle soft tissue swelling -> rheumatoid arthrosis involvement otherwise no significant bony lesion on radiographs No other findings to date at left 2nd MT head level Both accessory navicular bone type II Degenerous lesions in right foot dorsum hallux valgus deformity OA Probable RA vs ossification rather than old fracture(
#
# --- Example 30 ---
# Raw Report       :
# [ Finding ]_x000D_
# spur change of both calcaneous _x000D_
# _x000D_
# Rt. 1st MTP joint, gout arthritis with tophi._x000D_
# [ Conclusion ]_x000D_
# spur change of both calcaneous _x000D_
# _x000D_
# Rt. 1st MTP joint, gout arthritis with tophi._x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# spur change of both calcaneous Rt. 1st MTP joint, gout arthritis with tophi.
# Generated Report :
# No bony abnormality No significant interval change since last study. Slightly increased soft tissue swelling in medial portion of right 1st MTP joint with bone erosions at both 5th metatarsal head and left 2nd MT head level, suggesting probable gouty arthritis involvement rather than fracture or osteopenia induced mild degenerative changes flat footed state (+) Lt ankle OA Rt knee accessory navicular bones type II otherwise no remarkable finding on radiographs Both feet diffuse vascular calcification --> RA vs rec> clinical correlation Hallux valgus deformity Degenerous os trig

# %%
print("\n===== RANDOM TEST EXAMPLES =====")
for idx in random.sample(range(len(test_ds)), min(20, len(test_ds))):
    ex = test_ds[idx]
    raw   = ex['raw_report']
    clean = ex['cleaned_report']
    fi    = ex['full_img'].unsqueeze(0).to(device)
    pa    = ex['patches'].unsqueeze(0).to(device)

    # build encoder states
    g = model.global_encoder(fi)
    g = model.global_proj(g).unsqueeze(1)
    B, N, C, H, W = pa.shape
    p = pa.view(B * N, C, H, W)
    pf = model.patch_encoder(p)
    pf = model._pool(pf)
    pf = model.patch_proj(pf)
    pf = pf.view(B, N, 768)

    cat, _ = model.attn(torch.cat([g, pf], dim=1),
                        torch.cat([g, pf], dim=1),
                        torch.cat([g, pf], dim=1))
    comb = model.norm(cat)

    # generate with decoder_start_token_id
    gen_ids = model.decoder.generate(
        input_ids=None,
        encoder_hidden_states=comb,
        decoder_start_token_id=tokenizer.bos_token_id,
        eos_token_id=tokenizer.eos_token_id,
        pad_token_id=tokenizer.eos_token_id,
        max_length=120,
        do_sample=True,
        top_k=40,
        top_p=0.95,
        temperature=0.5,
        repetition_penalty=1.3,
    )

    gen = tokenizer.decode(gen_ids[0], skip_special_tokens=True)

    print(f"\n--- Example {idx} ---")
    print(f"Raw Report       : \n{raw}")
    print(f"Cleaned Report   : \n{clean}")
    print(f"Generated Report : \n{gen}")
# Out:
# ===== RANDOM TEST EXAMPLES =====
#
# --- Example 195 ---
# Raw Report       :
# [ Finding ]_x000D_
# _x000D_
# [ Diagnosis ]_x000D_
# no significant interval change sinde last study._x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# no significant interval change sinde last study.
# Generated Report :
# No bony abnormality. No bone abnormalities, both feet and hands.
# no significant interval change since last study : no definite evidence of gout involvement on radiographs or otherwise --> R/O RA vs rec> clinical correlation -> rheumatoid arthritis rather than fracture related disease progression degenerative changes Lt ankle soft tissue swelling with subtle increased density in medial aspect area around 5th metatarsal head level Degenerous osteopenia Hallux valgus deformity Os naviculare type III (right) Small enthesophyte at right distimal phalanx --- possible
#
# --- Example 7 ---
# Raw Report       :
# [ Finding ]_x000D_
# _x000D_
# [ Diagnosis ]_x000D_
# Gouty arthritis in both 1st MTP._x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# Gouty arthritis in both 1st MTP.
# Generated Report :
# no significant bony lesion on radiographs. no definite interval change of gout arthritis, both feet and wrist since last study (both 1st MTP joints). --> R/O RA involvement vs rec> clinical correlation or old fracture with bone erosive findings at right distal fibular head level rather than left calcaneus deformity (+) medial malleolus joint moderate OA navicular bones type II ulnar negative variance sinde previous intertarsum measurement No additional finding to date Suggested corrective osteotomy for talonavigation Joint space narrowing in r
#
# --- Example 104 ---
# Raw Report       :
# [ Finding ]_x000D_
# no significant bony lesion on radiographs._x000D_
# no significant bony lesion_x000D_
# [ Conclusion ]_x000D_
# no significant bony lesionno significant bony lesion on radiographs._x000D_
# _x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# no significant bony lesion on radiographs. no significant bony lesion no significant bony lesionno significant bony lesion on radiographs.
# Generated Report :
# no significant bony abnormality. no definite interval change since last study : multiple fracture with union, right fibula -> r/o gout involvement more likely degenerative changes of both feet and hands at Rt 2nd MT head - probable subluxation rather than osteopenia mild hallux valgus deformity Lt ankle soft tissue swelling --> RA suggested otherwise moderate OA on radiographs (+) knee joint effusion or calcification diffuse vascular disease Hallux sesamoid bone type III bilateral accessory navicular bones pes planis tendon insertion site suspicious periarticular thickening
#
# --- Example 116 ---
# Raw Report       :
# [FINDING       ]_x000D_R/O gout arthritis, both feet and hands.
# both 1st toe and finger, intramedullary scleoritc lesions
#   --> R/O bone infarction_x000D__x000D_[CONCLUSION    ]_x000D_R/O gout arthritis, both feet and hands.
# both 1st toe and finger, intramedullary scleoritc lesions
#   --> R/O bone infarction_x000D__x000D_[RECOMMENDATION]_x000D_-
# Cleaned Report   :
# R/O gout arthritis, both feet and hands. both 1st toe and finger, intramedullary scleoritc lesions --> R/O bone infarction
# Generated Report :
# degenerative change. degeneratory changes, both feet and hands with erosions at Rt 1st MTP joint -> r/o gout involvement more likely mild hallux valgus deformity of right foot ulnar neck diffuse osteopenia Lt ankle soft tissue swelling --> RA vs otherwise no significant bony abnormality rec> clinical correlation No interval progression to consider Fx severe OA periarticular instability fracture or TKA related subluxation state Degenerous cystic lesion in medial portion Subcortical calcaneal spur Suspicious large bone erosion adjacent
#
# --- Example 190 ---
# Raw Report       :
# [ Finding ]_x000D_
# R/O malunion state, left ulnar styloid process_x000D_
# Degenerative change_x000D_
# _x000D_
# Both hallux valgus_x000D_
# _x000D_
# [ Conclusion ]_x000D_
# R/O malunion state, left ulnar styloid process_x000D_
# Degenerative change_x000D_
# _x000D_
# Both hallux valgus_x000D_
# _x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# R/O malunion state, left ulnar styloid process Degenerative change Both hallux valgus
# Generated Report :
# no significant bony lesion on radiographs. no definite interval change of gout arthritis since last study with tibiotalar joint replacement, both feet and hands (Rt). otherwise unremarkable fracture or healing at right distal fibula bone head. rec> clinical correlation between RA involvement vs.: old avulsion injury -> r/o inflammatory reaction syndrome type II degenerative changes flat footed bipartite sesamoiditis mild hallux valgus deformity diffuse osteopenia Lt ankle soft tissue swelling --> RKD2 severe OA multiple os trigonum pes
#
# --- Example 191 ---
# Raw Report       :
# [ Finding ]_x000D_
# no bony lesion._x000D_
# [ Conclusion ]_x000D_
# no bony lesion._x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# no bony lesion.
# Generated Report :
# no significant bony lesion on radiographs. no definite interval change of other findings since last study, both feet and hands (Lt ankle) rec> clinical correlation with callus formation or bone erosions at Rt 2nd MT head -> probable gouty arthritis involvement rather than old fracture/suspicious soft tissue swelling in medial portion of left 1st MTP joint level progression to rheumatoid osteopenia degenerative changes diffuse vascular calcifications around right foot > mild inflammatory state such as RA more likely moderate OA including knee joints suspicious subluxation os navicul
#
# --- Example 76 ---
# Raw Report       :
# [ Finding ]_x000D_
# Rt. 1st MTP joint, erosion and soft tissue swelling.  --> gout arthritis, suggested._x000D_
# [ Conclusion ]_x000D_
# Rt. 1st MTP joint, erosion and soft tissue swelling.  --> gout arthritis, suggested._x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# Rt. 1st MTP joint, erosion and soft tissue swelling. --> gout arthritis, suggested.
# Generated Report :
# No significant interval change since last study. No remarkable abnormality of both feet and hands, esp., soft tissue swelling in medial portion of right ankle joint with subluxation or osteophyte formation on radiographs rather than rec> clinical correlation -> r/o gout involvement fracture vs. old stress fractures mild degenerative changes Lt elbow OA Rt 1st MTP joints erosive arthritis diffuse vascular calcification pes planus deformity sclerotic lesion at TMT level --> RA involvements Hallux valgum Degenerous cystic lesions Os naviculocune
#
# --- Example 221 ---
# Raw Report       :
# [FINDING       ]_x000D_-_x000D__x000D_[CONCLUSION    ]_x000D_old fracture, Rt lateral malleolus
# soft tissue swelling, Rt lateral ankle _x000D__x000D_[RECOMMENDATION]_x000D_-
# Cleaned Report   :
# - old fracture, Rt lateral malleolus soft tissue swelling, Rt lateral ankle
# Generated Report :
# Rt. ankle soft tissue swelling with erosions at both 5th MTP joint -> r/o gout involvement, more likely mild degenerative change diffuse osteopenia RA-related OA Rheumatoid arthritis type II and Lt 1st MT head Flat foot Suspicious erosion or calcification adjacent to TMT hallus valgus Diffuse vascular disease Degenerous cystic lesion in left 2nd metatarsal shaft Hallux sesamoid bone - suspicious subchondral sclerosis (SLE) Both feet Probable old fracture on right 3rd finger
#
# --- Example 189 ---
# Raw Report       :
# [ Finding ]_x000D_
# both accessory navicular bone, type II_x000D_
# [ Conclusion ]_x000D_
# both accessory navicular bone, type II_x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# both accessory navicular bone, type II
# Generated Report :
# No bony abnormality. No bone abnormalities, both feet and wrist. Both hands, no significant interval change since last study . Suspicious soft tissue swelling in medial portion of right 1st MTP joint with suspicious erosive changes at the distal tibial tuberosity level , left foot dorsum -> r/o RA involvement rec> clinical correlation otherwiseno definite evidence suggestive of gout arthritis on radiographs or CT findings Lt ankle OA Rt finger amputation state Probable old fracture vs probable osteopenia degenerative variance --> REC) inflammatory calcification progression progressed to C
#
# --- Example 146 ---
# Raw Report       :
# [ Finding ]_x000D_
# Minimal OA, both knee_x000D_
# Degenerative change, foot_x000D_
# Os naviculare type III, both_x000D_
# Degenerative change in distal DRUJ_x000D_
# [ Conclusion ]_x000D_
# Minimal OA, both knee_x000D_
# Degenerative change, foot_x000D_
# Os naviculare type III, both_x000D_
# Degenerative change in distal DRUJ_x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# Minimal OA, both knee Degenerative change, foot Os naviculare type III, both Degenerative change in distal DRUJ
# Generated Report :
# no bony lesion. no significant interval change since last study : multiple fracture with callus formation or calcification, right fibula and ankle joint area -> r/o gout involvement rather than suspicious old avulsion injury rec> clinical correlation of both feet > RA related OA Rt 1st MTP joints erosion --> osteotomy tophi vs psoriatic arthritis type 2 otherwise noted mild degenerative changes Lt knee soft tissue swelling diffuse vascular insufficiency os naviculocuneiform coalition pes planum hallux valgiora deformity flat foot SLE elbow severe sub
#
# --- Example 237 ---
# Raw Report       :
# [ Finding ]_x000D_
# 포함된 bone에 이상소견은 보이지 않음._x000D_
# 보이는 한도내에 soft tissue에 이상소견 보이지 않음._x000D_
# [ Diagnosis ]_x000D_
# No bony abnormality_x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# bone . soft tissue . No bony abnormality
# Generated Report :
# No bony abnormality. No bone abnormalities, both feet and wrists.
# no significant interval change since last study . no definite correlation with RA patient rec> clinical findings or old fracture history > R/O gout arthritis involvement of navicular bones , esp rt 1st MTP joint Joint space narrowing at Lt ankle -> IP joints Degenerative changes in talus Accessory osteopenia Probable tophi (RA) : 2nd MT head CMC-2 hallux valgus Small enthesophyte adjacent calcaneal tuberosity --> OA Hallux ses
#
# --- Example 211 ---
# Raw Report       :
# [FINDING       ]_x000D_Degenerative change
# OA, 1st MTP joint, both_x000D__x000D_[CONCLUSION    ]_x000D_Degenerative change
# OA, 1st MTP joint, both_x000D__x000D_[RECOMMENDATION]_x000D_-
# Cleaned Report   :
# Degenerative change OA, 1st MTP joint, both
# Generated Report :
# degenerative change diffuse osteopenia degeneratory changes joint space narrowing, erosions at both 1st MTP and 5th MT head -> RA involvement mild hallux valgus deformity old fracture with union type 2 flat foot OA. pes planum cuboid patella tendon insertion site of postop right 3rd DIP joints Rt knee soft tissue swelling around Lt ankle suspicious erosion or calcification adjacent to r/o gouty arthritis progression progressed state --> LT wrist severe ossicle dislocation Hallux sessamoid bone S-halluciform thick
#
# --- Example 192 ---
# Raw Report       :
# [ Finding ]_x000D_
# No signficant interval change since last study_x000D_
# [ Conclusion ]_x000D_
# No signficant interval change since last study_x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# No signficant interval change since last study
# Generated Report :
# No bony abnormality. No signficant interval change since last study . Suspicious gouty arthritis, right 1st MTP joint and left 2nd MT head , both hands with suspicious erosions at Lt ankle joints -> RA involvement or otherwise no significant lesion on radiographs : REC) clinical correlation rather than bone erosion state of medial side (right 3rd distal phalanx). --> R/O old avulsion injury vs rec> healing in milder condition possible os navicularis fracture type II degenerative changes periarticular osteopenia pes plan
#
# --- Example 171 ---
# Raw Report       :
# [ Finding ]_x000D_
# Hallux valgus._x000D_
# [ Diagnosis ]_x000D_
# _x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# Hallux valgus.
# Generated Report :
# no significant bony lesion on radiographs. no definite interval change since last study, both feet and wrist (Rt.) rec> clinical correlation with R/O fracture or old avulsion injury > gout arthritis involvement of left 1st MTP joint Degenerative changes Both calcaneous OA Lt fibular tip Soft tissue swelling in lateral portion --> RA vs bone disease rather than osteoarthritis No signficant abnormality Suspicious subchondral cystic deformity at right distal phalanx head Subtle increased density around medial aspect Slightly softening over posterior side
#
# --- Example 88 ---
# Raw Report       :
# [ Finding ]_x000D_
# _x000D_
# [ Diagnosis ]_x000D_
# 1. joint space narrowing with possible bone erosions in right 4th MTP, left 5th MTP joint._x000D_
#   --- with soft tissue swelling in left 5th MTP joint._x000D_
#   ---> possible rheumatoid arthritis._x000D_
# 2. enthesophytes in both calcaneus, plantar area._x000D_
# _x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# 1. joint space narrowing with possible bone erosions in right 4th MTP, left 5th MTP joint. --- with soft tissue swelling in left 5th MTP joint. ---> possible rheumatoid arthritis. 2. enthesophytes in both calcaneus, plantar area.
# Generated Report :
# degenerative change. degeneratory changes, both feet and hands with erosive erosion --> R/O RA involvement or old fracture state of right MT head suspicious subchondral cyst in left 3rd metatarsal shaft base rather than proximal phalanx neck area
# no significant bony lesion on radiographs since last study No definite interval increase OA over previous 2nd to 5th MTP joint space narrowing -> rheumatoid arthritis vs osteopenia mild hallux valgus deformity diffuse vascular calcification Lt ankle soft tissue swelling sinde medial
#
# --- Example 149 ---
# Raw Report       :
# [ Finding ]_x000D_
# No significant interval change_x000D_
# [ Conclusion ]_x000D_
# No significant interval change_x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# No significant interval change
# Generated Report :
# degenerative change. degeneratory changes, both feet and hands with erosions at Rt 1st MTP joint -> r/o inflammatory arthritis involvement mild hallux valgus deformity diffuse osteopenia bilateral accessory navicular bone type II pes planis progression of RA more likely Lt ankle OA suspicious erosion in medial aspect posterior calcaneal tuberosity advanced fracture or tibia insertion site periarticular thickening --> rec> clinical correlation otherwise no significant interval difference since last study No definite findings abnormality sinde severe soft tissue swelling around right 5th metatarsse
#
# --- Example 119 ---
# Raw Report       :
# [ Finding ]_x000D_
# degenerative change._x000D_
# [ Conclusion ]_x000D_
# degenerative change._x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# degenerative change.
# Generated Report :
# no bony lesion. no significant interval change since last study, both feet and hands (both wrist) rec> clinical correlation with callus formation or fracture at Rt 2nd MT head --> r/o RA involvement vs tibiotalar joint space narrowing -> probable gouty arthritis rather than old age progression of osteopenia degenerative changes Lt ankle soft tissue swelling diffuse vascular calcifications periarticular OA pes planum deformity accessory naviculocuneiform coalition Degenerous os trigonare type III Os subfibular stenosis Hallux valg
#
# --- Example 113 ---
# Raw Report       :
# [ Finding ]_x000D_
# _x000D_
# [ Diagnosis ]_x000D_
# Lt. navicular bone, medial jaspect, suspicious bony erosions._x000D_
#      : with ecogenic foci (+)_x000D_
# Lt. MTP joints, periarticular osteopenia._x000D_
# _x000D_
#   --> postop. change vs active gouty arthritis._x000D_
# _x000D_
# rec> clinical correlation and consider F/E_x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# Lt. navicular bone, medial jaspect, suspicious bony erosions. : with ecogenic foci (+) Lt. MTP joints, periarticular osteopenia. --> postop. change vs active gouty arthritis. rec> clinical correlation and consider F/E
# Generated Report :
# No bony abnormality No significant interval change since last study. --- possible gout, left ankle joint and medial malleolus Diffuse osteopenia Suspicious bone erosion at both 1st MT head with callonavicular coalition in right distal phalanx area Os naviculocuneiform type III Calcification of talocal shafts Degenerative changes Both accessory ossicle --> R/O RA involvement OA Probable old fracture or os trigonum Rec) Clinical correlation Hallux valgus deformity Lt.) degeneratory arthritis Pes planis pes
#
# --- Example 181 ---
# Raw Report       :
# [ Finding ]_x000D_
# Lt. foot soft tissue swelling._x000D_
# Lt. 1st MTP joint, suspicious erosion._x000D_
# [ Conclusion ]_x000D_
# Lt. foot soft tissue swelling._x000D_
# Lt. 1st MTP joint, suspicious erosion._x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# Lt. foot soft tissue swelling. Lt. 1st MTP joint, suspicious erosion.
# Generated Report :
# No bony abnormality. No gout arthritis.
#
# --- Example 106 ---
# Raw Report       :
# [FINDING       ]_x000D_no significant bony abnormality_x000D__x000D_[CONCLUSION    ]_x000D_no significant bony abnormality_x000D__x000D_[RECOMMENDATION]_x000D_-
# Cleaned Report   :
# no significant bony abnormality
# Generated Report :
# No significant interval change since last study. No definite abnormality of both feet and hands, Lt foot OA Rt 1st MTP joint erosions at TMT joints -> r/o RA involvement more likely degenerative changes diffuse osteopenia hallux valgus deformity mild radiopaque lesion with subluxation state probable gouty arthritis type 2 flatfoots ankle no bony abnormalities bilateral accessory navicular bone fracture coalition soft tissue swelling around right 5th metatarsal head suspicious periarticular inflammatory reaction rather than old age progression progressed knee severe interc
