# %%
import os
import re
import json
import unicodedata
import random
import logging
from collections import defaultdict, Counter

import numpy as np
import cv2
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, random_split
from PIL import Image
from torchvision import transforms
from tqdm import tqdm
import timm
from transformers import GPT2Tokenizer, GPT2LMHeadModel
from sentence_transformers import SentenceTransformer
import matplotlib.pyplot as plt

# LoRA imports
from peft import LoraConfig, get_peft_model, TaskType

# =============================================================================
# Logging configuration: write INFO+ logs only to training.log (no console output)
# =============================================================================
for h in logging.root.handlers[:]:
    logging.root.removeHandler(h)
logging.basicConfig(
    filename='training.log',
    filemode='w',
    level=logging.INFO,
    format='%(asctime)s %(levelname)-8s %(message)s',
    datefmt='%Y-%m-%d %H:%M:%S'
)

# =============================================================================
# Utility functions
# =============================================================================
def count_labels(data, target_classes, cfg):
    class_counts = defaultdict(int)
    data_by_class = defaultdict(list)
    for entry in tqdm(data.values(), desc="Counting dataset"):
        lbl = entry.get('class_label', '').lower()
        if lbl in target_classes and os.path.exists(entry['file_path']):
            class_counts[lbl] += 1
            data_by_class[lbl].append(entry)
    return class_counts, data_by_class

def prepare_abnormal_normal_data(data, cfg):
    random.seed(42)
    abnormal = ['ra', 'oa', 'gout']
    normal = ['normal']
    class_counts, data_by_class = count_labels(data, abnormal + normal, cfg)
    combined = {
        'abnormal': sum((data_by_class[c] for c in abnormal), []),
        'normal': data_by_class['normal']
    }
    combined_counts = {
        'abnormal': sum(class_counts[c] for c in abnormal),
        'normal': class_counts['normal']
    }
    if not cfg.DATASET.BALANCE and not cfg.DATASET.AUGMENT:
        return sum(combined.values(), []), combined_counts, combined_counts
    min_count = min(combined_counts.values())
    balanced = []
    final_counts = {}
    for lbl, items in combined.items():
        sampled = random.sample(items, min_count)
        balanced.extend(sampled)
        final_counts[lbl] = min_count
    if cfg.DATASET.AUGMENT:
        balanced *= 2
    return balanced, combined_counts, final_counts

def prepare_data(data, target_classes, cfg, is_binary=False):
    random.seed(42)
    if len(target_classes) == 2 and 'abnormal' in target_classes and 'normal' in target_classes:
        logging.info("Using abnormal-vs-normal logic")
        return prepare_abnormal_normal_data(data, cfg)
    class_counts, data_by_class = count_labels(data, target_classes, cfg)
    logging.info(f"Original class distribution: {class_counts}")
    if not cfg.DATASET.BALANCE and not cfg.DATASET.AUGMENT:
        return sum(data_by_class.values(), []), class_counts, class_counts
    min_count = min(class_counts.values())
    balanced, final_counts = [], {}
    for lbl in target_classes:
        sampled = random.sample(data_by_class[lbl], min_count)
        balanced.extend(sampled)
        final_counts[lbl] = min_count
    logging.info(f"Balanced class distribution: {final_counts}")
    if cfg.DATASET.AUGMENT:
        balanced *= 2
    return balanced, class_counts, final_counts

# =============================================================================
# Transforms
# =============================================================================
imagenet_mean = [0.485, 0.456, 0.406]
imagenet_std  = [0.229, 0.224, 0.225]

train_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(imagenet_mean, imagenet_std)
])
patch_transform = transforms.Compose([
    transforms.Resize((112, 112)),
    transforms.ToTensor(),
    transforms.Normalize(imagenet_mean, imagenet_std)
])

# =============================================================================
# Dataset (with FINDINGS: prefix in __getitem__)
# =============================================================================
class FinalSamplesDataset(Dataset):
    def __init__(self, cfg, image_transform=train_transform, patch_transform=patch_transform):
        self.cfg = cfg
        self.image_transform = image_transform
        self.patch_transform = patch_transform

        self.target_classes = cfg.DATASET.TARGET_CLASSES
        if isinstance(self.target_classes, str):
            self.target_classes = self.target_classes.split(",")

        self.is_binary = len(self.target_classes) == 2
        self.abnormal_classify = self.is_binary and 'abnormal' in self.target_classes
        self.abnormal_mapping = (
            {'ra': 'abnormal', 'oa': 'abnormal', 'gout': 'abnormal', 'normal': 'normal'}
            if self.abnormal_classify else None
        )

        with open(cfg.DATASET.JSON, 'r') as f:
            raw_list = json.load(f)

        filtered = []
        for item in raw_list:
            merged = item.get('merged_image_path', '')
            fp = item.get('file_paths', [])
            if isinstance(fp, str):
                fp = [fp]
            paths = [merged] + fp
            if any(os.path.exists(p) for p in paths):
                filtered.append((merged, fp, item))

        self.data = {}
        for i, (merged, fp, item) in enumerate(filtered):
            cls = item.get('class', 'unknown').lower()
            if self.abnormal_mapping:
                cls = self.abnormal_mapping.get(cls, cls)
            self.data[i] = {
                'file_path': merged,
                'left_right_file_path': fp,
                'class_label': cls,
                'diagnosis': item.get('diagnosis', ''),
                'keypoints': item.get('keypoints', {})
            }

        if self.is_binary:
            balanced, _, _ = prepare_data(self.data, self.target_classes, cfg, True)
            self.data = {i: e for i, e in enumerate(balanced)}

        self.tokenizer = None
        self.eos_token  = None

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        e = self.data[idx]
        img = Image.open(e['file_path']).convert('RGB')
        img = self.image_transform(img)
        logging.info(f"[Dataset] full_img shape: {img.shape}")

        patches = self._gen_patches(e['left_right_file_path'], e['keypoints'])
        pt = [self.patch_transform(Image.fromarray(p)) for p in patches]
        patches_tensor = torch.stack(pt, 0) if pt else torch.zeros(34, 3, 112, 112)
        logging.info(f"[Dataset] patches_tensor shape: {patches_tensor.shape}")

        raw = e.get('diagnosis', '')
        clean = self._clean_report(raw)

        # <<<— CHANGED: prepend FINDINGS: so model learns after it
        input_text = f"{self.tokenizer.bos_token} FINDINGS: {clean} {self.tokenizer.eos_token}"
        tok = self.tokenizer(input_text, truncation=True, max_length=512, return_tensors='pt')

        input_ids      = tok['input_ids'].squeeze(0)
        attention_mask = tok['attention_mask'].squeeze(0)
        logging.info(f"[Dataset] input_ids shape: {input_ids.shape}, attention_mask shape: {attention_mask.shape}")

        return {
            'full_img':       img,
            'patches':        patches_tensor,
            'raw_report':     raw,
            'cleaned_report': clean,
            'input_ids':      input_ids,
            'attention_mask': attention_mask
        }

    def _gen_patches(self, paths, kps_dict, crop_size=(200, 300), patch_size=(112, 112)):
        def extract(arr, side_kps):
            lst = []
            pts = side_kps[0]['keypoints']
            for i in range(17):
                x, y, s = int(pts[3*i]), int(pts[3*i+1]), pts[3*i+2]
                if s > 0:
                    x0 = max(x - crop_size[0]//2, 0)
                    y0 = max(y - crop_size[1]//2, 0)
                    x1 = min(x + crop_size[0]//2, arr.shape[1])
                    y1 = min(y + crop_size[1]//2, arr.shape[0])
                    c = arr[y0:y1, x0:x1]
                    if c.size:
                        lst.append(cv2.resize(c, patch_size))
            return lst

        def pad17(lst):
            black = np.zeros((patch_size[1], patch_size[0], 3), np.uint8)
            while len(lst) < 17:
                lst.append(black)
            return lst[:17]

        left, right = [], []
        if len(paths) == 1:
            pth = paths[0]
            if not pth or not os.path.exists(pth):
                return pad17([]) + pad17([])
            img_arr = cv2.imread(pth)
            if img_arr is None:
                return pad17([]) + pad17([])
            arr = cv2.cvtColor(img_arr, cv2.COLOR_BGR2RGB)
            if kps_dict.get('left'):  left  = extract(arr, kps_dict['left'])
            if kps_dict.get('right'): right = extract(arr, kps_dict['right'])
        else:
            for side, pth in zip(['left','right'], paths):
                if pth and os.path.exists(pth):
                    img_arr = cv2.imread(pth)
                    if img_arr is not None:
                        arr = cv2.cvtColor(img_arr, cv2.COLOR_BGR2RGB)
                        if kps_dict.get(side):
                            lst = extract(arr, kps_dict[side])
                            if side=='left':  left  = lst
                            else:             right = lst

        if left and not right:
            right = [cv2.flip(p,1) for p in left]
        if right and not left:
            left  = [cv2.flip(p,1) for p in right]
        if not left and not right:
            return pad17([]) + pad17([])

        return pad17(left) + pad17(right)

    def _clean_report(self, text):
        text = unicodedata.normalize('NFKC', text or '')
        text = re.sub(r'(?m)^-+\s*$', '', text)
        text = re.sub(r'[^\x00-\x7F]+', ' ', text)
        text = re.sub(r'([.!?]){2,}', r'\1', text)
        text = re.sub(r'\[\s*finding\s*\]', '[FINDING]', text, flags=re.IGNORECASE)
        text = re.sub(r'\[\s*conclusion\s*\]', '[CONCLUSION]', text, flags=re.IGNORECASE)
        text = re.sub(r'\[\s*diagnosis\s*\]', '[DIAGNOSIS]', text, flags=re.IGNORECASE)
        parts = re.split(r'\[\s*recommend(?:ation)?\s*\]', text, flags=re.IGNORECASE)
        text = parts[0]
        fm = re.search(r'\[FINDING\](.*?)(?=\[|$)', text, flags=re.IGNORECASE|re.DOTALL)
        cm = re.search(r'\[CONCLUSION\](.*?)(?=\[|$)', text, flags=re.IGNORECASE|re.DOTALL)
        if fm and cm and fm.group(1).strip().lower() == cm.group(1).strip().lower():
            text = re.sub(r'\[CONCLUSION\].*?(?=\[|$)', '', text, flags=re.IGNORECASE|re.DOTALL)
        text = re.sub(r'\[\s*(FINDING|CONCLUSION|DIAGNOSIS)\s*\]', '', text, flags=re.IGNORECASE)
        text = text.replace('_x000D_', ' ')
        return re.sub(r'\s+', ' ', text).strip()

# =============================================================================
# Collate function
# =============================================================================
def collate_fn(batch):
    imgs = torch.stack([b['full_img'] for b in batch])
    logging.info(f"[Collate] imgs: {imgs.shape}")

    pts = [b['patches'] for b in batch]
    max_p = max(p.shape[0] for p in pts)
    pads = []
    for p in pts:
        if p.shape[0] < max_p:
            pad = torch.zeros((max_p - p.shape[0], *p.shape[1:]))
            p = torch.cat([p, pad], dim=0)
        pads.append(p)
    patches = torch.stack(pads, 0)
    logging.info(f"[Collate] patches: {patches.shape}")

    ids   = [b['input_ids'] for b in batch]
    masks = [b['attention_mask'] for b in batch]
    ids   = nn.utils.rnn.pad_sequence(ids, batch_first=True, padding_value=tokenizer.pad_token_id)
    masks = nn.utils.rnn.pad_sequence(masks, batch_first=True, padding_value=0)
    logging.info(f"[Collate] ids: {ids.shape}, masks: {masks.shape}")

    return {
        'full_imgs':       imgs,
        'patches':         patches,
        'input_ids':       ids,
        'attention_mask':  masks,
        'raw_reports':     [b['raw_report']     for b in batch],
        'cleaned_reports': [b['cleaned_report'] for b in batch]
    }

# =============================================================================
# Model definition, with LoRA integration
# =============================================================================
class MultiModalModel(nn.Module):
    def __init__(self, gpt2_model_name='gpt2'):
        super().__init__()
        # Global image encoder
        self.global_encoder = timm.create_model('swin_base_patch4_window7_224', pretrained=True)
        self.global_encoder.reset_classifier(0)
        self.global_proj    = nn.Linear(self.global_encoder.num_features, 768)

        # Patch encoder
        self.patch_encoder  = timm.create_model('resnet50', pretrained=True)
        self.patch_encoder.fc = nn.Identity()
        self.patch_proj     = nn.Linear(self.patch_encoder.num_features, 768)

        # Fusion
        self.attn           = nn.MultiheadAttention(embed_dim=768, num_heads=8, batch_first=True)
        self.norm           = nn.LayerNorm(768)

        # GPT-2 decoder w/ cross-attention
        self.decoder = GPT2LMHeadModel.from_pretrained(
            gpt2_model_name, add_cross_attention=True
        )

        # LoRA on self-attn
        lora_config = LoraConfig(
            task_type=TaskType.CAUSAL_LM,
            r=16,
            lora_alpha=32,
            lora_dropout=0.05,
            target_modules=["c_attn", "c_proj"],
            bias="none"
        )
        self.decoder = get_peft_model(self.decoder, lora_config)
        print("LoRA adapters integrated into GPT-2 decoder")

    def _pool(self, feats):
        return feats.mean(dim=[2,3]) if feats.ndim>2 else feats

    def forward(self, imgs, patches, input_ids, attention_mask, decoder_labels=None):
        g_feats = self.global_encoder(imgs)
        g = self.global_proj(g_feats).unsqueeze(1)

        B,N,C,H,W = patches.shape
        p = patches.view(B*N, C, H, W)
        pf_feats = (
            self.patch_encoder.forward_features(p)
            if hasattr(self.patch_encoder, 'forward_features')
            else self.patch_encoder(p)
        )
        pf_pooled = self._pool(pf_feats)
        pf = self.patch_proj(pf_pooled).view(B, N, 768)

        cat, _ = self.attn(
            torch.cat([g, pf],1),
            torch.cat([g, pf],1),
            torch.cat([g, pf],1)
        )
        comb = self.norm(cat)

        out = self.decoder(
            input_ids=input_ids,
            attention_mask=attention_mask,
            encoder_hidden_states=comb,
            labels=decoder_labels
        )
        return out

# =============================================================================
# Training & evaluation loops
# =============================================================================
def train_epoch(model, loader, optimizer, scaler, device):
    model.train()
    total_loss = 0.
    for b in tqdm(loader, desc="Training", leave=False):
        imgs = b['full_imgs'].to(device)
        pts  = b['patches'].to(device)
        ids  = b['input_ids'].to(device)
        msk  = b['attention_mask'].to(device)

        optimizer.zero_grad()
        with torch.amp.autocast(device_type='cuda'):
            out = model(imgs, pts, ids, msk, decoder_labels=ids)
            loss = out.loss
        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()
        total_loss += loss.item()
    return total_loss / len(loader)

def evaluate(model, loader, device):
    model.eval()
    total_loss = 0.
    all_gen, all_gt = [], []
    for b in tqdm(loader, desc="Evaluating", leave=False):
        imgs = b['full_imgs'].to(device)
        pts  = b['patches'].to(device)
        ids  = b['input_ids'].to(device)
        msk  = b['attention_mask'].to(device)

        with torch.no_grad():
            out = model(imgs, pts, ids, msk, decoder_labels=ids)
            total_loss += out.loss.item()

            # rebuild visual context
            g_feats = model.global_encoder(imgs)
            g = model.global_proj(g_feats).unsqueeze(1)
            B,N,C,H,W = pts.shape
            p = pts.view(B*N, C, H, W)
            pf_feats = model.patch_encoder(p)
            pf_pooled = model._pool(pf_feats)
            pf = model.patch_proj(pf_pooled).view(B, N, 768)
            cat, _ = model.attn(
                torch.cat([g,pf],1),
                torch.cat([g,pf],1),
                torch.cat([g,pf],1)
            )
            comb = model.norm(cat)

            # decode with FINDINGS: prompt
            prompt_ids = tokenizer("FINDINGS:", return_tensors="pt", add_special_tokens=False).input_ids.to(device)
            prompt_ids = prompt_ids.expand(B, -1)
            prompt_mask= torch.ones_like(prompt_ids, device=device)

            gen_ids = model.decoder.generate(
                input_ids=prompt_ids,
                attention_mask=prompt_mask,
                encoder_hidden_states=comb,
                encoder_attention_mask=torch.ones(B, comb.size(1), device=device),
                max_length=150,
                do_sample=True,
                top_p=0.9,
                temperature=0.7,
                repetition_penalty=1.3,
                eos_token_id=tokenizer.eos_token_id,
                pad_token_id=tokenizer.eos_token_id
            )
            gen_txt = [tokenizer.decode(g_, skip_special_tokens=True) for g_ in gen_ids]
            gt_txt  = [tokenizer.decode(i_, skip_special_tokens=True) for i_ in ids]
            all_gen.extend(gen_txt)
            all_gt .extend(gt_txt)

    return total_loss / len(loader), all_gen, all_gt

def compute_semantic_similarity(gen, gt):
    stm = SentenceTransformer('all-MiniLM-L6-v2')
    e1 = stm.encode(gen, convert_to_tensor=True)
    e2 = stm.encode(gt,  convert_to_tensor=True)
    return nn.functional.cosine_similarity(e1, e2).mean().item()

def plot_metrics(train_losses, val_losses, sems):
    epochs = range(1, len(train_losses)+1)
    plt.figure(figsize=(12,5))
    plt.subplot(1,2,1)
    plt.plot(epochs, train_losses, label="Train Loss")
    plt.plot(epochs, val_losses,   label="Val Loss")
    plt.xlabel("Epoch"); plt.ylabel("Loss"); plt.legend()
    plt.subplot(1,2,2)
    plt.plot(epochs, sems, label="Semantic Sim")
    plt.xlabel("Epoch"); plt.ylabel("Sim"); plt.legend()
    plt.tight_layout(); plt.show()

# =============================================================================
# MAIN: two-phase training with freeze/unfreeze
# =============================================================================
class Cfg: pass
cfg = Cfg()
cfg.DATASET = Cfg()
cfg.DATASET.JSON           = 'final_samples_both_only_v2.json'
cfg.DATASET.USE_RAW        = True
cfg.DATASET.USE_PATCH      = True
cfg.DATASET.REPORT         = True
cfg.DATASET.TARGET_CLASSES = ['ra','oa','gout','normal','uncertain','ref.prev']
cfg.DATASET.BALANCE        = False
cfg.DATASET.AUGMENT        = False

# ─── Tokenizer setup
tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
tokenizer.add_special_tokens({
    "bos_token": "<BOS>",
    "additional_special_tokens": ["FINDINGS:"]
})
tokenizer.padding_side = 'left'
tokenizer.pad_token     = tokenizer.eos_token

# ─── Device & Model
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
logging.info(f"Using device: {device}")

model = MultiModalModel().to(device)
model.decoder.resize_token_embeddings(len(tokenizer))

# ─── Dataset
dataset = FinalSamplesDataset(cfg)
dataset.tokenizer = tokenizer
dataset.eos_token  = tokenizer.eos_token

dist = Counter(e['class_label'] for e in dataset.data.values())
for cls,cnt in dist.items():
    logging.info(f"  {cls}: {cnt}")
    print(f"  {cls}: {cnt}")

n = len(dataset)
n_train = int(0.8 * n)
n_val   = int(0.1 * n)
n_test  = n - n_train - n_val
train_ds, val_ds, test_ds = random_split(dataset, [n_train, n_val, n_test])

print(f"\nNumber of training samples:   {len(train_ds)}")
print(f"Number of validation samples: {len(val_ds)}")
print(f"Number of test samples:       {len(test_ds)}")
print(f"Total samples:                {len(train_ds) + len(val_ds) + len(test_ds)}\n")

train_loader = DataLoader(train_ds, batch_size=4, shuffle=True, collate_fn=collate_fn)
val_loader   = DataLoader(val_ds,   batch_size=4, shuffle=False, collate_fn=collate_fn)
test_loader  = DataLoader(test_ds,  batch_size=4, shuffle=False, collate_fn=collate_fn)

# =============================================================================
# Phase 1: freeze base GPT-2 (except cross-attn), train LoRA + vision + cross-attn
# =============================================================================
for name, p in model.decoder.base_model.named_parameters():
    if "crossattention" in name.lower():
        p.requires_grad = True
    else:
        p.requires_grad = False

for p in model.global_proj.parameters():
    p.requires_grad = True
for p in model.patch_proj.parameters():
    p.requires_grad = True

optimizer = optim.AdamW(filter(lambda x: x.requires_grad, model.parameters()), lr=5e-5)
scheduler = torch.optim.lr_scheduler.CosineAnnealingWarmRestarts(optimizer, T_0=10, T_mult=2)
scaler    = torch.amp.GradScaler()

phase1_epochs = 5
train_losses, val_losses, sems = [], [], []

for epoch in range(phase1_epochs):
    print(f"\n-- Phase 1, Epoch {epoch+1}/{phase1_epochs} --")
    train_loss = train_epoch(model, train_loader, optimizer, scaler, device)

    # sanity-check gradient norm after first epoch
    if epoch == 0:
        total_norm = 0.0
        for name,p in model.named_parameters():
            if p.grad is not None:
                total_norm += p.grad.data.norm(2).item()**2
        print(f"Grad norm after 1st epoch backward: {total_norm**0.5:.4f}")

    val_loss, gen_txt, gt_txt = evaluate(model, val_loader, device)
    sem = compute_semantic_similarity(gen_txt, gt_txt)

    train_losses.append(train_loss)
    val_losses.append(val_loss)
    sems.append(sem)

    print(f"  Train Loss          : {train_loss:.4f}")
    print(f"  Validation Loss     : {val_loss:.4f}")
    print(f"  Semantic Similarity : {sem:.4f}")
    scheduler.step()

plot_metrics(train_losses, val_losses, sems)

# =============================================================================
# Phase 2: freeze base GPT-2 (except cross-attn), finetune LoRA only
# =============================================================================
for name, p in model.decoder.base_model.named_parameters():
    if "crossattention" in name.lower():
        p.requires_grad = True
    else:
        p.requires_grad = False

optimizer = optim.AdamW(filter(lambda x: x.requires_grad, model.parameters()), lr=1e-6)
scheduler = torch.optim.lr_scheduler.CosineAnnealingWarmRestarts(optimizer, T_0=5, T_mult=1)
scaler    = torch.amp.GradScaler()

phase2_epochs = 5
for epoch in range(phase2_epochs):
    print(f"\n-- Phase 2, Epoch {epoch+1}/{phase2_epochs} --")
    train_loss = train_epoch(model, train_loader, optimizer, scaler, device)
    val_loss, gen_txt, gt_txt = evaluate(model, val_loader, device)
    sem = compute_semantic_similarity(gen_txt, gt_txt)

    print(f"  Train Loss          : {train_loss:.4f}")
    print(f"  Validation Loss     : {val_loss:.4f}")
    print(f"  Semantic Similarity : {sem:.4f}")
    scheduler.step()

# Final test
test_loss, test_gen, test_gt = evaluate(model, test_loader, device)
test_sem = compute_semantic_similarity(test_gen, test_gt)

print("\n========== TEST RESULTS ==========")
print(f"Test Loss               : {test_loss:.4f}")
print(f"Test Semantic Similarity: {test_sem:.4f}")

# Random examples
for idx in random.sample(range(len(test_ds)), min(30, len(test_ds))):
    ex    = test_ds[idx]
    raw   = ex['raw_report']
    clean = ex['cleaned_report']
    fi    = ex['full_img'].unsqueeze(0).to(device)
    pa    = ex['patches'].unsqueeze(0).to(device)

    # build visual context
    g_feats = model.global_encoder(fi)
    g       = model.global_proj(g_feats).unsqueeze(1)
    B,N,C,H,W = pa.shape
    p      = pa.view(B*N, C, H, W)
    pf_feats= model.patch_encoder(p)
    pf_pooled= model._pool(pf_feats)
    pf        = model.patch_proj(pf_pooled).view(B,N,768)
    cat,_    = model.attn(torch.cat([g,pf],1),
                          torch.cat([g,pf],1),
                          torch.cat([g,pf],1))
    comb     = model.norm(cat)

    # generate after FINDINGS: prompt
    prompt_ids = tokenizer("FINDINGS:", return_tensors="pt", add_special_tokens=False).input_ids.to(device)
    prompt_mask= torch.ones_like(prompt_ids, device=device)
    gen_ids = model.decoder.generate(
        input_ids=prompt_ids,
        attention_mask=prompt_mask,
        encoder_hidden_states=comb,
        encoder_attention_mask=torch.ones(1, comb.size(1), device=device),
        max_length=150,
        do_sample=True,
        top_p=0.9,
        temperature=0.7,
        repetition_penalty=1.3,
        eos_token_id=tokenizer.eos_token_id,
        pad_token_id=tokenizer.eos_token_id
    )
    gen = tokenizer.decode(gen_ids[0], skip_special_tokens=True)

    print(f"\n--- Example {idx} ---")
    print(f"Raw Report       : \n{raw}")
    print(f"Cleaned Report   : \n{clean}")
    print(f"Generated Report : \n{gen}")
# Out:
# Some weights of GPT2LMHeadModel were not initialized from the model checkpoint at gpt2 and are newly initialized: ['h.0.crossattention.c_attn.bias', 'h.0.crossattention.c_attn.weight', 'h.0.crossattention.c_proj.bias', 'h.0.crossattention.c_proj.weight', 'h.0.crossattention.q_attn.bias', 'h.0.crossattention.q_attn.weight', 'h.0.ln_cross_attn.bias', 'h.0.ln_cross_attn.weight', 'h.1.crossattention.c_attn.bias', 'h.1.crossattention.c_attn.weight', 'h.1.crossattention.c_proj.bias', 'h.1.crossattention.c_proj.weight', 'h.1.crossattention.q_attn.bias', 'h.1.crossattention.q_attn.weight', 'h.1.ln_cross_attn.bias', 'h.1.ln_cross_attn.weight', 'h.10.crossattention.c_attn.bias', 'h.10.crossattention.c_attn.weight', 'h.10.crossattention.c_proj.bias', 'h.10.crossattention.c_proj.weight', 'h.10.crossattention.q_attn.bias', 'h.10.crossattention.q_attn.weight', 'h.10.ln_cross_attn.bias', 'h.10.ln_cross_attn.weight', 'h.11.crossattention.c_attn.bias', 'h.11.crossattention.c_attn.weight', 'h.11.crossattention.c_proj.bias', 'h.11.crossattention.c_proj.weight', 'h.11.crossattention.q_attn.bias', 'h.11.crossattention.q_attn.weight', 'h.11.ln_cross_attn.bias', 'h.11.ln_cross_attn.weight', 'h.2.crossattention.c_attn.bias', 'h.2.crossattention.c_attn.weight', 'h.2.crossattention.c_proj.bias', 'h.2.crossattention.c_proj.weight', 'h.2.crossattention.q_attn.bias', 'h.2.crossattention.q_attn.weight', 'h.2.ln_cross_attn.bias', 'h.2.ln_cross_attn.weight', 'h.3.crossattention.c_attn.bias', 'h.3.crossattention.c_attn.weight', 'h.3.crossattention.c_proj.bias', 'h.3.crossattention.c_proj.weight', 'h.3.crossattention.q_attn.bias', 'h.3.crossattention.q_attn.weight', 'h.3.ln_cross_attn.bias', 'h.3.ln_cross_attn.weight', 'h.4.crossattention.c_attn.bias', 'h.4.crossattention.c_attn.weight', 'h.4.crossattention.c_proj.bias', 'h.4.crossattention.c_proj.weight', 'h.4.crossattention.q_attn.bias', 'h.4.crossattention.q_attn.weight', 'h.4.ln_cross_attn.bias', 'h.4.ln_cross_attn.weight', 'h.5.crossattention.c_attn.bias', 'h.5.crossattention.c_attn.weight', 'h.5.crossattention.c_proj.bias', 'h.5.crossattention.c_proj.weight', 'h.5.crossattention.q_attn.bias', 'h.5.crossattention.q_attn.weight', 'h.5.ln_cross_attn.bias', 'h.5.ln_cross_attn.weight', 'h.6.crossattention.c_attn.bias', 'h.6.crossattention.c_attn.weight', 'h.6.crossattention.c_proj.bias', 'h.6.crossattention.c_proj.weight', 'h.6.crossattention.q_attn.bias', 'h.6.crossattention.q_attn.weight', 'h.6.ln_cross_attn.bias', 'h.6.ln_cross_attn.weight', 'h.7.crossattention.c_attn.bias', 'h.7.crossattention.c_attn.weight', 'h.7.crossattention.c_proj.bias', 'h.7.crossattention.c_proj.weight', 'h.7.crossattention.q_attn.bias', 'h.7.crossattention.q_attn.weight', 'h.7.ln_cross_attn.bias', 'h.7.ln_cross_attn.weight', 'h.8.crossattention.c_attn.bias', 'h.8.crossattention.c_attn.weight', 'h.8.crossattention.c_proj.bias', 'h.8.crossattention.c_proj.weight', 'h.8.crossattention.q_attn.bias', 'h.8.crossattention.q_attn.weight', 'h.8.ln_cross_attn.bias', 'h.8.ln_cross_attn.weight', 'h.9.crossattention.c_attn.bias', 'h.9.crossattention.c_attn.weight', 'h.9.crossattention.c_proj.bias', 'h.9.crossattention.c_proj.weight', 'h.9.crossattention.q_attn.bias', 'h.9.crossattention.q_attn.weight', 'h.9.ln_cross_attn.bias', 'h.9.ln_cross_attn.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# LoRA adapters integrated into GPT-2 decoder
#   oa: 573
#   ra: 115
#   uncertain: 620
#   oa, ra: 8
#   normal: 748
#   gout: 267
#   combination of oa, ra: 3
#   ref.prev: 60
#
# Number of training samples:   1915
# Number of validation samples: 239
# Number of test samples:       240
# Total samples:                2394
#
#
# -- Phase 1, Epoch 1/5 --
# Grad norm after 1st epoch backward: 5.1733
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
#   Train Loss          : 2.2818
#   Validation Loss     : 1.7979
#   Semantic Similarity : 0.2744
#
# -- Phase 1, Epoch 2/5 --
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
#   Train Loss          : 1.9434
#   Validation Loss     : 1.7206
#   Semantic Similarity : 0.1633
#
# -- Phase 1, Epoch 3/5 --
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
#   Train Loss          : 1.8943
#   Validation Loss     : 1.6763
#   Semantic Similarity : 0.2999
#
# -- Phase 1, Epoch 4/5 --
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
#   Train Loss          : 1.8434
#   Validation Loss     : 1.6178
#   Semantic Similarity : 0.3272
#
# -- Phase 1, Epoch 5/5 --
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
#   Train Loss          : 1.8244
#   Validation Loss     : 1.6122
#   Semantic Similarity : 0.3347
# -- Phase 2, Epoch 1/5 --
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
#   Train Loss          : 1.7897
#   Validation Loss     : 1.5894
#   Semantic Similarity : 0.3236
#
# -- Phase 2, Epoch 2/5 --
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
#   Train Loss          : 1.7608
#   Validation Loss     : 1.5832
#   Semantic Similarity : 0.3492
#
# -- Phase 2, Epoch 3/5 --
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
#   Train Loss          : 1.7603
#   Validation Loss     : 1.5784
#   Semantic Similarity : 0.3593
#
# -- Phase 2, Epoch 4/5 --
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
#   Train Loss          : 1.7438
#   Validation Loss     : 1.5781
#   Semantic Similarity : 0.3505
#
# -- Phase 2, Epoch 5/5 --
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
#   Train Loss          : 1.7618
#   Validation Loss     : 1.5781
#   Semantic Similarity : 0.3419
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# ========== TEST RESULTS ==========
# Test Loss               : 1.5975
# Test Semantic Similarity: 0.3355
#
# --- Example 237 ---
# Raw Report       :
# [ Finding ]_x000D_
# degenerative change._x000D_
# periarticular osteopenia, both hands._x000D_
# both elbow soft tissue swelling._x000D_
# [ Conclusion ]_x000D_
# degenerative change._x000D_
# periarticular osteopenia, both hands._x000D_
# both elbow soft tissue swelling._x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# degenerative change. periarticular osteopenia, both hands. both elbow soft tissue swelling.
# Generated Report :
#  extractative osteopenia. both 1st MTP joint, Gouttus lateral incursion of left ankle dorsum and medial soft tissue swelling at R/O joints 2nd motticular bone (a) OA with erosions on 3rd knee girdle to right thigh flexion hallux valgoid ossificationary arthritis .
#
# --- Example 199 ---
# Raw Report       :
# [ Finding ]_x000D_
# _x000D_
# [ Diagnosis ]_x000D_
# S/P internal fixation, 1/2/3th MT bone head, Rt._x000D_
# Suspicious erosive changes in both multiple MT bone head._x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# S/P internal fixation, 1/2/3th MT bone head, Rt. Suspicious erosive changes in both multiple MT bone head.
# Generated Report :
#  Possible degenerative change. no significant interval in follow-up, both feet No detectable abnormality of ankle joint or other foot swelling Ever since last study by radiographs (see below).
#
# --- Example 37 ---
# Raw Report       :
# [FINDING       ]_x000D_Rt. 1st hallux valgus.
# otherwise no significant interval change since last study._x000D__x000D_[CONCLUSION    ]_x000D_Rt. 1st hallux valgus.
# otherwise no significant interval change since last study._x000D__x000D_[RECOMMENDATION]_x000D_-
# Cleaned Report   :
# Rt. 1st hallux valgus. otherwise no significant interval change since last study.
# Generated Report :
#   Rt. 1st MTP joint, both 5th molar degenerative change; r/o 2nd MT foot movement -------------------------------- - erosions on MR knee joints and radiographs from multiple sources >
#
# --- Example 172 ---
# Raw Report       :
# [FINDING       ]_x000D_Rt. hallux valgus and degenerative change.
#
# both talocalcaneal coalition, suspicious._x000D__x000D_[CONCLUSION    ]_x000D_Rt. hallux valgus and degenerative change.
#
# both talocalcaneal coalition, suspicious._x000D__x000D_[RECOMMENDATION]_x000D_-
# Cleaned Report   :
# Rt. hallux valgus and degenerative change. both talocalcaneal coalition, suspicious.
# Generated Report :
#   high degenerative change. both knee, MTP joint
#
# --- Example 55 ---
# Raw Report       :
# [ Finding ]_x000D_
# both ankle, OA with loose bodies._x000D_
# [ Conclusion ]_x000D_
# both ankle, OA with loose bodies._x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# both ankle, OA with loose bodies.
# Generated Report :
#   Rt. 1st MTP joint, both 5th molar vertebral bone type II soft tissue swelling on 3rd right index finger and ulnar root joints at left elbow level 2nd G1 tendon of the femoral navicular artery in middle thigh 0.5 cm high density bony lesion along with slight degenerative change to blue plasticity within upper part of ankle dorsolateral calcification associated with small periartinosis . Peridrolar radius tendons
#
# --- Example 192 ---
# Raw Report       :
# [ Finding ]_x000D_
# No significant interval change_x000D_
# [ Conclusion ]_x000D_
# No significant interval change_x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# No significant interval change
# Generated Report :
#  Ackle, both. Lt. 1st MTP joint
#
# --- Example 94 ---
# Raw Report       :
# [ Finding ]_x000D_
# no change._x000D_
# [ Conclusion ]_x000D_
# no change._x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# no change.
# Generated Report :
#   Kony infiltration. degenerative change, both feet and knee joints with eroded soft tissue swelling of ankle joint type 2. Both hips/legs abnormal form of right foot Rt. 1st MTP joint Type 3-4th OA - osteopenia gouty arthritis
#
# --- Example 14 ---
# Raw Report       :
# [ Finding ]_x000D_
# Bony erosion in right 1st MTP & both 5th MTP joints._x000D_
# Joint space narrowing with mild spur change in both talonavicular joints._x000D_
# [ Diagnosis ]_x000D_
# Gouty arthritis in left 1st and both 5th MTP joints._x000D_
# OA in both talonavicular joints._x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# Bony erosion in right 1st MTP & both 5th MTP joints. Joint space narrowing with mild spur change in both talonavicular joints. Gouty arthritis in left 1st and both 5th MTP joints. OA in both talonavicular joints.
# Generated Report :
#  informative change, both feet. No significant bony lesion in left 2nd MTP joint at right ankle and medial navicular bone abnormality . no prominent B4 lateral root osteoma on 1st mottles of Rt 5th toe angle to sternal vertebral canal (R/O) ---------------------------------------- Paus scepura calcaneus formation with lower half swelling around the middle phalanx fracture --- os valgare de la illemora formes --> psochlear gout arthritis S2M rheumatoid joints: +1m hip flexor soft tissue erosion along upper part of midsection.--
#
# --- Example 151 ---
# Raw Report       :
# [FINDING       ]_x000D_no significant bony abnormality_x000D__x000D_[CONCLUSION    ]_x000D_no significant bony abnormality_x000D__x000D_[RECOMMENDATION]_x000D_-
# Cleaned Report   :
# no significant bony abnormality
# Generated Report :
#   possible degenerative change, both. Rt 1st MTP joint
#
# --- Example 132 ---
# Raw Report       :
# [ Finding ]_x000D_
# diffuse osteopenia._x000D_
# degenerative change._x000D_
# [ Conclusion ]_x000D_
# diffuse osteopenia._x000D_
# degenerative change._x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# diffuse osteopenia. degenerative change.
# Generated Report :
#  Routicular osteopenia. no significant bony abnormality at both ankle, Lt RA joint and right knee joints with swelling or degenerative change from left to right foot 2nd MTP joint/tibia-deepened calcification of medial soft tissue along with erosions on radiographs 4th MI ROT gait canal in fracture site erosion 3rd MLT groove (rondelphi) - probable G8Lt ALP�al aggravation
#
# --- Example 179 ---
# Raw Report       :
# [ Finding ]_x000D_
# both accessory navicular bone, type II_x000D_
# mild degenerative change._x000D_
# [ Conclusion ]_x000D_
# both accessory navicular bone, type II_x000D_
# mild degenerative change._x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# both accessory navicular bone, type II mild degenerative change.
# Generated Report :
#  O gout, both. no significant bony abnormality No explanation for osteopenia left on radiographs .
#
# --- Example 201 ---
# Raw Report       :
# [FINDING       ]_x000D_-_x000D__x000D_[CONCLUSION    ]_x000D_joint space narrowing with possible erosions at both 1st MTP joint
# erosions at Rt 4th and Lt 5th MT head
# -> RA involvement, more likely_x000D__x000D_[RECOMMENDATION]_x000D_-
# Cleaned Report   :
# - joint space narrowing with possible erosions at both 1st MTP joint erosions at Rt 4th and Lt 5th MT head -> RA involvement, more likely
# Generated Report :
#  Rt. 2nd MTP joint, Lt. 1st ML joints - OA
#
# --- Example 231 ---
# Raw Report       :
# [FINDING       ]_x000D_-_x000D__x000D_[CONCLUSION    ]_x000D_mild periarticular osteopenia, Rt 1st MTP joint
# -> r/o inflammatory or crystal associated arthritis _x000D__x000D_[RECOMMENDATION]_x000D_-
# Cleaned Report   :
# - mild periarticular osteopenia, Rt 1st MTP joint -> r/o inflammatory or crystal associated arthritis
# Generated Report :
#   Pulsification, Rt. 1st MTP joint degenerative change from left 4th MIcture with RA involvement and TMT foot swelling on radiographs (gout). both ankle soft tissue erosion in Lt 3rd molar area of MR/Pulchicular thickening at 5th LT tendon ophiocutaneous incision - probable fracture --------------------------------
#
# --- Example 68 ---
# Raw Report       :
# [ Finding ]_x000D_
# both feet and ankle, gout_x000D_
# [ Conclusion ]_x000D_
# both feet and ankle, gout_x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# both feet and ankle, gout
# Generated Report :
#
#
# --- Example 88 ---
# Raw Report       :
# [ Finding ]_x000D_
# 포함된 bone에 이상소견은 보이지 않음._x000D_
# 보이는 한도내에 soft tissue에 이상소견 보이지 않음._x000D_
# [ Diagnosis ]_x000D_
# No bony abnormality_x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# bone . soft tissue . No bony abnormality
# Generated Report :
#   mixture of both ankle and hip joints, OA. Both feet with bony abnormality in left 2nd MTP joint . No significant change since last study (both foot). -->
#
# --- Example 163 ---
# Raw Report       :
# [FINDING       ]_x000D_-_x000D__x000D_[CONCLUSION    ]_x000D_No significant interval change_x000D__x000D_[RECOMMENDATION]_x000D_-
# Cleaned Report   :
# - No significant interval change
# Generated Report :
#   degenerative change. diffuse osteopenia, both fingers and toes of probable RA involvement. Rt 1st MTP joint space narrowing in Lt 2nd MTT progression to OA. Both hands/body armour soft tissue swelling at LE site (Lt 3rd ML joints). MR - erosions on the 4th MI joint with eroded index finger protoplacepalaromaloid formation -> erosion or osseus form
#
# --- Example 142 ---
# Raw Report       :
# [ Finding ]_x000D_
# degenerative change._x000D_
# [ Conclusion ]_x000D_
# degenerative change._x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# degenerative change.
# Generated Report :
#   Gout, left. no bony abnormality either
#
# --- Example 213 ---
# Raw Report       :
# [ Finding ]_x000D_
# degenerative change._x000D_
# [ Conclusion ]_x000D_
# degenerative change._x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# degenerative change.
# Generated Report :
#   gout, both feet. No bony abnormality . no os navicular bone .. ophiocervoid tendons , right ankle joint swelling
#
# --- Example 236 ---
# Raw Report       :
# [ Finding ]_x000D_
# possible gout, both 1st toes._x000D_
# [ Conclusion ]_x000D_
# possible gout, both 1st toes._x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# possible gout, both 1st toes.
# Generated Report :
#
#
# --- Example 17 ---
# Raw Report       :
# [ Finding ]_x000D_
# degenerative change._x000D_
# [ Diagnosis ]_x000D_
# degenerative change._x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# degenerative change. degenerative change.
# Generated Report :
#   soft tissue swelling of the right lateral navicular bone. No bony abnormality . no edema or fracture in medial 5th rib, lesion on radiographs at left hand joint with rt. 1st MTPO toe osteopenia 2nd R/P hip joints and calcified ankle flexing by erosion
#
# --- Example 33 ---
# Raw Report       :
# [ Finding ]_x000D_
# _x000D_
# [ Diagnosis ]_x000D_
# plantar calcaneal spur, both._x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# plantar calcaneal spur, both.
# Generated Report :
#   Rt. 1st MTP joint, right side of lateral bone in left knee . soft tissue swelling and fracture on both sides of ankle RA/dorsal vertebral joints 2nd OA with thickening around the hip area
#
# --- Example 1 ---
# Raw Report       :
# [FINDING       ]_x000D_mild degenerative change_x000D__x000D_[CONCLUSION    ]_x000D_mild degenerative change_x000D__x000D_[RECOMMENDATION]_x000D_-
# Cleaned Report   :
# mild degenerative change
# Generated Report :
#  Tangle hallux valgus. - degenerative change, both knees and ankles
#
# --- Example 153 ---
# Raw Report       :
# [ Finding ]_x000D_
# _x000D_
# [ Conclusion ]_x000D_
# diffuse osteopenia._x000D_
# degenerative changes._x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# diffuse osteopenia. degenerative changes.
# Generated Report :
#  Carpal osteopenia, both. (R/O) periarticular joint swelling and right ankle soft tissue erosion on radiographs > medial hallux valgus RA1st MTP joints --> Rt 2nd knee degenerative change - TAC joint < 1st time period of followngosis at MRT 5th molar bone build-up
#
# --- Example 149 ---
# Raw Report       :
# [ Finding ]_x000D_
# degenerative change._x000D_
# osteopenia._x000D_
# [ Conclusion ]_x000D_
# degenerative change._x000D_
# osteopenia._x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# degenerative change. osteopenia.
# Generated Report :
#   OA, Lt. 1st MTP joint swelling and degenerative change RA/Tg1 form of both feet; neither foot nor upper extremity in MR 2nd GIP-targyngoid fracture on CT scan . Both ankle bone mineralosis with low density range Rtgs2 Form of left knee gout arthritis (ROT)
#
# --- Example 13 ---
# Raw Report       :
# [ Finding ]_x000D_
# no change._x000D_
# [ Conclusion ]_x000D_
# no change._x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# no change.
# Generated Report :
#  Dietrogenic syndrome. both feet, degenerative change . soft tissue swelling and erosions on left hip joint with low back pain radiations to right ankle osteopenia
#
# --- Example 144 ---
# Raw Report       :
# [FINDING       ]_x000D_degenerative change
# soft tissue swelling, Rt 1st MTP joint_x000D__x000D_[CONCLUSION    ]_x000D_degenerative change_x000D__x000D_[RECOMMENDATION]_x000D_-
# Cleaned Report   :
# degenerative change soft tissue swelling, Rt 1st MTP joint degenerative change
# Generated Report :
#
#
# --- Example 89 ---
# Raw Report       :
# [FINDING       ]_x000D_degenerative change_x000D__x000D_[CONCLUSION    ]_x000D_degenerative change_x000D__x000D_[RECOMMENDATION]_x000D_-
# Cleaned Report   :
# degenerative change
# Generated Report :
#   a degenerative change, both hands. Rt 2nd MTP joint space narrowing with mild RA involvement. Lt 1st OA foot soft tissue swelling on radiographs and MR joints to no significant interval reduction or erosions since last study
#
# --- Example 210 ---
# Raw Report       :
# [ Finding ]_x000D_
# no significant interval change since last study._x000D_
# [ Conclusion ]_x000D_
# no significant interval change since last study._x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# no significant interval change since last study.
# Generated Report :
#  Dietrogenic dysfunction. No significant change since last study, no bony lesion on radiographs or bone swelling at right ankle osteopenia xxxxxxxxxx
#
# --- Example 77 ---
# Raw Report       :
# [ Finding ]_x000D_
# no significant bony lesion on radiographs._x000D_
# _x000D_
# [ Conclusion ]_x000D_
# no significant bony lesion on radiographs._x000D_
# _x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# no significant bony lesion on radiographs.
# Generated Report :
#  Rt. 1st MTP joint, both ankle swelling and fracture --------------------------------------- degenerative change of R/O gout arthritis at right knee bone type II (MTE) Gout osteopenia on radiographs ........ - no significant interval changes since last study revision
#
# --- Example 162 ---
# Raw Report       :
# [ Finding ]_x000D_
# Os naviulare type II, Rt, and os naviculare type III, Lt_x000D_
# Ulnar negative variance, both_x000D_
# both ankle soft tissue swelling._x000D_
# _x000D_
# [ Conclusion ]_x000D_
# Os naviulare type II, Rt, and os naviculare type III, Lt_x000D_
# Ulnar negative variance, both_x000D_
# both ankle soft tissue swelling._x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# Os naviulare type II, Rt, and os naviculare type III, Lt Ulnar negative variance, both both ankle soft tissue swelling. Os naviulare type II, Rt, and os naviculare type III, Lt Ulnar negative variance, both both ankle soft tissue swelling.
# Generated Report :
#  Dietrogenic dysseal fracture. No bony abnormality, no osteophyte on radiographs at left lateral 5th navicular bone area of right index finger and ankle . soft tissue swelling along with degenerative change in both joints , os navi accessory calcaneus joint

# %%
import os
import re
import json
import unicodedata
import random
import logging
from collections import defaultdict, Counter

import numpy as np
import cv2
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, random_split
from PIL import Image
from torchvision import transforms
from tqdm import tqdm
import timm
from transformers import GPT2Tokenizer, GPT2LMHeadModel
from sentence_transformers import SentenceTransformer
import matplotlib.pyplot as plt

# LoRA imports
from peft import LoraConfig, get_peft_model, TaskType

# =============================================================================
# Logging configuration: write INFO+ logs only to training.log (no console output)
# =============================================================================
for h in logging.root.handlers[:]:
    logging.root.removeHandler(h)
logging.basicConfig(
    filename='training.log',
    filemode='w',
    level=logging.INFO,
    format='%(asctime)s %(levelname)-8s %(message)s',
    datefmt='%Y-%m-%d %H:%M:%S'
)

# =============================================================================
# Utility functions
# =============================================================================
def count_labels(data, target_classes, cfg):
    class_counts = defaultdict(int)
    data_by_class = defaultdict(list)
    for entry in tqdm(data.values(), desc="Counting dataset"):
        lbl = entry.get('class_label', '').lower()
        if lbl in target_classes and os.path.exists(entry['file_path']):
            class_counts[lbl] += 1
            data_by_class[lbl].append(entry)
    return class_counts, data_by_class

def prepare_abnormal_normal_data(data, cfg):
    random.seed(42)
    abnormal = ['ra', 'oa', 'gout']
    normal = ['normal']
    class_counts, data_by_class = count_labels(data, abnormal + normal, cfg)
    combined = {
        'abnormal': sum((data_by_class[c] for c in abnormal), []),
        'normal': data_by_class['normal']
    }
    combined_counts = {
        'abnormal': sum(class_counts[c] for c in abnormal),
        'normal': class_counts['normal']
    }
    if not cfg.DATASET.BALANCE and not cfg.DATASET.AUGMENT:
        return sum(combined.values(), []), combined_counts, combined_counts
    min_count = min(combined_counts.values())
    balanced = []
    final_counts = {}
    for lbl, items in combined.items():
        sampled = random.sample(items, min_count)
        balanced.extend(sampled)
        final_counts[lbl] = min_count
    if cfg.DATASET.AUGMENT:
        balanced *= 2
    return balanced, combined_counts, final_counts

def prepare_data(data, target_classes, cfg, is_binary=False):
    random.seed(42)
    if len(target_classes) == 2 and 'abnormal' in target_classes and 'normal' in target_classes:
        logging.info("Using abnormal-vs-normal logic")
        return prepare_abnormal_normal_data(data, cfg)
    class_counts, data_by_class = count_labels(data, target_classes, cfg)
    logging.info(f"Original class distribution: {class_counts}")
    if not cfg.DATASET.BALANCE and not cfg.DATASET.AUGMENT:
        return sum(data_by_class.values(), []), class_counts, class_counts
    min_count = min(class_counts.values())
    balanced, final_counts = [], {}
    for lbl in target_classes:
        sampled = random.sample(data_by_class[lbl], min_count)
        balanced.extend(sampled)
        final_counts[lbl] = min_count
    logging.info(f"Balanced class distribution: {final_counts}")
    if cfg.DATASET.AUGMENT:
        balanced *= 2
    return balanced, class_counts, final_counts

# =============================================================================
# Transforms
# =============================================================================
imagenet_mean = [0.485, 0.456, 0.406]
imagenet_std  = [0.229, 0.224, 0.225]

train_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(imagenet_mean, imagenet_std)
])
patch_transform = transforms.Compose([
    transforms.Resize((112, 112)),
    transforms.ToTensor(),
    transforms.Normalize(imagenet_mean, imagenet_std)
])

# =============================================================================
# Dataset (with FINDINGS: prefix in __getitem__)
# =============================================================================
class FinalSamplesDataset(Dataset):
    def __init__(self, cfg, image_transform=train_transform, patch_transform=patch_transform):
        self.cfg = cfg
        self.image_transform = image_transform
        self.patch_transform = patch_transform

        self.target_classes = cfg.DATASET.TARGET_CLASSES
        if isinstance(self.target_classes, str):
            self.target_classes = self.target_classes.split(",")

        self.is_binary = len(self.target_classes) == 2
        self.abnormal_classify = self.is_binary and 'abnormal' in self.target_classes
        self.abnormal_mapping = (
            {'ra': 'abnormal', 'oa': 'abnormal', 'gout': 'abnormal', 'normal': 'normal'}
            if self.abnormal_classify else None
        )

        with open(cfg.DATASET.JSON, 'r') as f:
            raw_list = json.load(f)

        filtered = []
        for item in raw_list:
            merged = item.get('merged_image_path', '')
            fp = item.get('file_paths', [])
            if isinstance(fp, str):
                fp = [fp]
            paths = [merged] + fp
            if any(os.path.exists(p) for p in paths):
                filtered.append((merged, fp, item))

        self.data = {}
        for i, (merged, fp, item) in enumerate(filtered):
            cls = item.get('class', 'unknown').lower()
            if self.abnormal_mapping:
                cls = self.abnormal_mapping.get(cls, cls)
            self.data[i] = {
                'file_path': merged,
                'left_right_file_path': fp,
                'class_label': cls,
                'diagnosis': item.get('diagnosis', ''),
                'keypoints': item.get('keypoints', {})
            }

        if self.is_binary:
            balanced, _, _ = prepare_data(self.data, self.target_classes, cfg, True)
            self.data = {i: e for i, e in enumerate(balanced)}

        self.tokenizer = None
        self.eos_token  = None

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        e = self.data[idx]
        img = Image.open(e['file_path']).convert('RGB')
        img = self.image_transform(img)
        logging.info(f"[Dataset] full_img shape: {img.shape}")

        patches = self._gen_patches(e['left_right_file_path'], e['keypoints'])
        pt = [self.patch_transform(Image.fromarray(p)) for p in patches]
        patches_tensor = torch.stack(pt, 0) if pt else torch.zeros(34, 3, 112, 112)
        logging.info(f"[Dataset] patches_tensor shape: {patches_tensor.shape}")

        raw = e.get('diagnosis', '')
        clean = self._clean_report(raw)

        # <<<— CHANGED: prepend FINDINGS: so model learns after it
        input_text = f"{self.tokenizer.bos_token} FINDINGS: {clean} {self.tokenizer.eos_token}"
        tok = self.tokenizer(input_text, truncation=True, max_length=512, return_tensors='pt')

        input_ids      = tok['input_ids'].squeeze(0)
        attention_mask = tok['attention_mask'].squeeze(0)
        logging.info(f"[Dataset] input_ids shape: {input_ids.shape}, attention_mask shape: {attention_mask.shape}")

        return {
            'full_img':       img,
            'patches':        patches_tensor,
            'raw_report':     raw,
            'cleaned_report': clean,
            'input_ids':      input_ids,
            'attention_mask': attention_mask
        }

    def _gen_patches(self, paths, kps_dict, crop_size=(200, 300), patch_size=(112, 112)):
        def extract(arr, side_kps):
            lst = []
            pts = side_kps[0]['keypoints']
            for i in range(17):
                x, y, s = int(pts[3*i]), int(pts[3*i+1]), pts[3*i+2]
                if s > 0:
                    x0 = max(x - crop_size[0]//2, 0)
                    y0 = max(y - crop_size[1]//2, 0)
                    x1 = min(x + crop_size[0]//2, arr.shape[1])
                    y1 = min(y + crop_size[1]//2, arr.shape[0])
                    c = arr[y0:y1, x0:x1]
                    if c.size:
                        lst.append(cv2.resize(c, patch_size))
            return lst

        def pad17(lst):
            black = np.zeros((patch_size[1], patch_size[0], 3), np.uint8)
            while len(lst) < 17:
                lst.append(black)
            return lst[:17]

        left, right = [], []
        if len(paths) == 1:
            pth = paths[0]
            if not pth or not os.path.exists(pth):
                return pad17([]) + pad17([])
            img_arr = cv2.imread(pth)
            if img_arr is None:
                return pad17([]) + pad17([])
            arr = cv2.cvtColor(img_arr, cv2.COLOR_BGR2RGB)
            if kps_dict.get('left'):  left  = extract(arr, kps_dict['left'])
            if kps_dict.get('right'): right = extract(arr, kps_dict['right'])
        else:
            for side, pth in zip(['left','right'], paths):
                if pth and os.path.exists(pth):
                    img_arr = cv2.imread(pth)
                    if img_arr is not None:
                        arr = cv2.cvtColor(img_arr, cv2.COLOR_BGR2RGB)
                        if kps_dict.get(side):
                            lst = extract(arr, kps_dict[side])
                            if side=='left':  left  = lst
                            else:             right = lst

        if left and not right:
            right = [cv2.flip(p,1) for p in left]
        if right and not left:
            left  = [cv2.flip(p,1) for p in right]
        if not left and not right:
            return pad17([]) + pad17([])

        return pad17(left) + pad17(right)

    def _clean_report(self, text):
        text = unicodedata.normalize('NFKC', text or '')
        text = re.sub(r'(?m)^-+\s*$', '', text)
        text = re.sub(r'[^\x00-\x7F]+', ' ', text)
        text = re.sub(r'([.!?]){2,}', r'\1', text)
        text = re.sub(r'\[\s*finding\s*\]', '[FINDING]', text, flags=re.IGNORECASE)
        text = re.sub(r'\[\s*conclusion\s*\]', '[CONCLUSION]', text, flags=re.IGNORECASE)
        text = re.sub(r'\[\s*diagnosis\s*\]', '[DIAGNOSIS]', text, flags=re.IGNORECASE)
        parts = re.split(r'\[\s*recommend(?:ation)?\s*\]', text, flags=re.IGNORECASE)
        text = parts[0]
        fm = re.search(r'\[FINDING\](.*?)(?=\[|$)', text, flags=re.IGNORECASE|re.DOTALL)
        cm = re.search(r'\[CONCLUSION\](.*?)(?=\[|$)', text, flags=re.IGNORECASE|re.DOTALL)
        if fm and cm and fm.group(1).strip().lower() == cm.group(1).strip().lower():
            text = re.sub(r'\[CONCLUSION\].*?(?=\[|$)', '', text, flags=re.IGNORECASE|re.DOTALL)
        text = re.sub(r'\[\s*(FINDING|CONCLUSION|DIAGNOSIS)\s*\]', '', text, flags=re.IGNORECASE)
        text = text.replace('_x000D_', ' ')
        return re.sub(r'\s+', ' ', text).strip()

# =============================================================================
# Collate function
# =============================================================================
def collate_fn(batch):
    imgs = torch.stack([b['full_img'] for b in batch])
    logging.info(f"[Collate] imgs: {imgs.shape}")

    pts = [b['patches'] for b in batch]
    max_p = max(p.shape[0] for p in pts)
    pads = []
    for p in pts:
        if p.shape[0] < max_p:
            pad = torch.zeros((max_p - p.shape[0], *p.shape[1:]))
            p = torch.cat([p, pad], dim=0)
        pads.append(p)
    patches = torch.stack(pads, 0)
    logging.info(f"[Collate] patches: {patches.shape}")

    ids   = [b['input_ids'] for b in batch]
    masks = [b['attention_mask'] for b in batch]
    ids   = nn.utils.rnn.pad_sequence(ids, batch_first=True, padding_value=tokenizer.pad_token_id)
    masks = nn.utils.rnn.pad_sequence(masks, batch_first=True, padding_value=0)
    logging.info(f"[Collate] ids: {ids.shape}, masks: {masks.shape}")

    return {
        'full_imgs':       imgs,
        'patches':         patches,
        'input_ids':       ids,
        'attention_mask':  masks,
        'raw_reports':     [b['raw_report']     for b in batch],
        'cleaned_reports': [b['cleaned_report'] for b in batch]
    }

# =============================================================================
# Model definition, with LoRA integration
# =============================================================================
class MultiModalModel(nn.Module):
    def __init__(self, gpt2_model_name='gpt2'):
        super().__init__()
        # Global image encoder
        self.global_encoder = timm.create_model('swin_base_patch4_window7_224', pretrained=True)
        self.global_encoder.reset_classifier(0)
        self.global_proj    = nn.Linear(self.global_encoder.num_features, 768)

        # Patch encoder
        self.patch_encoder  = timm.create_model('resnet50', pretrained=True)
        self.patch_encoder.fc = nn.Identity()
        self.patch_proj     = nn.Linear(self.patch_encoder.num_features, 768)

        # Fusion
        self.attn           = nn.MultiheadAttention(embed_dim=768, num_heads=8, batch_first=True)
        self.norm           = nn.LayerNorm(768)

        # GPT-2 decoder w/ cross-attention
        self.decoder = GPT2LMHeadModel.from_pretrained(
            gpt2_model_name, add_cross_attention=True
        )

        # LoRA on self-attn
        lora_config = LoraConfig(
            task_type=TaskType.CAUSAL_LM,
            r=16,
            lora_alpha=32,
            lora_dropout=0.05,
            target_modules=["c_attn", "c_proj"],
            bias="none"
        )
        self.decoder = get_peft_model(self.decoder, lora_config)
        print("LoRA adapters integrated into GPT-2 decoder")

    def _pool(self, feats):
        return feats.mean(dim=[2,3]) if feats.ndim>2 else feats

    def forward(self, imgs, patches, input_ids, attention_mask, decoder_labels=None):
        g_feats = self.global_encoder(imgs)
        g = self.global_proj(g_feats).unsqueeze(1)

        B,N,C,H,W = patches.shape
        p = patches.view(B*N, C, H, W)
        pf_feats = (
            self.patch_encoder.forward_features(p)
            if hasattr(self.patch_encoder, 'forward_features')
            else self.patch_encoder(p)
        )
        pf_pooled = self._pool(pf_feats)
        pf = self.patch_proj(pf_pooled).view(B, N, 768)

        cat, _ = self.attn(
            torch.cat([g, pf],1),
            torch.cat([g, pf],1),
            torch.cat([g, pf],1)
        )
        comb = self.norm(cat)

        out = self.decoder(
            input_ids=input_ids,
            attention_mask=attention_mask,
            encoder_hidden_states=comb,
            labels=decoder_labels
        )
        return out

# =============================================================================
# Training & evaluation loops
# =============================================================================
def train_epoch(model, loader, optimizer, scaler, device):
    model.train()
    total_loss = 0.
    for b in tqdm(loader, desc="Training", leave=False):
        imgs = b['full_imgs'].to(device)
        pts  = b['patches'].to(device)
        ids  = b['input_ids'].to(device)
        msk  = b['attention_mask'].to(device)

        optimizer.zero_grad()
        with torch.amp.autocast(device_type='cuda'):
            out = model(imgs, pts, ids, msk, decoder_labels=ids)
            loss = out.loss
        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()
        total_loss += loss.item()
    return total_loss / len(loader)

def evaluate(model, loader, device):
    model.eval()
    total_loss = 0.
    all_gen, all_gt = [], []
    for b in tqdm(loader, desc="Evaluating", leave=False):
        imgs = b['full_imgs'].to(device)
        pts  = b['patches'].to(device)
        ids  = b['input_ids'].to(device)
        msk  = b['attention_mask'].to(device)

        with torch.no_grad():
            out = model(imgs, pts, ids, msk, decoder_labels=ids)
            total_loss += out.loss.item()

            # rebuild visual context
            g_feats = model.global_encoder(imgs)
            g = model.global_proj(g_feats).unsqueeze(1)
            B,N,C,H,W = pts.shape
            p = pts.view(B*N, C, H, W)
            pf_feats = model.patch_encoder(p)
            pf_pooled = model._pool(pf_feats)
            pf = model.patch_proj(pf_pooled).view(B, N, 768)
            cat, _ = model.attn(
                torch.cat([g,pf],1),
                torch.cat([g,pf],1),
                torch.cat([g,pf],1)
            )
            comb = model.norm(cat)

            # decode with FINDINGS: prompt
            prompt_ids = tokenizer("FINDINGS:", return_tensors="pt", add_special_tokens=False).input_ids.to(device)
            prompt_ids = prompt_ids.expand(B, -1)
            prompt_mask= torch.ones_like(prompt_ids, device=device)

            gen_ids = model.decoder.generate(
                input_ids=prompt_ids,
                attention_mask=prompt_mask,
                encoder_hidden_states=comb,
                encoder_attention_mask=torch.ones(B, comb.size(1), device=device),
                max_length=150,
                do_sample=True,
                early_stopping = True,
                top_p=0.9,
                temperature=0.7,
                repetition_penalty=1.3,
                eos_token_id=tokenizer.eos_token_id,
                pad_token_id=tokenizer.eos_token_id
            )
            gen_txt = [tokenizer.decode(g_, skip_special_tokens=True) for g_ in gen_ids]
            gt_txt  = [tokenizer.decode(i_, skip_special_tokens=True) for i_ in ids]
            all_gen.extend(gen_txt)
            all_gt .extend(gt_txt)

    return total_loss / len(loader), all_gen, all_gt

def compute_semantic_similarity(gen, gt):
    stm = SentenceTransformer('all-MiniLM-L6-v2')
    e1 = stm.encode(gen, convert_to_tensor=True)
    e2 = stm.encode(gt,  convert_to_tensor=True)
    return nn.functional.cosine_similarity(e1, e2).mean().item()

def plot_metrics(train_losses, val_losses, sems):
    epochs = range(1, len(train_losses)+1)
    plt.figure(figsize=(12,5))
    plt.subplot(1,2,1)
    plt.plot(epochs, train_losses, label="Train Loss")
    plt.plot(epochs, val_losses,   label="Val Loss")
    plt.xlabel("Epoch"); plt.ylabel("Loss"); plt.legend()
    plt.subplot(1,2,2)
    plt.plot(epochs, sems, label="Semantic Sim")
    plt.xlabel("Epoch"); plt.ylabel("Sim"); plt.legend()
    plt.tight_layout(); plt.show()

# =============================================================================
# MAIN: two-phase training with freeze/unfreeze
# =============================================================================
class Cfg: pass
cfg = Cfg()
cfg.DATASET = Cfg()
cfg.DATASET.JSON           = 'final_samples_both_only_v2.json'
cfg.DATASET.USE_RAW        = True
cfg.DATASET.USE_PATCH      = True
cfg.DATASET.REPORT         = True
cfg.DATASET.TARGET_CLASSES = ['ra','oa','gout','normal','uncertain','ref.prev']
cfg.DATASET.BALANCE        = False
cfg.DATASET.AUGMENT        = False

# ─── Tokenizer setup
tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
tokenizer.add_special_tokens({
    "bos_token": "<BOS>",
    "additional_special_tokens": ["FINDINGS:"]
})
tokenizer.padding_side = 'left'
tokenizer.pad_token     = tokenizer.eos_token

# ─── Device & Model
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
logging.info(f"Using device: {device}")

model = MultiModalModel().to(device)
model.decoder.resize_token_embeddings(len(tokenizer))

# ─── Dataset
dataset = FinalSamplesDataset(cfg)
dataset.tokenizer = tokenizer
dataset.eos_token  = tokenizer.eos_token

dist = Counter(e['class_label'] for e in dataset.data.values())
for cls,cnt in dist.items():
    logging.info(f"  {cls}: {cnt}")
    print(f"  {cls}: {cnt}")

n = len(dataset)
n_train = int(0.8 * n)
n_val   = int(0.1 * n)
n_test  = n - n_train - n_val
train_ds, val_ds, test_ds = random_split(dataset, [n_train, n_val, n_test])

print(f"\nNumber of training samples:   {len(train_ds)}")
print(f"Number of validation samples: {len(val_ds)}")
print(f"Number of test samples:       {len(test_ds)}")
print(f"Total samples:                {len(train_ds) + len(val_ds) + len(test_ds)}\n")

train_loader = DataLoader(train_ds, batch_size=4, shuffle=True, collate_fn=collate_fn)
val_loader   = DataLoader(val_ds,   batch_size=4, shuffle=False, collate_fn=collate_fn)
test_loader  = DataLoader(test_ds,  batch_size=4, shuffle=False, collate_fn=collate_fn)

# =============================================================================
# Phase 1: freeze base GPT-2 (except cross-attn), train LoRA + vision + cross-attn
# =============================================================================
for name, p in model.decoder.base_model.named_parameters():
    if "crossattention" in name.lower():
        p.requires_grad = True
    else:
        p.requires_grad = False

for p in model.global_proj.parameters():
    p.requires_grad = True
for p in model.patch_proj.parameters():
    p.requires_grad = True

optimizer = optim.AdamW(filter(lambda x: x.requires_grad, model.parameters()), lr=1e-4)
scheduler = torch.optim.lr_scheduler.CosineAnnealingWarmRestarts(optimizer, T_0=10, T_mult=2)
scaler    = torch.amp.GradScaler()

phase1_epochs = 5
train_losses, val_losses, sems = [], [], []

for epoch in range(phase1_epochs):
    print(f"\n-- Phase 1, Epoch {epoch+1}/{phase1_epochs} --")
    train_loss = train_epoch(model, train_loader, optimizer, scaler, device)

    # sanity-check gradient norm after first epoch
    if epoch == 0:
        total_norm = 0.0
        for name,p in model.named_parameters():
            if p.grad is not None:
                total_norm += p.grad.data.norm(2).item()**2
        print(f"Grad norm after 1st epoch backward: {total_norm**0.5:.4f}")

    val_loss, gen_txt, gt_txt = evaluate(model, val_loader, device)
    sem = compute_semantic_similarity(gen_txt, gt_txt)

    train_losses.append(train_loss)
    val_losses.append(val_loss)
    sems.append(sem)

    print(f"  Train Loss          : {train_loss:.4f}")
    print(f"  Validation Loss     : {val_loss:.4f}")
    print(f"  Semantic Similarity : {sem:.4f}")
    scheduler.step()

plot_metrics(train_losses, val_losses, sems)

# =============================================================================
# Phase 2: freeze base GPT-2 (except cross-attn), finetune LoRA only
# =============================================================================
for name, p in model.decoder.base_model.named_parameters():
    if "crossattention" in name.lower():
        p.requires_grad = True
    else:
        p.requires_grad = False

optimizer = optim.AdamW(filter(lambda x: x.requires_grad, model.parameters()), lr=1e-5)
scheduler = torch.optim.lr_scheduler.CosineAnnealingWarmRestarts(optimizer, T_0=5, T_mult=1)
scaler    = torch.amp.GradScaler()

phase2_epochs = 5
for epoch in range(phase2_epochs):
    print(f"\n-- Phase 2, Epoch {epoch+1}/{phase2_epochs} --")
    train_loss = train_epoch(model, train_loader, optimizer, scaler, device)
    val_loss, gen_txt, gt_txt = evaluate(model, val_loader, device)
    sem = compute_semantic_similarity(gen_txt, gt_txt)

    print(f"  Train Loss          : {train_loss:.4f}")
    print(f"  Validation Loss     : {val_loss:.4f}")
    print(f"  Semantic Similarity : {sem:.4f}")
    scheduler.step()

# Final test
test_loss, test_gen, test_gt = evaluate(model, test_loader, device)
test_sem = compute_semantic_similarity(test_gen, test_gt)

print("\n========== TEST RESULTS ==========")
print(f"Test Loss               : {test_loss:.4f}")
print(f"Test Semantic Similarity: {test_sem:.4f}")

# Random examples
for idx in random.sample(range(len(test_ds)), min(30, len(test_ds))):
    ex    = test_ds[idx]
    raw   = ex['raw_report']
    clean = ex['cleaned_report']
    fi    = ex['full_img'].unsqueeze(0).to(device)
    pa    = ex['patches'].unsqueeze(0).to(device)

    # build visual context
    g_feats = model.global_encoder(fi)
    g       = model.global_proj(g_feats).unsqueeze(1)
    B,N,C,H,W = pa.shape
    p      = pa.view(B*N, C, H, W)
    pf_feats= model.patch_encoder(p)
    pf_pooled= model._pool(pf_feats)
    pf        = model.patch_proj(pf_pooled).view(B,N,768)
    cat,_    = model.attn(torch.cat([g,pf],1),
                          torch.cat([g,pf],1),
                          torch.cat([g,pf],1))
    comb     = model.norm(cat)

    # generate after FINDINGS: prompt
    prompt_ids = tokenizer("FINDINGS:", return_tensors="pt", add_special_tokens=False).input_ids.to(device)
    prompt_mask= torch.ones_like(prompt_ids, device=device)
    gen_ids = model.decoder.generate(
        input_ids=prompt_ids,
        attention_mask=prompt_mask,
        early_stopping = True,
        encoder_hidden_states=comb,
        encoder_attention_mask=torch.ones(1, comb.size(1), device=device),
        max_length=150,
        do_sample=True,
        top_p=0.9,
        temperature=0.7,
        repetition_penalty=1.3,
        eos_token_id=tokenizer.eos_token_id,
        pad_token_id=tokenizer.eos_token_id
    )
    gen = tokenizer.decode(gen_ids[0], skip_special_tokens=True)

    print(f"\n--- Example {idx} ---")
    print(f"Raw Report       : \n{raw}")
    print(f"Cleaned Report   : \n{clean}")
    print(f"Generated Report : \n{gen}")
# Out:
# Some weights of GPT2LMHeadModel were not initialized from the model checkpoint at gpt2 and are newly initialized: ['h.0.crossattention.c_attn.bias', 'h.0.crossattention.c_attn.weight', 'h.0.crossattention.c_proj.bias', 'h.0.crossattention.c_proj.weight', 'h.0.crossattention.q_attn.bias', 'h.0.crossattention.q_attn.weight', 'h.0.ln_cross_attn.bias', 'h.0.ln_cross_attn.weight', 'h.1.crossattention.c_attn.bias', 'h.1.crossattention.c_attn.weight', 'h.1.crossattention.c_proj.bias', 'h.1.crossattention.c_proj.weight', 'h.1.crossattention.q_attn.bias', 'h.1.crossattention.q_attn.weight', 'h.1.ln_cross_attn.bias', 'h.1.ln_cross_attn.weight', 'h.10.crossattention.c_attn.bias', 'h.10.crossattention.c_attn.weight', 'h.10.crossattention.c_proj.bias', 'h.10.crossattention.c_proj.weight', 'h.10.crossattention.q_attn.bias', 'h.10.crossattention.q_attn.weight', 'h.10.ln_cross_attn.bias', 'h.10.ln_cross_attn.weight', 'h.11.crossattention.c_attn.bias', 'h.11.crossattention.c_attn.weight', 'h.11.crossattention.c_proj.bias', 'h.11.crossattention.c_proj.weight', 'h.11.crossattention.q_attn.bias', 'h.11.crossattention.q_attn.weight', 'h.11.ln_cross_attn.bias', 'h.11.ln_cross_attn.weight', 'h.2.crossattention.c_attn.bias', 'h.2.crossattention.c_attn.weight', 'h.2.crossattention.c_proj.bias', 'h.2.crossattention.c_proj.weight', 'h.2.crossattention.q_attn.bias', 'h.2.crossattention.q_attn.weight', 'h.2.ln_cross_attn.bias', 'h.2.ln_cross_attn.weight', 'h.3.crossattention.c_attn.bias', 'h.3.crossattention.c_attn.weight', 'h.3.crossattention.c_proj.bias', 'h.3.crossattention.c_proj.weight', 'h.3.crossattention.q_attn.bias', 'h.3.crossattention.q_attn.weight', 'h.3.ln_cross_attn.bias', 'h.3.ln_cross_attn.weight', 'h.4.crossattention.c_attn.bias', 'h.4.crossattention.c_attn.weight', 'h.4.crossattention.c_proj.bias', 'h.4.crossattention.c_proj.weight', 'h.4.crossattention.q_attn.bias', 'h.4.crossattention.q_attn.weight', 'h.4.ln_cross_attn.bias', 'h.4.ln_cross_attn.weight', 'h.5.crossattention.c_attn.bias', 'h.5.crossattention.c_attn.weight', 'h.5.crossattention.c_proj.bias', 'h.5.crossattention.c_proj.weight', 'h.5.crossattention.q_attn.bias', 'h.5.crossattention.q_attn.weight', 'h.5.ln_cross_attn.bias', 'h.5.ln_cross_attn.weight', 'h.6.crossattention.c_attn.bias', 'h.6.crossattention.c_attn.weight', 'h.6.crossattention.c_proj.bias', 'h.6.crossattention.c_proj.weight', 'h.6.crossattention.q_attn.bias', 'h.6.crossattention.q_attn.weight', 'h.6.ln_cross_attn.bias', 'h.6.ln_cross_attn.weight', 'h.7.crossattention.c_attn.bias', 'h.7.crossattention.c_attn.weight', 'h.7.crossattention.c_proj.bias', 'h.7.crossattention.c_proj.weight', 'h.7.crossattention.q_attn.bias', 'h.7.crossattention.q_attn.weight', 'h.7.ln_cross_attn.bias', 'h.7.ln_cross_attn.weight', 'h.8.crossattention.c_attn.bias', 'h.8.crossattention.c_attn.weight', 'h.8.crossattention.c_proj.bias', 'h.8.crossattention.c_proj.weight', 'h.8.crossattention.q_attn.bias', 'h.8.crossattention.q_attn.weight', 'h.8.ln_cross_attn.bias', 'h.8.ln_cross_attn.weight', 'h.9.crossattention.c_attn.bias', 'h.9.crossattention.c_attn.weight', 'h.9.crossattention.c_proj.bias', 'h.9.crossattention.c_proj.weight', 'h.9.crossattention.q_attn.bias', 'h.9.crossattention.q_attn.weight', 'h.9.ln_cross_attn.bias', 'h.9.ln_cross_attn.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# LoRA adapters integrated into GPT-2 decoder
#   oa: 573
#   ra: 115
#   uncertain: 620
#   oa, ra: 8
#   normal: 748
#   gout: 267
#   combination of oa, ra: 3
#   ref.prev: 60
#
# Number of training samples:   1915
# Number of validation samples: 239
# Number of test samples:       240
# Total samples:                2394
#
#
# -- Phase 1, Epoch 1/5 --
# Grad norm after 1st epoch backward: 5.7834
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
#   Train Loss          : 2.2231
#   Validation Loss     : 1.7918
#   Semantic Similarity : 0.3289
#
# -- Phase 1, Epoch 2/5 --
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
#   Train Loss          : 1.9812
#   Validation Loss     : 1.7074
#   Semantic Similarity : 0.3637
#
# -- Phase 1, Epoch 3/5 --
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
#   Train Loss          : 1.8591
#   Validation Loss     : 1.6753
#   Semantic Similarity : 0.3052
#
# -- Phase 1, Epoch 4/5 --
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
#   Train Loss          : 1.8884
#   Validation Loss     : 1.6243
#   Semantic Similarity : 0.3207
#
# -- Phase 1, Epoch 5/5 --
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
#   Train Loss          : 1.8310
#   Validation Loss     : 1.5914
#   Semantic Similarity : 0.3110
# -- Phase 2, Epoch 1/5 --
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
#   Train Loss          : 1.7787
#   Validation Loss     : 1.5474
#   Semantic Similarity : 0.3155
#
# -- Phase 2, Epoch 2/5 --
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
#   Train Loss          : 1.7427
#   Validation Loss     : 1.5457
#   Semantic Similarity : 0.3271
#
# -- Phase 2, Epoch 3/5 --
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
#   Train Loss          : 1.7482
#   Validation Loss     : 1.5353
#   Semantic Similarity : 0.3158
#
# -- Phase 2, Epoch 4/5 --
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
#   Train Loss          : 1.7245
#   Validation Loss     : 1.5384
#   Semantic Similarity : 0.3170
#
# -- Phase 2, Epoch 5/5 --
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
#   Train Loss          : 1.7169
#   Validation Loss     : 1.5343
#   Semantic Similarity : 0.3257
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# ========== TEST RESULTS ==========
# Test Loss               : 1.5278
# Test Semantic Similarity: 0.3481
#
# --- Example 98 ---
# Raw Report       :
# [FINDING       ]_x000D_-_x000D__x000D_[CONCLUSION    ]_x000D_degenerative change_x000D__x000D_[RECOMMENDATION]_x000D_-
# Cleaned Report   :
# - degenerative change
# Generated Report :
#  MTP joint degenerative change at Rt 1st MTP joint, Lt 2nd MTA ankle RA joint. --> OA Lt 3rd MTC joints, Major changes
#
# --- Example 63 ---
# Raw Report       :
# [ Finding ]_x000D_
# RA, both feet._x000D_
# [ Diagnosis ]_x000D_
# RA, both feet._x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# RA, both feet. RA, both feet.
# Generated Report :
#   OA, both. Lt Lt RA joint and erosions with gout arthritis in knee space narrowing to right side of quadricepili joints Rt. 2nd MTP (non invasive) degenerative change PPTs suggestive ophiolic bone erosion after hip replacement
#
# --- Example 238 ---
# Raw Report       :
# [ Finding ]_x000D_
# No bony abnormality_x000D_
# _x000D_
# [ Diagnosis ]_x000D_
# No bony abnormality_x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# No bony abnormality No bony abnormality
# Generated Report :
#  Sodium bony erosion in the left lateral gout joint. both feet, ankle and hip joints at right knee, swelling of bone tissue 1st MTP joint on radiographs 2nd Rt. 3rd GOUT OF MR/Og nodal change , soft tissues (bilateral) 4th STM
#
# --- Example 198 ---
# Raw Report       :
# [ Finding ]_x000D_
# gout, left ankle and both 1st MTP joints._x000D_
# [ Conclusion ]_x000D_
# gout, left ankle and both 1st MTP joints._x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# gout, left ankle and both 1st MTP joints.
# Generated Report :
#   the first steps of osteopenia. both feet, swelling and degenerative change . joint joints , r/o elbow soft tissue erosion in ankle Osteoporosis : R/O knee hard tissues erosions on radiographs (both hips). --> 1st MTP joint arthritis, right foot ossification with periarticular bone formation > 2nd Knee scar, inflammation with calcified osilloite form...
#
# --- Example 42 ---
# Raw Report       :
# [FINDING       ]_x000D_both 2-3rd toe, MTP joint space narrowing and osteophytes.
#    --> R/O inflammatory arthritis._x000D__x000D_[CONCLUSION    ]_x000D_both 2-3rd toe, MTP joint space narrowing and osteophytes.
#    --> R/O inflammatory arthritis._x000D__x000D_[RECOMMENDATION]_x000D_-
# Cleaned Report   :
# both 2-3rd toe, MTP joint space narrowing and osteophytes. --> R/O inflammatory arthritis.
# Generated Report :
#  MTP joint
#
# --- Example 16 ---
# Raw Report       :
# [ Finding ]_x000D_
# No bony abnormality_x000D_
# _x000D_
# [ Diagnosis ]_x000D_
# No bony abnormality_x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# No bony abnormality No bony abnormality
# Generated Report :
#   Diverseal form of both feet. No bony lesion on radiographs, no abnormality found in either ankle. Lt. 1st MTP joint. ------------------------------------------------------------------------ --------------------------------------- Both ankles.
#
# --- Example 1 ---
# Raw Report       :
# [ Finding ]_x000D_
# 포함된 bone에 이상소견은 보이지 않음._x000D_
# 보이는 한도내에 soft tissue에 이상소견 보이지 않음._x000D_
# [ Diagnosis ]_x000D_
# No bony abnormality_x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# bone . soft tissue . No bony abnormality
# Generated Report :
#   MTP joint. no bony abnormality on radiographs, both feet. No abnormal lesion either. --> Orthopedic tendon inflammation in right ankle and sternal vertebral bone. --> R/O medial navicular tendinoma. --> Paretta soft tissue swelling with anterior portion of 1st Lt. Gout arthritis. --> T-1st Lt.-gt. Bilateral calcification (left lateral aspect). --> OA small gout fracture or erosion within the left foot. --> degenerative change from top to bottom at distention. --> os ossicle type II. --> Peripherum osteophyte accumulation along posterior accessory side of TB joint. --> periarticular rotations throughout anterior thigh.
#
# --- Example 67 ---
# Raw Report       :
# [ Finding ]_x000D_
# 포함된 bone에 이상소견은 보이지 않음._x000D_
# 보이는 한도내에 soft tissue에 이상소견 보이지 않음._x000D_
# [ Diagnosis ]_x000D_
# No bony abnormality_x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# bone . soft tissue . No bony abnormality
# Generated Report :
#
#
# --- Example 224 ---
# Raw Report       :
# [ Finding ]_x000D_
# No bony abnormality_x000D_
# _x000D_
# [ Diagnosis ]_x000D_
# No bony abnormality_x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# No bony abnormality No bony abnormality
# Generated Report :
#   A Rt. 1st MTP joint, right ankle and hip osteophyte in left calf of both feet with large bone swelling on upper back . No bony abnormality here! ossification from the femoral cavity at midline OA
#
# --- Example 94 ---
# Raw Report       :
# [FINDING       ]_x000D_(SLE patient)
#
# old fractures, Rt 5th, Lt 2,4,5th metatarsal shafts
# old fracture, Lt 5th PP base
#
# newly noted fracture at Rt 4th metatarsal shaft
# - with partial callus formation
# -> stress fracture a/w systemic condition, more likely _x000D__x000D_[CONCLUSION    ]_x000D_(SLE patient)
#
# old fractures, Rt 5th, Lt 2,4,5th metatarsal shafts
# old fracture, Lt 5th PP base
#
# newly noted fracture at Rt 4th metatarsal shaft
# - with partial callus formation
# -> stress fracture a/w systemic condition, more likely _x000D__x000D_[RECOMMENDATION]_x000D_-
# Cleaned Report   :
# (SLE patient) old fractures, Rt 5th, Lt 2,4,5th metatarsal shafts old fracture, Lt 5th PP base newly noted fracture at Rt 4th metatarsal shaft - with partial callus formation -> stress fracture a/w systemic condition, more likely
# Generated Report :
#  R/O gout arthritis, both.
#
# --- Example 182 ---
# Raw Report       :
# [ Finding ]_x000D_
# degenerative change._x000D_
# [ Conclusion ]_x000D_
# degenerative change._x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# degenerative change.
# Generated Report :
#  Cuneal bone fracture. Rt. 1st MTP joint, both feet and sternocarpus on right side of calcification . r/o 2nd MT joints (1st MI), degenerative change in left foot > 3rd RA joint, osteopenia erosion OA - knee tenders with soft tissue swelling , ankle arthritis at elbow 4th-5th navicular area --> probable a rotator muscle sore gouty inflammation
#
# --- Example 86 ---
# Raw Report       :
# [ Finding ]_x000D_
# degenerative change._x000D_
# [ Conclusion ]_x000D_
# degenerative change._x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# degenerative change.
# Generated Report :
#   Rt. 1st MTP joint, both 3rd mTP joints and bone tissue swelling in left lateral aspect of right knee AC joint MRO1 - OA --> CTE/R gout arthritis
#
# --- Example 172 ---
# Raw Report       :
# [ Finding ]_x000D_
# no significant bony lesion on radiographs._x000D_
# _x000D_
# [ Diagnosis ]_x000D_
# _x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# no significant bony lesion on radiographs.
# Generated Report :
#  informative change, both feet. osteophyte in medial 2nd 1st metatarsal left 4th vertechessicle (both knees). Both toes. No bony abnormality since last analysis.*
#
# --- Example 231 ---
# Raw Report       :
# [FINDING       ]_x000D_both knee, RA involvement.
# both feet and hands, RA, no change._x000D__x000D_[CONCLUSION    ]_x000D_both knee, RA involvement.
# both feet and hands, RA, no change._x000D__x000D_[RECOMMENDATION]_x000D_-
# Cleaned Report   :
# both knee, RA involvement. both feet and hands, RA, no change.
# Generated Report :
#  MTP joint -> degenerative change diffuse osteopenia, both ankle RA involvement. Both foot and hands - no significant interval erosions at Lt 1st MTA hallux valgus progression --> Rt 2nd MTTD outgrowth on dm head RA involvement. flat grassy arthritis -> probable erosion of upper thigh bone, likely r/o gout mild lupia > PPP joints narrowing down swelling
#
# --- Example 22 ---
# Raw Report       :
# [FINDING       ]_x000D_-_x000D__x000D_[CONCLUSION    ]_x000D_no significant bony abnormality_x000D__x000D_[RECOMMENDATION]_x000D_-
# Cleaned Report   :
# - no significant bony abnormality
# Generated Report :
#  Rt. 1st MTP joint
#
# --- Example 161 ---
# Raw Report       :
# [ Finding ]_x000D_
# no significant bony lesion_x000D_
# [ Conclusion ]_x000D_
# no significant bony lesion_x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# no significant bony lesion
# Generated Report :
#   the TMT 2nd Lt. knee joint, right ankle soft tissue swelling both feet and neck area degenerative change ------------------------------------------------------------- ----------------------------------------------------------------------- Rt. 1st MTP joint, left foot with abnormal growth in medial navicular bone --------------------
#
# --- Example 204 ---
# Raw Report       :
# [ Finding ]_x000D_
# no bony lesion._x000D_
# [ Conclusion ]_x000D_
# no bony lesion._x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# no bony lesion.
# Generated Report :
#   bony abnormality in medial part of left 1st MTP joint. No significant lesion on radiographs, no abnormal lesions.(1) This is the ankle bone within right lateral aspect of xyloculaneous area below knee swelling with anterior calcaneal nodation (left).
#
# --- Example 219 ---
# Raw Report       :
# [ Finding ]_x000D_
# no bony lesion._x000D_
# [ Diagnosis ]_x000D_
# no bony lesion._x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# no bony lesion. no bony lesion.
# Generated Report :
#   and OA, both. Rt. 1st MTP joint, left lateral gout area. with bony lesion on right elbow 5th ankle bone (both). No significant change since last study except for knee osteopenia in radiographs at D1st Lt. 2nd NPP joints tend to be low back tendon periarticular soft tissue erosion of the RA/T2 fingers 3rd mTA joint, left medial GOUT angle. wavy degenerative changes along Lateral delangeus .
#
# --- Example 141 ---
# Raw Report       :
# [ Finding ]_x000D_
# _x000D_
# [ Diagnosis ]_x000D_
# No significant interval change since last study._x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# No significant interval change since last study.
# Generated Report :
#   Kony infiltration. no bony lesion on radiographs or histologic examination, both feet with joint swelling in right middle portion of left lateral aspect. No significant medial bone abnormality . Rt. 1st MTP joints calcification and erosion along the fascicle area
#
# --- Example 110 ---
# Raw Report       :
# [ Finding ]_x000D_
# no change._x000D_
# [ Diagnosis ]_x000D_
# no change._x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# no change. no change.
# Generated Report :
#
#
# --- Example 75 ---
# Raw Report       :
# [ Finding ]_x000D_
# Os naviculare type II, both_x000D_
# [ Conclusion ]_x000D_
# Os naviculare type II, both_x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# Os naviculare type II, both
# Generated Report :
#   "No bony abnormality. No significant crescental soft tissue lesion."
#
# --- Example 113 ---
# Raw Report       :
# [FINDING       ]_x000D_degenerative change, both 1st MTP joint_x000D__x000D_[CONCLUSION    ]_x000D_degenerative change_x000D__x000D_[RECOMMENDATION]_x000D_-
# Cleaned Report   :
# degenerative change, both 1st MTP joint degenerative change
# Generated Report :
#
#
# --- Example 7 ---
# Raw Report       :
# [ Finding ]_x000D_
# Rt. navicular bone, accessory navicular bone type III._x000D_
# _x000D_
# [ Conclusion ]_x000D_
# Rt. navicular bone, accessory navicular bone type III._x000D_
# _x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# Rt. navicular bone, accessory navicular bone type III.
# Generated Report :
#   MTP joint swelling. Rt. 1st Lt. ankle bone, both feet tomorata 2nd LT joints and right lateral incision of foot...
#
# --- Example 73 ---
# Raw Report       :
# [ Finding ]_x000D_
# _x000D_
# [ Diagnosis ]_x000D_
# diffuse osteopenia_x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# diffuse osteopenia
# Generated Report :
#   Rt. 1st MTP joint, RA/Rm 5th ankle gout arthritis ------------------------------------------------------------------------------------------------------- osteopenia with degenerative change
#
# --- Example 80 ---
# Raw Report       :
# [FINDING       ]_x000D_diffuse osteopenia
# both feet, advanced RA._x000D__x000D_[CONCLUSION    ]_x000D_diffuse osteopenia
# both feet, advanced RA._x000D__x000D_[RECOMMENDATION]_x000D_-
# Cleaned Report   :
# diffuse osteopenia both feet, advanced RA.
# Generated Report :
#
#
# --- Example 111 ---
# Raw Report       :
# [ Finding ]_x000D_
# degenerative change._x000D_
# [ Conclusion ]_x000D_
# degenerative change._x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# degenerative change.
# Generated Report :
#   soft tissue swelling. Soft tissue swollen.
#
# --- Example 127 ---
# Raw Report       :
# [ Finding ]_x000D_
# _x000D_
# [ Diagnosis ]_x000D_
# Both hallux valgus._x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# Both hallux valgus.
# Generated Report :
#   TK joint. No bony lesion on radiographs, both feet.
#
# --- Example 130 ---
# Raw Report       :
# [FINDING       ]_x000D_Left 1st MTP joint, soft tissue swelling and erosion.
#     -> R/O gout arthritis_x000D__x000D_[CONCLUSION    ]_x000D_Left 1st MTP joint, soft tissue swelling and erosion.
#     -> R/O gout arthritis_x000D__x000D_[RECOMMENDATION]_x000D_-
# Cleaned Report   :
# Left 1st MTP joint, soft tissue swelling and erosion. -> R/O gout arthritis
# Generated Report :
#  Pietrogenial tract swelling.
#
# --- Example 34 ---
# Raw Report       :
# [ Finding ]_x000D_
# degenerative change._x000D_
# [ Conclusion ]_x000D_
# degenerative change._x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# degenerative change.
# Generated Report :
#
#
# --- Example 227 ---
# Raw Report       :
# [ Finding ]_x000D_
# Multiple osteolytic lesions in both 1st PP and MT_x000D_
# Increased opaicty in both 1st MCPs, R/O tophis_x000D_
# [ Conclusion ]_x000D_
# R/O gout involvement, both 1st MCP and PP_x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# Multiple osteolytic lesions in both 1st PP and MT Increased opaicty in both 1st MCPs, R/O tophis R/O gout involvement, both 1st MCP and PP
# Generated Report :
#   the ankle, both feet. Lt. 2nd MTP joint, degenerative change over time of Rt. 1st OA. No significant bony lesion on radiographs since last analysis .

# %%
import os
import re
import json
import unicodedata
import random
import logging
from collections import defaultdict, Counter

import numpy as np
import cv2
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, random_split
from PIL import Image
from torchvision import transforms
from tqdm import tqdm
import timm
from transformers import GPT2Tokenizer, GPT2LMHeadModel
from sentence_transformers import SentenceTransformer
import matplotlib.pyplot as plt

# LoRA imports
from peft import LoraConfig, get_peft_model, TaskType

# =============================================================================
# Logging configuration: write INFO+ logs only to training.log (no console output)
# =============================================================================
for h in logging.root.handlers[:]:
    logging.root.removeHandler(h)
logging.basicConfig(
    filename='training.log',
    filemode='w',
    level=logging.INFO,
    format='%(asctime)s %(levelname)-8s %(message)s',
    datefmt='%Y-%m-%d %H:%M:%S'
)

# =============================================================================
# Utility functions
# =============================================================================
def count_labels(data, target_classes, cfg):
    class_counts = defaultdict(int)
    data_by_class = defaultdict(list)
    for entry in tqdm(data.values(), desc="Counting dataset"):
        lbl = entry.get('class_label', '').lower()
        if lbl in target_classes and os.path.exists(entry['file_path']):
            class_counts[lbl] += 1
            data_by_class[lbl].append(entry)
    return class_counts, data_by_class

def prepare_abnormal_normal_data(data, cfg):
    random.seed(42)
    abnormal = ['ra', 'oa', 'gout']
    normal = ['normal']
    class_counts, data_by_class = count_labels(data, abnormal + normal, cfg)
    combined = {
        'abnormal': sum((data_by_class[c] for c in abnormal), []),
        'normal': data_by_class['normal']
    }
    combined_counts = {
        'abnormal': sum(class_counts[c] for c in abnormal),
        'normal': class_counts['normal']
    }
    if not cfg.DATASET.BALANCE and not cfg.DATASET.AUGMENT:
        return sum(combined.values(), []), combined_counts, combined_counts
    min_count = min(combined_counts.values())
    balanced = []
    final_counts = {}
    for lbl, items in combined.items():
        sampled = random.sample(items, min_count)
        balanced.extend(sampled)
        final_counts[lbl] = min_count
    if cfg.DATASET.AUGMENT:
        balanced *= 2
    return balanced, combined_counts, final_counts

def prepare_data(data, target_classes, cfg, is_binary=False):
    random.seed(42)
    if len(target_classes) == 2 and 'abnormal' in target_classes and 'normal' in target_classes:
        logging.info("Using abnormal-vs-normal logic")
        return prepare_abnormal_normal_data(data, cfg)
    class_counts, data_by_class = count_labels(data, target_classes, cfg)
    logging.info(f"Original class distribution: {class_counts}")
    if not cfg.DATASET.BALANCE and not cfg.DATASET.AUGMENT:
        return sum(data_by_class.values(), []), class_counts, class_counts
    min_count = min(class_counts.values())
    balanced, final_counts = [], {}
    for lbl in target_classes:
        sampled = random.sample(data_by_class[lbl], min_count)
        balanced.extend(sampled)
        final_counts[lbl] = min_count
    logging.info(f"Balanced class distribution: {final_counts}")
    if cfg.DATASET.AUGMENT:
        balanced *= 2
    return balanced, class_counts, final_counts

# =============================================================================
# Transforms
# =============================================================================
imagenet_mean = [0.485, 0.456, 0.406]
imagenet_std  = [0.229, 0.224, 0.225]

train_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(imagenet_mean, imagenet_std)
])
patch_transform = transforms.Compose([
    transforms.Resize((112, 112)),
    transforms.ToTensor(),
    transforms.Normalize(imagenet_mean, imagenet_std)
])

# =============================================================================
# Dataset (with FINDINGS: prefix in __getitem__)
# =============================================================================
class FinalSamplesDataset(Dataset):
    def __init__(self, cfg, image_transform=train_transform, patch_transform=patch_transform):
        self.cfg = cfg
        self.image_transform = image_transform
        self.patch_transform = patch_transform

        self.target_classes = cfg.DATASET.TARGET_CLASSES
        if isinstance(self.target_classes, str):
            self.target_classes = self.target_classes.split(",")

        self.is_binary = len(self.target_classes) == 2
        self.abnormal_classify = self.is_binary and 'abnormal' in self.target_classes
        self.abnormal_mapping = (
            {'ra': 'abnormal', 'oa': 'abnormal', 'gout': 'abnormal', 'normal': 'normal'}
            if self.abnormal_classify else None
        )

        with open(cfg.DATASET.JSON, 'r') as f:
            raw_list = json.load(f)

        filtered = []
        for item in raw_list:
            merged = item.get('merged_image_path', '')
            fp = item.get('file_paths', [])
            if isinstance(fp, str):
                fp = [fp]
            paths = [merged] + fp
            if any(os.path.exists(p) for p in paths):
                filtered.append((merged, fp, item))

        self.data = {}
        for i, (merged, fp, item) in enumerate(filtered):
            cls = item.get('class', 'unknown').lower()
            if self.abnormal_mapping:
                cls = self.abnormal_mapping.get(cls, cls)
            self.data[i] = {
                'file_path': merged,
                'left_right_file_path': fp,
                'class_label': cls,
                'diagnosis': item.get('diagnosis', ''),
                'keypoints': item.get('keypoints', {})
            }

        if self.is_binary:
            balanced, _, _ = prepare_data(self.data, self.target_classes, cfg, True)
            self.data = {i: e for i, e in enumerate(balanced)}

        self.tokenizer = None
        self.eos_token  = None

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        e = self.data[idx]
        img = Image.open(e['file_path']).convert('RGB')
        img = self.image_transform(img)
        logging.info(f"[Dataset] full_img shape: {img.shape}")

        patches = self._gen_patches(e['left_right_file_path'], e['keypoints'])
        pt = [self.patch_transform(Image.fromarray(p)) for p in patches]
        patches_tensor = torch.stack(pt, 0) if pt else torch.zeros(34, 3, 112, 112)
        logging.info(f"[Dataset] patches_tensor shape: {patches_tensor.shape}")

        raw = e.get('diagnosis', '')
        clean = self._clean_report(raw)

        # <<<— CHANGED: prepend FINDINGS: so model learns after it
        input_text = f"{self.tokenizer.bos_token} FINDINGS: {clean} {self.tokenizer.eos_token}"
        tok = self.tokenizer(input_text, truncation=True, max_length=512, return_tensors='pt')

        input_ids      = tok['input_ids'].squeeze(0)
        attention_mask = tok['attention_mask'].squeeze(0)
        logging.info(f"[Dataset] input_ids shape: {input_ids.shape}, attention_mask shape: {attention_mask.shape}")

        return {
            'full_img':       img,
            'patches':        patches_tensor,
            'raw_report':     raw,
            'cleaned_report': clean,
            'input_ids':      input_ids,
            'attention_mask': attention_mask
        }

    def _gen_patches(self, paths, kps_dict, crop_size=(200, 300), patch_size=(112, 112)):
        def extract(arr, side_kps):
            lst = []
            pts = side_kps[0]['keypoints']
            for i in range(17):
                x, y, s = int(pts[3*i]), int(pts[3*i+1]), pts[3*i+2]
                if s > 0:
                    x0 = max(x - crop_size[0]//2, 0)
                    y0 = max(y - crop_size[1]//2, 0)
                    x1 = min(x + crop_size[0]//2, arr.shape[1])
                    y1 = min(y + crop_size[1]//2, arr.shape[0])
                    c = arr[y0:y1, x0:x1]
                    if c.size:
                        lst.append(cv2.resize(c, patch_size))
            return lst

        def pad17(lst):
            black = np.zeros((patch_size[1], patch_size[0], 3), np.uint8)
            while len(lst) < 17:
                lst.append(black)
            return lst[:17]

        left, right = [], []
        if len(paths) == 1:
            pth = paths[0]
            if not pth or not os.path.exists(pth):
                return pad17([]) + pad17([])
            img_arr = cv2.imread(pth)
            if img_arr is None:
                return pad17([]) + pad17([])
            arr = cv2.cvtColor(img_arr, cv2.COLOR_BGR2RGB)
            if kps_dict.get('left'):  left  = extract(arr, kps_dict['left'])
            if kps_dict.get('right'): right = extract(arr, kps_dict['right'])
        else:
            for side, pth in zip(['left','right'], paths):
                if pth and os.path.exists(pth):
                    img_arr = cv2.imread(pth)
                    if img_arr is not None:
                        arr = cv2.cvtColor(img_arr, cv2.COLOR_BGR2RGB)
                        if kps_dict.get(side):
                            lst = extract(arr, kps_dict[side])
                            if side=='left':  left  = lst
                            else:             right = lst

        if left and not right:
            right = [cv2.flip(p,1) for p in left]
        if right and not left:
            left  = [cv2.flip(p,1) for p in right]
        if not left and not right:
            return pad17([]) + pad17([])

        return pad17(left) + pad17(right)

    def _clean_report(self, text):
        text = unicodedata.normalize('NFKC', text or '')
        text = re.sub(r'(?m)^-+\s*$', '', text)
        text = re.sub(r'[^\x00-\x7F]+', ' ', text)
        text = re.sub(r'([.!?]){2,}', r'\1', text)
        text = re.sub(r'\[\s*finding\s*\]', '[FINDING]', text, flags=re.IGNORECASE)
        text = re.sub(r'\[\s*conclusion\s*\]', '[CONCLUSION]', text, flags=re.IGNORECASE)
        text = re.sub(r'\[\s*diagnosis\s*\]', '[DIAGNOSIS]', text, flags=re.IGNORECASE)
        parts = re.split(r'\[\s*recommend(?:ation)?\s*\]', text, flags=re.IGNORECASE)
        text = parts[0]
        fm = re.search(r'\[FINDING\](.*?)(?=\[|$)', text, flags=re.IGNORECASE|re.DOTALL)
        cm = re.search(r'\[CONCLUSION\](.*?)(?=\[|$)', text, flags=re.IGNORECASE|re.DOTALL)
        if fm and cm and fm.group(1).strip().lower() == cm.group(1).strip().lower():
            text = re.sub(r'\[CONCLUSION\].*?(?=\[|$)', '', text, flags=re.IGNORECASE|re.DOTALL)
        text = re.sub(r'\[\s*(FINDING|CONCLUSION|DIAGNOSIS)\s*\]', '', text, flags=re.IGNORECASE)
        text = text.replace('_x000D_', ' ')
        return re.sub(r'\s+', ' ', text).strip()

# =============================================================================
# Collate function
# =============================================================================
def collate_fn(batch):
    imgs = torch.stack([b['full_img'] for b in batch])
    logging.info(f"[Collate] imgs: {imgs.shape}")

    pts = [b['patches'] for b in batch]
    max_p = max(p.shape[0] for p in pts)
    pads = []
    for p in pts:
        if p.shape[0] < max_p:
            pad = torch.zeros((max_p - p.shape[0], *p.shape[1:]))
            p = torch.cat([p, pad], dim=0)
        pads.append(p)
    patches = torch.stack(pads, 0)
    logging.info(f"[Collate] patches: {patches.shape}")

    ids   = [b['input_ids'] for b in batch]
    masks = [b['attention_mask'] for b in batch]
    ids   = nn.utils.rnn.pad_sequence(ids, batch_first=True, padding_value=tokenizer.pad_token_id)
    masks = nn.utils.rnn.pad_sequence(masks, batch_first=True, padding_value=0)
    logging.info(f"[Collate] ids: {ids.shape}, masks: {masks.shape}")

    return {
        'full_imgs':       imgs,
        'patches':         patches,
        'input_ids':       ids,
        'attention_mask':  masks,
        'raw_reports':     [b['raw_report']     for b in batch],
        'cleaned_reports': [b['cleaned_report'] for b in batch]
    }

# =============================================================================
# Model definition, with LoRA integration
# =============================================================================
class MultiModalModel(nn.Module):
    def __init__(self, gpt2_model_name='gpt2'):
        super().__init__()
        # Global image encoder
        self.global_encoder = timm.create_model('swin_base_patch4_window7_224', pretrained=True)
        self.global_encoder.reset_classifier(0)
        self.global_proj    = nn.Linear(self.global_encoder.num_features, 768)

        # Patch encoder
        self.patch_encoder  = timm.create_model('resnet50', pretrained=True)
        self.patch_encoder.fc = nn.Identity()
        self.patch_proj     = nn.Linear(self.patch_encoder.num_features, 768)

        # Fusion
        self.attn           = nn.MultiheadAttention(embed_dim=768, num_heads=8, batch_first=True)
        self.norm           = nn.LayerNorm(768)

        # GPT-2 decoder w/ cross-attention
        self.decoder = GPT2LMHeadModel.from_pretrained(
            gpt2_model_name, add_cross_attention=True
        )

        # LoRA on self-attn
        lora_config = LoraConfig(
            task_type=TaskType.CAUSAL_LM,
            r=16,
            lora_alpha=32,
            lora_dropout=0.05,
            target_modules=["c_attn", "c_proj"],
            bias="none"
        )
        self.decoder = get_peft_model(self.decoder, lora_config)
        print("LoRA adapters integrated into GPT-2 decoder")

    def _pool(self, feats):
        return feats.mean(dim=[2,3]) if feats.ndim>2 else feats

    def forward(self, imgs, patches, input_ids, attention_mask, decoder_labels=None):
        g_feats = self.global_encoder(imgs)
        g = self.global_proj(g_feats).unsqueeze(1)

        B,N,C,H,W = patches.shape
        p = patches.view(B*N, C, H, W)
        pf_feats = (
            self.patch_encoder.forward_features(p)
            if hasattr(self.patch_encoder, 'forward_features')
            else self.patch_encoder(p)
        )
        pf_pooled = self._pool(pf_feats)
        pf = self.patch_proj(pf_pooled).view(B, N, 768)

        cat, _ = self.attn(
            torch.cat([g, pf],1),
            torch.cat([g, pf],1),
            torch.cat([g, pf],1)
        )
        comb = self.norm(cat)

        out = self.decoder(
            input_ids=input_ids,
            attention_mask=attention_mask,
            encoder_hidden_states=comb,
            labels=decoder_labels
        )
        return out

# =============================================================================
# Training & evaluation loops
# =============================================================================
def train_epoch(model, loader, optimizer, scaler, device):
    model.train()
    total_loss = 0.
    for b in tqdm(loader, desc="Training", leave=False):
        imgs = b['full_imgs'].to(device)
        pts  = b['patches'].to(device)
        ids  = b['input_ids'].to(device)
        msk  = b['attention_mask'].to(device)

        optimizer.zero_grad()
        with torch.amp.autocast(device_type='cuda'):
            out = model(imgs, pts, ids, msk, decoder_labels=ids)
            loss = out.loss
        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()
        total_loss += loss.item()
    return total_loss / len(loader)

# ─── UPDATED EVALUATE() ─────────────────────────────────────────────────────
def evaluate(model, loader, device):
    model.eval()
    total_loss = 0.
    all_gen, all_gt = [], []
    for b in tqdm(loader, desc="Evaluating", leave=False):
        imgs = b['full_imgs'].to(device)
        pts  = b['patches'].to(device)
        ids  = b['input_ids'].to(device)
        msk  = b['attention_mask'].to(device)

        with torch.no_grad():
            out = model(imgs, pts, ids, msk, decoder_labels=ids)
            total_loss += out.loss.item()

            # rebuild visual context (unchanged)…
            g_feats = model.global_encoder(imgs)
            g       = model.global_proj(g_feats).unsqueeze(1)
            B,N,C,H,W = pts.shape
            p      = pts.view(B*N, C, H, W)
            pf_feats = model.patch_encoder(p)
            pf_pooled= model._pool(pf_feats)
            pf        = model.patch_proj(pf_pooled).view(B, N, 768)
            cat,_  = model.attn(
                torch.cat([g,pf],1),
                torch.cat([g,pf],1),
                torch.cat([g,pf],1)
            )
            comb    = model.norm(cat)

            # GREEDY / BEAM decoding instead of heavy sampling
            prompt_ids = tokenizer("FINDINGS:", return_tensors="pt",
                                   add_special_tokens=False).input_ids.to(device)
            prompt_ids = prompt_ids.expand(B, -1)
            prompt_mask= torch.ones_like(prompt_ids, device=device)

            gen_ids = model.decoder.generate(
                input_ids=prompt_ids,
                attention_mask=prompt_mask,
                encoder_hidden_states=comb,
                encoder_attention_mask=torch.ones(B, comb.size(1), device=device),
                max_length=150,

                # ← key change: no sampling, use beam search
                do_sample=False,
                num_beams=4,
                early_stopping=True,

                eos_token_id=tokenizer.eos_token_id,
                pad_token_id=tokenizer.eos_token_id
            )
            gen_txt = [tokenizer.decode(g_, skip_special_tokens=True) for g_ in gen_ids]
            gt_txt  = [tokenizer.decode(i_, skip_special_tokens=True) for i_ in ids]
            all_gen.extend(gen_txt)
            all_gt .extend(gt_txt)

    return total_loss/len(loader), all_gen, all_gt


def compute_semantic_similarity(gen, gt):
    stm = SentenceTransformer('all-MiniLM-L6-v2')
    e1 = stm.encode(gen, convert_to_tensor=True)
    e2 = stm.encode(gt,  convert_to_tensor=True)
    return nn.functional.cosine_similarity(e1, e2).mean().item()

def plot_metrics(train_losses, val_losses, sems):
    epochs = range(1, len(train_losses)+1)
    plt.figure(figsize=(12,5))
    plt.subplot(1,2,1)
    plt.plot(epochs, train_losses, label="Train Loss")
    plt.plot(epochs, val_losses,   label="Val Loss")
    plt.xlabel("Epoch"); plt.ylabel("Loss"); plt.legend()
    plt.subplot(1,2,2)
    plt.plot(epochs, sems, label="Semantic Sim")
    plt.xlabel("Epoch"); plt.ylabel("Sim"); plt.legend()
    plt.tight_layout(); plt.show()

# =============================================================================
# MAIN: two-phase training with freeze/unfreeze
# =============================================================================
class Cfg: pass
cfg = Cfg()
cfg.DATASET = Cfg()
cfg.DATASET.JSON           = 'final_samples_both_only_v2.json'
cfg.DATASET.USE_RAW        = True
cfg.DATASET.USE_PATCH      = True
cfg.DATASET.REPORT         = True
cfg.DATASET.TARGET_CLASSES = ['ra','oa','gout','normal','uncertain','ref.prev']
cfg.DATASET.BALANCE        = False
cfg.DATASET.AUGMENT        = False

# ─── Tokenizer setup
tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
tokenizer.add_special_tokens({
    "bos_token": "<BOS>",
    "additional_special_tokens": ["FINDINGS:"]
})
tokenizer.padding_side = 'left'
tokenizer.pad_token     = tokenizer.eos_token

# ─── Device & Model
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
logging.info(f"Using device: {device}")

model = MultiModalModel().to(device)
model.decoder.resize_token_embeddings(len(tokenizer))

# ─── Dataset
dataset = FinalSamplesDataset(cfg)
dataset.tokenizer = tokenizer
dataset.eos_token  = tokenizer.eos_token

dist = Counter(e['class_label'] for e in dataset.data.values())
for cls,cnt in dist.items():
    logging.info(f"  {cls}: {cnt}")
    print(f"  {cls}: {cnt}")

n = len(dataset)
n_train = int(0.8 * n)
n_val   = int(0.1 * n)
n_test  = n - n_train - n_val
train_ds, val_ds, test_ds = random_split(dataset, [n_train, n_val, n_test])

print(f"\nNumber of training samples:   {len(train_ds)}")
print(f"Number of validation samples: {len(val_ds)}")
print(f"Number of test samples:       {len(test_ds)}")
print(f"Total samples:                {len(train_ds) + len(val_ds) + len(test_ds)}\n")

train_loader = DataLoader(train_ds, batch_size=4, shuffle=True, collate_fn=collate_fn)
val_loader   = DataLoader(val_ds,   batch_size=4, shuffle=False, collate_fn=collate_fn)
test_loader  = DataLoader(test_ds,  batch_size=4, shuffle=False, collate_fn=collate_fn)

# =============================================================================
# Phase 1: freeze base GPT-2 (except cross-attn), train LoRA + vision + cross-attn
# =============================================================================
num_layers = len(model.decoder.base_model.transformer.h)
last_two = list(range(num_layers-2, num_layers))

# Phase 1: freeze everything except cross-attn, LoRA adapters, vision & last-2 layers
for name, p in model.decoder.base_model.named_parameters():
    if ("crossattention" in name.lower()
        or any(f"transformer.h.{i}" in name for i in last_two)):
        p.requires_grad = True
    else:
        p.requires_grad = False

for p in model.global_proj.parameters():
    p.requires_grad = True
for p in model.patch_proj.parameters():
    p.requires_grad = True

optimizer = optim.AdamW(filter(lambda x: x.requires_grad, model.parameters()), lr=5e-5)
scheduler = torch.optim.lr_scheduler.CosineAnnealingWarmRestarts(optimizer, T_0=10, T_mult=2)
scaler    = torch.amp.GradScaler()

phase1_epochs = 1
train_losses, val_losses, sems = [], [], []

for epoch in range(phase1_epochs):
    print(f"\n-- Phase 1, Epoch {epoch+1}/{phase1_epochs} --")
    train_loss = train_epoch(model, train_loader, optimizer, scaler, device)

    # sanity-check gradient norm after first epoch
    if epoch == 0:
        total_norm = 0.0
        for name,p in model.named_parameters():
            if p.grad is not None:
                total_norm += p.grad.data.norm(2).item()**2
        print(f"Grad norm after 1st epoch backward: {total_norm**0.5:.4f}")

    val_loss, gen_txt, gt_txt = evaluate(model, val_loader, device)
    sem = compute_semantic_similarity(gen_txt, gt_txt)

    train_losses.append(train_loss)
    val_losses.append(val_loss)
    sems.append(sem)

    print(f"  Train Loss          : {train_loss:.4f}")
    print(f"  Validation Loss     : {val_loss:.4f}")
    print(f"  Semantic Similarity : {sem:.4f}")
    scheduler.step()

plot_metrics(train_losses, val_losses, sems)

# =============================================================================
# Phase 2: freeze base GPT-2 (except cross-attn), finetune LoRA only
# =============================================================================
for name, p in model.decoder.base_model.named_parameters():
    if ("crossattention" in name.lower()
        or any(f"transformer.h.{i}" in name for i in last_two)):
        p.requires_grad = True
    else:
        p.requires_grad = False

optimizer = optim.AdamW(filter(lambda x: x.requires_grad, model.parameters()), lr=1e-6)
scheduler = torch.optim.lr_scheduler.CosineAnnealingWarmRestarts(optimizer, T_0=5, T_mult=1)
scaler    = torch.amp.GradScaler()

phase2_epochs = 1
for epoch in range(phase2_epochs):
    print(f"\n-- Phase 2, Epoch {epoch+1}/{phase2_epochs} --")
    train_loss = train_epoch(model, train_loader, optimizer, scaler, device)
    val_loss, gen_txt, gt_txt = evaluate(model, val_loader, device)
    sem = compute_semantic_similarity(gen_txt, gt_txt)

    print(f"  Train Loss          : {train_loss:.4f}")
    print(f"  Validation Loss     : {val_loss:.4f}")
    print(f"  Semantic Similarity : {sem:.4f}")
    scheduler.step()

# Final test
test_loss, test_gen, test_gt = evaluate(model, test_loader, device)
test_sem = compute_semantic_similarity(test_gen, test_gt)

print("\n========== TEST RESULTS ==========")
print(f"Test Loss               : {test_loss:.4f}")
print(f"Test Semantic Similarity: {test_sem:.4f}")

# Random examples
for idx in random.sample(range(len(test_ds)), min(30, len(test_ds))):
    ex    = test_ds[idx]
    raw   = ex['raw_report']
    clean = ex['cleaned_report']
    fi    = ex['full_img'].unsqueeze(0).to(device)
    pa    = ex['patches'].unsqueeze(0).to(device)

    # build visual context
    g_feats = model.global_encoder(fi)
    g       = model.global_proj(g_feats).unsqueeze(1)
    B,N,C,H,W = pa.shape
    p      = pa.view(B*N, C, H, W)
    pf_feats= model.patch_encoder(p)
    pf_pooled= model._pool(pf_feats)
    pf        = model.patch_proj(pf_pooled).view(B,N,768)
    cat,_    = model.attn(torch.cat([g,pf],1),
                          torch.cat([g,pf],1),
                          torch.cat([g,pf],1))
    comb     = model.norm(cat)

    # generate after FINDINGS: prompt
    prompt_ids = tokenizer("FINDINGS:", return_tensors="pt", add_special_tokens=False).input_ids.to(device)
    prompt_mask= torch.ones_like(prompt_ids, device=device)
    gen_ids = model.decoder.generate(
        input_ids=prompt_ids,
        attention_mask=prompt_mask,
        encoder_hidden_states=comb,
        encoder_attention_mask=torch.ones(1, comb.size(1), device=device),
        max_length=150,
        do_sample=True,
        top_p=0.9,
        temperature=0.7,
        repetition_penalty=1.3,
        eos_token_id=tokenizer.eos_token_id,
        pad_token_id=tokenizer.eos_token_id
    )
    gen = tokenizer.decode(gen_ids[0], skip_special_tokens=True)

    print(f"\n--- Example {idx} ---")
    print(f"Raw Report       : \n{raw}")
    print(f"Cleaned Report   : \n{clean}")
    print(f"Generated Report : \n{gen}")
# Out:
# Some weights of GPT2LMHeadModel were not initialized from the model checkpoint at gpt2 and are newly initialized: ['h.0.crossattention.c_attn.bias', 'h.0.crossattention.c_attn.weight', 'h.0.crossattention.c_proj.bias', 'h.0.crossattention.c_proj.weight', 'h.0.crossattention.q_attn.bias', 'h.0.crossattention.q_attn.weight', 'h.0.ln_cross_attn.bias', 'h.0.ln_cross_attn.weight', 'h.1.crossattention.c_attn.bias', 'h.1.crossattention.c_attn.weight', 'h.1.crossattention.c_proj.bias', 'h.1.crossattention.c_proj.weight', 'h.1.crossattention.q_attn.bias', 'h.1.crossattention.q_attn.weight', 'h.1.ln_cross_attn.bias', 'h.1.ln_cross_attn.weight', 'h.10.crossattention.c_attn.bias', 'h.10.crossattention.c_attn.weight', 'h.10.crossattention.c_proj.bias', 'h.10.crossattention.c_proj.weight', 'h.10.crossattention.q_attn.bias', 'h.10.crossattention.q_attn.weight', 'h.10.ln_cross_attn.bias', 'h.10.ln_cross_attn.weight', 'h.11.crossattention.c_attn.bias', 'h.11.crossattention.c_attn.weight', 'h.11.crossattention.c_proj.bias', 'h.11.crossattention.c_proj.weight', 'h.11.crossattention.q_attn.bias', 'h.11.crossattention.q_attn.weight', 'h.11.ln_cross_attn.bias', 'h.11.ln_cross_attn.weight', 'h.2.crossattention.c_attn.bias', 'h.2.crossattention.c_attn.weight', 'h.2.crossattention.c_proj.bias', 'h.2.crossattention.c_proj.weight', 'h.2.crossattention.q_attn.bias', 'h.2.crossattention.q_attn.weight', 'h.2.ln_cross_attn.bias', 'h.2.ln_cross_attn.weight', 'h.3.crossattention.c_attn.bias', 'h.3.crossattention.c_attn.weight', 'h.3.crossattention.c_proj.bias', 'h.3.crossattention.c_proj.weight', 'h.3.crossattention.q_attn.bias', 'h.3.crossattention.q_attn.weight', 'h.3.ln_cross_attn.bias', 'h.3.ln_cross_attn.weight', 'h.4.crossattention.c_attn.bias', 'h.4.crossattention.c_attn.weight', 'h.4.crossattention.c_proj.bias', 'h.4.crossattention.c_proj.weight', 'h.4.crossattention.q_attn.bias', 'h.4.crossattention.q_attn.weight', 'h.4.ln_cross_attn.bias', 'h.4.ln_cross_attn.weight', 'h.5.crossattention.c_attn.bias', 'h.5.crossattention.c_attn.weight', 'h.5.crossattention.c_proj.bias', 'h.5.crossattention.c_proj.weight', 'h.5.crossattention.q_attn.bias', 'h.5.crossattention.q_attn.weight', 'h.5.ln_cross_attn.bias', 'h.5.ln_cross_attn.weight', 'h.6.crossattention.c_attn.bias', 'h.6.crossattention.c_attn.weight', 'h.6.crossattention.c_proj.bias', 'h.6.crossattention.c_proj.weight', 'h.6.crossattention.q_attn.bias', 'h.6.crossattention.q_attn.weight', 'h.6.ln_cross_attn.bias', 'h.6.ln_cross_attn.weight', 'h.7.crossattention.c_attn.bias', 'h.7.crossattention.c_attn.weight', 'h.7.crossattention.c_proj.bias', 'h.7.crossattention.c_proj.weight', 'h.7.crossattention.q_attn.bias', 'h.7.crossattention.q_attn.weight', 'h.7.ln_cross_attn.bias', 'h.7.ln_cross_attn.weight', 'h.8.crossattention.c_attn.bias', 'h.8.crossattention.c_attn.weight', 'h.8.crossattention.c_proj.bias', 'h.8.crossattention.c_proj.weight', 'h.8.crossattention.q_attn.bias', 'h.8.crossattention.q_attn.weight', 'h.8.ln_cross_attn.bias', 'h.8.ln_cross_attn.weight', 'h.9.crossattention.c_attn.bias', 'h.9.crossattention.c_attn.weight', 'h.9.crossattention.c_proj.bias', 'h.9.crossattention.c_proj.weight', 'h.9.crossattention.q_attn.bias', 'h.9.crossattention.q_attn.weight', 'h.9.ln_cross_attn.bias', 'h.9.ln_cross_attn.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# LoRA adapters integrated into GPT-2 decoder
#   oa: 573
#   ra: 115
#   uncertain: 620
#   oa, ra: 8
#   normal: 748
#   gout: 267
#   combination of oa, ra: 3
#   ref.prev: 60
#
# Number of training samples:   1915
# Number of validation samples: 239
# Number of test samples:       240
# Total samples:                2394
#
#
# -- Phase 1, Epoch 1/1 --
# Grad norm after 1st epoch backward: 3.9506
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
#   Train Loss          : 1.9271
#   Validation Loss     : 1.4329
#   Semantic Similarity : 0.2275
# -- Phase 2, Epoch 1/1 --
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
#   Train Loss          : 1.5269
#   Validation Loss     : 1.3780
#   Semantic Similarity : 0.2115
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# ========== TEST RESULTS ==========
# Test Loss               : 1.3842
# Test Semantic Similarity: 0.2171
#
# --- Example 95 ---
# Raw Report       :
# [ Finding ]_x000D_
# dislocation, right 3rd MTP joint._x000D_
# [ Conclusion ]_x000D_
# dislocation, right 3rd MTP joint._x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# dislocation, right 3rd MTP joint.
# Generated Report :
#   The patella, both. No significant interval change since last study on radiographs or femoral bone erosion of ankle soft tissue in left foot with erosions at Rt 1st MTP joint and right 10th MT knee RA involvement (non-significant intervals). - no bony abnormality after alloarticular osteopenia degenerative changes over time; Lt 2nd toe OA: Bilateral phalanx nodal lesion type II ossification V/O gout arthritis ------------------------------------------ --> inguinal calcaneus lateral hallux valgum -> probable accessory navicularean joints --------------------
#
# --- Example 96 ---
# Raw Report       :
# [ Finding ]_x000D_
# no bony lesion._x000D_
# [ Conclusion ]_x000D_
# no bony lesion._x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# no bony lesion.
# Generated Report :
#
#
# --- Example 5 ---
# Raw Report       :
# [FINDING       ]_x000D_Rt. 1st MTP joint, OA with erosion and soft tissue swelling
#   --> gout arthritis._x000D__x000D_[CONCLUSION    ]_x000D_Rt. 1st MTP joint, OA with erosion and soft tissue swelling
#   --> gout arthritis._x000D__x000D_[RECOMMENDATION]_x000D_-
# Cleaned Report   :
# Rt. 1st MTP joint, OA with erosion and soft tissue swelling --> gout arthritis.
# Generated Report :
#   horizontal bone . soft tissue swelling and both feet, no significant bony abnormality. No abnormal abnormalities on radiographs or MRI showing any changes at all either.(both hands.)
#
# --- Example 239 ---
# Raw Report       :
# [ Finding ]_x000D_
# _x000D_
# [ Conclusion ]_x000D_
# Calcification and osteophyte growing with suspected bony erosions, both 3rd MCP, 1st CMC and Rt. 1st MCP and both 1st MTP_x000D_
#  -> R/O gout_x000D_
# _x000D_
# Both hallus valgus_x000D_
# OA, both wrist, Rt. ankle joints and both subtalar joints_x000D_
# Bony fragment, Rt. medial malleolus_x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# Calcification and osteophyte growing with suspected bony erosions, both 3rd MCP, 1st CMC and Rt. 1st MCP and both 1st MTP -> R/O gout Both hallus valgus OA, both wrist, Rt. ankle joints and both subtalar joints Bony fragment, Rt. medial malleolus
# Generated Report :
#   mathemat. 1st MTP joint, both feet and wrists soft tissue swelling in right hand with Rt 2nd MT joints at base of left 3rd mTk ankle OA --> RA involvement
#
# --- Example 179 ---
# Raw Report       :
# [ Finding ]_x000D_
# both ankle OA._x000D_
# [ Conclusion ]_x000D_
# both ankle OA._x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# both ankle OA.
# Generated Report :
#   redes post-arousal joint, both 1st MTP joints. No bony abnormality on radiographs or fracture of left 2nd PIP ankle bone >1 vertebral canal with degenerative change at Lt ciculare type II TMT and OA RA involvement . Both hands erosion in right hand base 3rd MT Rt 5th PT knee soft tissue swelling suggestive os trigonum small subchondral lesion - possible ossification recessed r/o gout arthritis -> Knee calcaneus incongruidation --> Bilateral lumborum infusion -- no significant interval changes since last study --------------------------------
#
# --- Example 155 ---
# Raw Report       :
# [ Finding ]_x000D_
# suspicious small bone erosion in both 1st proximal phalangeal bone of PIP joint._x000D_
# mild joint space narrowing in right 1st MTP joint with suspicious subchondral cyst in 1st proximal phalangeal bone base and periarticular osteopenia._x000D_
# [ Diagnosis ]_x000D_
# suspicious inflammatory arthritis including rheumatoid arthritis._x000D_
# [ Recommend ]_x000D_
# REC) clinical correlation
# Cleaned Report   :
# suspicious small bone erosion in both 1st proximal phalangeal bone of PIP joint. mild joint space narrowing in right 1st MTP joint with suspicious subchondral cyst in 1st proximal phalangeal bone base and periarticular osteopenia. suspicious inflammatory arthritis including rheumatoid arthritis.
# Generated Report :
#
#
# --- Example 38 ---
# Raw Report       :
# [ Finding ]_x000D_
# _x000D_
# [ Diagnosis ]_x000D_
# Os naviculare type 3_x000D_
# Right 1st MTP joint soft tissue swelling_x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# Os naviculare type 3 Right 1st MTP joint soft tissue swelling
# Generated Report :
#  - no significant interval change since last study. No major intervals changes in radiographs or other pathology at all except for talonum, left lateral bone type III and minor osteopenia of right 1st MTP joint with R/O gouty arthritis on both sides to feet (both). TMT activity is moderate but not abnormal either - probable soft tissue swelling along the 2nd MT joints . Lt calcaneal erosion elsewhere as well
#
# --- Example 168 ---
# Raw Report       :
# [ Finding ]_x000D_
# Erosive change in MTP, intertarsal joint, both._x000D_
# [ Diagnosis ]_x000D_
# _x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# Erosive change in MTP, intertarsal joint, both.
# Generated Report :
#
#
# --- Example 99 ---
# Raw Report       :
# [ Finding ]_x000D_
# _x000D_
# [ Diagnosis ]_x000D_
# Osteophyte of right 1st MTP joint._x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# Osteophyte of right 1st MTP joint.
# Generated Report :
#
#
# --- Example 13 ---
# Raw Report       :
# [ Finding ]_x000D_
# Soft tissue swelling in 1st MTP joint, both._x000D_
# Sclerotic lesion in left 2nd metatarsal diaphysis: osteoma, osteoid osteoma, stress fracture._x000D_
# [ Diagnosis ]_x000D_
# _x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# Soft tissue swelling in 1st MTP joint, both. Sclerotic lesion in left 2nd metatarsal diaphysis: osteoma, osteoid osteoma, stress fracture.
# Generated Report :
#
#
# --- Example 126 ---
# Raw Report       :
# [FINDING       ]_x000D_soft tissue swelling around Rt 1st MTP joint_x000D__x000D_[CONCLUSION    ]_x000D_soft tissue swelling around Rt 1st MTP joint_x000D__x000D_[RECOMMENDATION]_x000D_-
# Cleaned Report   :
# soft tissue swelling around Rt 1st MTP joint
# Generated Report :
#
#
# --- Example 35 ---
# Raw Report       :
# [FINDING       ]_x000D_pes cavus, both.
# degenerative change_x000D__x000D_[CONCLUSION    ]_x000D_pes cavus, both.
# degenerative change_x000D__x000D_[RECOMMENDATION]_x000D_-
# Cleaned Report   :
# pes cavus, both. degenerative change
# Generated Report :
#   is likely osteopenia degenerative change. both feet, middle 3rd MTP joint with possible mild OA fracture and calcification of left 1st toe soft tissue swelling at Rt 2nd Gout arthritis --> r/o gouts -> RA involvement in right ankle ossicle type II > bilateral periarticular edema regrowth (Rx) - probable PIP TMT joints ---------------------------------------- Lt foot deformity on radiographs as indicated by ultrasthenoid erosions hereonocarpal ulnar area erosion
#
# --- Example 87 ---
# Raw Report       :
# [ Finding ]_x000D_
# degenerative change._x000D_
# [ Conclusion ]_x000D_
# degenerative change._x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# degenerative change.
# Generated Report :
#   redes osteopenia degenerative change. both feet, right 1st MTP joint with accessory navicular bone swelling in left foot and r/o gouty arthritis of Rt 5th mtp ankle soft tissue erosion (R-5th MT) on radiographs as indicated by TMT > Lt 2nd postosilateral OA RA involvement for sedation at 3rd PT joints -> ossicle formation --> no significant bony abnormality or os trigonum No statistically meaningful interval increase since last study --------------------------------
#
# --- Example 207 ---
# Raw Report       :
# [ Finding ]_x000D_
# _x000D_
# [ Diagnosis ]_x000D_
# 1. Small osteophyte in left first MTP joint._x000D_
#    --- mild Osteoarthritis_x000D_
# 2. possible bone erosion in left 1st metatarsal head without soft tissue swelling_x000D_
#    ---suspicious gouty arthritis._x000D_
#    --- REC) clinical correlation._x000D_
# 3. Soft tissue bulging with calcification adjacent right lateral malleolus._x000D_
#    --- REC) clinical correlation._x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# 1. Small osteophyte in left first MTP joint. --- mild Osteoarthritis 2. possible bone erosion in left 1st metatarsal head without soft tissue swelling ---suspicious gouty arthritis. --- REC) clinical correlation. 3. Soft tissue bulging with calcification adjacent right lateral malleolus. --- REC) clinical correlation.
# Generated Report :
#
#
# --- Example 56 ---
# Raw Report       :
# [ Finding ]_x000D_
# both feet, intertarsal joints, bony erosion._x000D_
#    --> gout arthritis suggested._x000D_
# [ Conclusion ]_x000D_
# both feet, intertarsal joints, bony erosion._x000D_
#    --> gout arthritis suggested._x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# both feet, intertarsal joints, bony erosion. --> gout arthritis suggested.
# Generated Report :
#
#
# --- Example 39 ---
# Raw Report       :
# [ Finding ]_x000D_
# no significant interval change since last study._x000D_
# [ Conclusion ]_x000D_
# no significant interval change since last study._x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# no significant interval change since last study.
# Generated Report :
#   suspicous periarticular osteopenia. Lt 1st MTP joint, calcaneal area of left 5th MT TMT MRT RA involvement in right 3rd knee bone type II with both accessory naviculareolar and lateral malleolus medial part of OA at Rt 2nd proximal phalanxilateral gout soft tissue swelling on radiographs 4/5 mHP erosion to the head CT erosions -> rheumatoid arthritis Bony abnormality --> no bifocal cystic fibrosis GIPs or pes planterite-ocecalcification ------------------------------------------------------------------------ No significant interval change since last study ------------------------------------------ degenerative changes all over body except feet - ulnar hallux
#
# --- Example 175 ---
# Raw Report       :
# [ Finding ]_x000D_
# _x000D_
# No bony abnormalities._x000D_
# [ Diagnosis ]_x000D_
# _x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# No bony abnormalities.
# Generated Report :
#  . No bony abnormality, no significant interval change since last study of left 1st MTP joint and right 2nd MT joints at Rt 20th N/O gout arthritis degenerative changes to both 3rd MM head TMT --> RA involvement in radiographs 5-6 foot OA with Bilioid bone erosion on Lt 4 th phalanxalar aspect osteopenia calcaneus fracture ------------------------------------------ accessory navicular bones not evident yet (ROT) ankle soft tissue swelling -> rtu area type II os trigonum minor or suspected lumbary lesion GIP ratio > 0/-2g periarticularean nodularization - probable cuneiform abnormalities Erosions Knee
#
# --- Example 225 ---
# Raw Report       :
# [ Finding ]_x000D_
# _x000D_
# [ Diagnosis ]_x000D_
# Lt. calcaneocuboidal joint, OA with accessory ossicle._x000D_
# both calcaneal spur._x000D_
# _x000D_
# both wrist, RA with bony erosion._x000D_
# _x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# Lt. calcaneocuboidal joint, OA with accessory ossicle. both calcaneal spur. both wrist, RA with bony erosion.
# Generated Report :
#
#
# --- Example 70 ---
# Raw Report       :
# [FINDING       ]_x000D_Mild degenerative change, both talonavicular joint and Lt 1st MTP joint
# Erosions, Lt 1st MTP joint. r/o gout_x000D__x000D_[CONCLUSION    ]_x000D_Mild degenerative change_x000D__x000D_[RECOMMENDATION]_x000D_-
# Cleaned Report   :
# Mild degenerative change, both talonavicular joint and Lt 1st MTP joint Erosions, Lt 1st MTP joint. r/o gout Mild degenerative change
# Generated Report :
#
#
#
# --- Example 169 ---
# Raw Report       :
# [ Finding ]_x000D_
# no significant bony lesion on radiographs._x000D_
# _x000D_
# [ Conclusion ]_x000D_
# no significant bony lesion on radiographs._x000D_
# _x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# no significant bony lesion on radiographs.
# Generated Report :
#   "Dry body, both feet and ankles. Both ankle joints degenerative change in form of erosions on radiographs." -- Lt 1st MTP joint -> soft tissue swelling at R/O gout arthritis with calcification (potus lateral aspect). --> RA involvement or OA incisional bone erosion along fractures as indicated by MRI 2nd MT finger fracture right below left knee site suggestive os naviculare type II ballroom area Knee Bony abnormality recessed to medial part temple-gut Type III patella milder modification possible minor ossicle abnormalities PIP biliary nodular lesion plus osteopenia regressive changes probable GOUT progression moderate - no significant interval increase since last study
#
# --- Example 54 ---
# Raw Report       :
# [FINDING       ]_x000D_Lt. ankle loose body.
# degenerative change_x000D__x000D_[CONCLUSION    ]_x000D_Lt. ankle loose body.
# degenerative change_x000D__x000D_[RECOMMENDATION]_x000D_-
# Cleaned Report   :
# Lt. ankle loose body. degenerative change
# Generated Report :
#
#
# --- Example 196 ---
# Raw Report       :
# [ Finding ]_x000D_
# no bony lesion._x000D_
# [ Diagnosis ]_x000D_
# no bony lesion._x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# no bony lesion. no bony lesion.
# Generated Report :
#
#
# --- Example 238 ---
# Raw Report       :
# [ Finding ]_x000D_
# suspicious gout, both ankle joints._x000D_
# [ Conclusion ]_x000D_
# suspicious gout, both ankle joints._x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# suspicious gout, both ankle joints.
# Generated Report :
#
#
#
# --- Example 234 ---
# Raw Report       :
# [ Finding ]_x000D_
# diffuse osteopenia._x000D_
# [ Conclusion ]_x000D_
# diffuse osteopenia._x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# diffuse osteopenia.
# Generated Report :
#
#
# --- Example 216 ---
# Raw Report       :
# [FINDING       ]_x000D_soft tissue swelling, LT ankle
# others, no significant interval change_x000D__x000D_[CONCLUSION    ]_x000D_soft tissue swelling, LT ankle
# others, no significant interval change_x000D__x000D_[RECOMMENDATION]_x000D_-
# Cleaned Report   :
# soft tissue swelling, LT ankle others, no significant interval change
# Generated Report :
#
#
#
# --- Example 164 ---
# Raw Report       :
# [FINDING       ]_x000D_diffuse osteopenia
# degenerative change_x000D__x000D_[CONCLUSION    ]_x000D_diffuse osteopenia
# degenerative change_x000D__x000D_[RECOMMENDATION]_x000D_-
# Cleaned Report   :
# diffuse osteopenia degenerative change
# Generated Report :
#
#
#
# --- Example 208 ---
# Raw Report       :
# [ Finding ]_x000D_
# diffuse osteopenia._x000D_
# degenerative change, both feet._x000D_
# s/p TKA, Lt._x000D_
# _x000D_
# Rt. knee OA._x000D_
# [ Conclusion ]_x000D_
# diffuse osteopenia._x000D_
# degenerative change, both feet._x000D_
# s/p TKA, Lt._x000D_
# _x000D_
# Rt. knee OA._x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# diffuse osteopenia. degenerative change, both feet. s/p TKA, Lt. Rt. knee OA.
# Generated Report :
#
#
# --- Example 154 ---
# Raw Report       :
# [ Finding ]_x000D_
# No bony abnormality._x000D_
# [ Diagnosis ]_x000D_
# No bony abnormality._x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# No bony abnormality. No bony abnormality.
# Generated Report :
#
#
# --- Example 213 ---
# Raw Report       :
# [ Finding ]_x000D_
# minimal OA, both knee joints._x000D_
# Rt. calcaneous, old fracture._x000D_
# Rt. 5th MT head fracture, old._x000D_
# both 3-4th MT head, radiolucency._x000D_
#   --> degenerative change d/t old fracture._x000D_
#        D/Dx. gout_x000D_
# _x000D_
# both subtalar joint OA._x000D_
# pes planus, both._x000D_
# [ Conclusion ]_x000D_
# minimal OA, both knee joints._x000D_
# Rt. calcaneous, old fracture._x000D_
# Rt. 5th MT head fracture, old._x000D_
# both 3-4th MT head, radiolucency._x000D_
#   --> degenerative change d/t old fracture._x000D_
#        D/Dx. gout_x000D_
# _x000D_
# both subtalar joint OA._x000D_
# pes planus, both._x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# minimal OA, both knee joints. Rt. calcaneous, old fracture. Rt. 5th MT head fracture, old. both 3-4th MT head, radiolucency. --> degenerative change d/t old fracture. D/Dx. gout both subtalar joint OA. pes planus, both.
# Generated Report :
#
#
# --- Example 172 ---
# Raw Report       :
# [ Finding ]_x000D_
# _x000D_
# [ Diagnosis ]_x000D_
# 1. Suspicious soft tissue swelling in right 5th MTP joint level._x000D_
# Subtle low density lesion with sclerotic rim in both 1st proximal phalangeal bone 2. base, central portion._x000D_
#   --- suspicious subchondral cysts._x000D_
# [ Recommend ]_x000D_
#
# Cleaned Report   :
# 1. Suspicious soft tissue swelling in right 5th MTP joint level. Subtle low density lesion with sclerotic rim in both 1st proximal phalangeal bone 2. base, central portion. --- suspicious subchondral cysts.
# Generated Report :
#  來 TMT, Rt. ankle soft tissue swelling of both 1st MTP joint and proximal phalange in RA involvement with calcaneus (mammeral bone). Lt. toe osteopenia degenerative change --> no significant interval changes since last study on radiographs at PIP joints or accessory navicular type II -> OA incision to the right lateral aspect hallux valgum > Kneosions as indicated by gouty arthritis r/o GOUTY ACU formation periarticle os trigoncavious lesion along PT 2nd MT knee protrusive area erosion enchondral head space narrowing - probable ossification otitis General X-ray evidence suggestive
